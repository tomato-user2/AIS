# %% [markdown]
# ## LSTM Model to predict vessel status
#
# ## Table of Contents
# 1. [Description](#model-selection)
# 2. [Further Datapreparation](#further-datapreparation)
# 3. [Model Script](#model-script)
# 4. [Detailed Explanations](#explanation)

# %% [markdown]
# ## Model Selection
#
# The problem at hand is a binary classification task to predict the navigational status of vessels: "Under way using engine" versus "Engaged in fishing." After experimenting with various approaches, including Random Forest and CNN, an LSTM-based neural network was chosen for its ability to model sequential dependencies in time-series data. The LSTM architecture was selected due to its effectiveness in capturing temporal patterns in features such as Speed Over Ground (SOG), Course Over Ground (COG), and Heading.
#
# ---
#
# ## Feature Engineering
#
# Feature engineering was a critical step in preparing the dataset for modeling. Key steps included:
#
# 1. **Normalization**: SOG values were normalized using MinMaxScaler to ensure all features were on a similar scale.
# 2. **Cyclical Encoding**: Circular features like COG and Heading were encoded using sine and cosine transformations to preserve their cyclical nature.
# 3. **Sequence Creation**: Each input sequence was created with a fixed length of 60 time steps, corresponding to 1 hour of data sampled at 1-minute intervals.
# 4. **Initial Course Adjustment**: The initial COG was subtracted from all COG and Heading values to standardize the directionality across sequences.
#
# ---
#
# ## Hyperparameter Tuning
#
# Hyperparameter tuning was conducted using a combination of manual experimentation and automated tools like Keras Tuner. Key hyperparameters tuned included:
#
# 1. **Number of LSTM Layers and Units**: Experiments with single and multi-layer LSTM architectures led to the final choice of two LSTM layers with 64 and 32 units, respectively.
# 2. **Dropout Rates**: Dropout rates of 0.3 were applied after each LSTM layer to mitigate overfitting.
# 3. **Batch Size and Learning Rate**: A batch size of 32 and the Adam optimizer with default learning rates provided the best results.
# 4. **Activation Functions**: The final output layer used a sigmoid activation function for binary classification.
#
# ---
#
# ## Implementation
#
# The LSTM model was implemented using TensorFlow/Keras. The architecture consisted of:
#
# - Two LSTM layers (64 and 32 units) with return sequences enabled for the first layer.
# - Dropout layers after each LSTM layer.
# - A Dense layer with 32 units and ReLU activation.
# - A final Dense layer with a sigmoid activation function for binary classification.
#
# Training was conducted with early stopping to monitor validation loss, with a patience of 10 epochs to prevent overfitting. The model was trained for up to 200 epochs, with validation split set to 20% of the training data.
#
# ---
#
# ## Evaluation Metrics
#
# The model’s performance was evaluated using:
#
# 1. **Accuracy**: Achieved a test accuracy of 0.99.
# 2. **F1 Score**: Recorded an F1 score of 0.99, indicating a balance between precision and recall.
# 3. **Precision and Recall**: Precision and recall scores were 0.99 and 0.98, respectively, demonstrating the model’s ability to minimize false positives and false negatives.
# 4. **Confusion Matrix**: Highlighted the model’s ability to correctly classify both classes with minimal misclassifications.
# 5. **ROC Curve and AUC**: The AUC of 0.99 indicated excellent model discrimination.
#
# ---
#
# ## Comparative Analysis
#
# The LSTM model outperformed other approaches, including:
#
# 1. **Baseline Random Forest Model**: Achieved an accuracy of 0.68–0.78, but struggled to recognize certain classes and lacked temporal modeling capabilities.
# 2. **CNN Architecture**: While capable of capturing spatial patterns, the CNN overfitted and did not leverage temporal dependencies effectively.
# 3. **Flattened Data Approach**: Flattening sequences into vectors led to faster computation but resulted in overfitting and lower generalization performance.
#
# The final LSTM model’s ability to capture temporal dependencies, combined with robust feature engineering and careful hyperparameter tuning, resulted in a significant performance improvement, making it the best-performing model for this task.

# %% [markdown]
# ## Further Datapreparation

# %%
import os
import shutil
import pandas as pd

# Define the source and destination folders
source_folder = '../2_BaselineModel/time_sets_st_shortened'
destination_folder = './input/engaged_in_fishing'

# Ensure destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Iterate over each file in the source folder
for filename in os.listdir(source_folder):
    # Check if the file is a CSV file
    if filename.endswith('.csv'):
        file_path = os.path.join(source_folder, filename)
        
        # Try to read the CSV file
        try:
            df = pd.read_csv(file_path)

            # Check if 'Navigational status' column exists and contains the value 'Underway using engine'
            if 'Navigational status' in df.columns and 'Engaged in fishing' in df['Navigational status'].values:
                # If the condition is met, copy the file to the destination folder
                shutil.copy(file_path, os.path.join(destination_folder, filename))
                print(f"Copied: {filename}")
        except Exception as e:
            print(f"Could not process {filename}: {e}")

print("Script execution completed.")
# Out:
# Copied: filtered_219001518_20240522_0220-20240522_0235_standardized_10s.csv
# Copied: filtered_219001518_20240522_0235-20240522_0250_standardized_10s.csv
# Copied: filtered_219001518_20240522_0320-20240522_0335_standardized_10s.csv
# Copied: filtered_219001518_20240522_0350-20240522_0405_standardized_10s.csv
# Copied: filtered_219001518_20240522_0405-20240522_0420_standardized_10s.csv
# Copied: filtered_219001518_20240522_0450-20240522_0505_standardized_10s.csv
# Copied: filtered_219001518_20240522_0635-20240522_0650_standardized_10s.csv
# Copied: filtered_219001518_20240522_0705-20240522_0720_standardized_10s.csv
# Copied: filtered_219001518_20240522_0820-20240522_0835_standardized_10s.csv
# Copied: filtered_219001518_20240522_0905-20240522_0920_standardized_10s.csv
# Copied: filtered_219001518_20240522_0920-20240522_0935_standardized_10s.csv
# Copied: filtered_219001518_20240522_0935-20240522_0950_standardized_10s.csv
# Copied: filtered_219001518_20240522_0950-20240522_1005_standardized_10s.csv
# Copied: filtered_219001518_20240522_1005-20240522_1020_standardized_10s.csv
# Copied: filtered_219001518_20240522_1035-20240522_1050_standardized_10s.csv
# Copied: filtered_219001518_20240522_1120-20240522_1135_standardized_10s.csv
# Copied: filtered_219001518_20240522_1220-20240522_1235_standardized_10s.csv
# Copied: filtered_219001518_20240522_1350-20240522_1405_standardized_10s.csv
# Copied: filtered_219001518_20240522_1420-20240522_1435_standardized_10s.csv
# Copied: filtered_219001518_20240522_1505-20240522_1520_standardized_10s.csv
# Copied: filtered_219001518_20240522_1520-20240522_1535_standardized_10s.csv
# Copied: filtered_219001518_20240522_1550-20240522_1605_standardized_10s.csv
# Copied: filtered_219001518_20240522_1635-20240522_1650_standardized_10s.csv
# Copied: filtered_219001518_20240522_1735-20240522_1750_standardized_10s.csv
# Copied: filtered_219001518_20240522_1805-20240522_1820_standardized_10s.csv
# Copied: filtered_219001518_20240522_1820-20240522_1835_standardized_10s.csv
# Copied: filtered_219001518_20240522_1835-20240522_1850_standardized_10s.csv
# Copied: filtered_219001518_20240522_1905-20240522_1920_standardized_10s.csv
# Copied: filtered_219001518_20240522_1935-20240522_1950_standardized_10s.csv
# Copied: filtered_219001518_20240522_1950-20240522_2005_standardized_10s.csv
# Copied: filtered_219001518_20240522_2005-20240522_2020_standardized_10s.csv
# Copied: filtered_219001518_20240522_2050-20240522_2105_standardized_10s.csv
# Copied: filtered_219001518_20240522_2105-20240522_2120_standardized_10s.csv
# Copied: filtered_219001518_20240522_2150-20240522_2205_standardized_10s.csv
# Copied: filtered_219001518_20240522_2220-20240522_2235_standardized_10s.csv
# Copied: filtered_219001518_20240522_2235-20240522_2250_standardized_10s.csv
# Copied: filtered_219001518_20240522_2250-20240522_2305_standardized_10s.csv
# Copied: filtered_219001518_20240522_2320-20240522_2335_standardized_10s.csv
# Copied: filtered_219001518_20240523_0105-20240523_0120_standardized_10s.csv
# Copied: filtered_219001518_20240523_0205-20240523_0220_standardized_10s.csv
# Copied: filtered_219001518_20240523_0305-20240523_0320_standardized_10s.csv
# Copied: filtered_219001518_20240523_0335-20240523_0350_standardized_10s.csv
# Copied: filtered_219001518_20240523_0435-20240523_0450_standardized_10s.csv
# Copied: filtered_219001518_20240523_0450-20240523_0505_standardized_10s.csv
# Copied: filtered_219001518_20240523_0620-20240523_0635_standardized_10s.csv
# Copied: filtered_219001518_20240523_0705-20240523_0720_standardized_10s.csv
# Copied: filtered_219001518_20240523_0735-20240523_0750_standardized_10s.csv
# Copied: filtered_219001518_20240523_0820-20240523_0835_standardized_10s.csv
# Copied: filtered_219001518_20240523_0850-20240523_0905_standardized_10s.csv
# Copied: filtered_219001518_20240523_0920-20240523_0935_standardized_10s.csv
# Copied: filtered_219001518_20240523_0935-20240523_0950_standardized_10s.csv
# Copied: filtered_219001518_20240523_0950-20240523_1005_standardized_10s.csv
# Copied: filtered_219001518_20240523_1020-20240523_1035_standardized_10s.csv
# Copied: filtered_219001518_20240523_1035-20240523_1050_standardized_10s.csv
# Copied: filtered_219001518_20240523_1105-20240523_1120_standardized_10s.csv
# Copied: filtered_219001518_20240523_1120-20240523_1135_standardized_10s.csv
# Copied: filtered_219001518_20240524_1020-20240524_1035_standardized_10s.csv
# Copied: filtered_219001518_20240524_1035-20240524_1050_standardized_10s.csv
# Copied: filtered_219001518_20240524_1105-20240524_1120_standardized_10s.csv
# Copied: filtered_219001518_20240524_1120-20240524_1135_standardized_10s.csv
# Copied: filtered_219001518_20240524_1220-20240524_1235_standardized_10s.csv
# Copied: filtered_219001518_20240524_1235-20240524_1250_standardized_10s.csv
# Copied: filtered_219001518_20240524_1305-20240524_1320_standardized_10s.csv
# Copied: filtered_219001518_20240524_1320-20240524_1335_standardized_10s.csv
# Copied: filtered_219001518_20240524_1350-20240524_1405_standardized_10s.csv
# Copied: filtered_219001518_20240524_1405-20240524_1420_standardized_10s.csv
# Copied: filtered_219001518_20240524_1435-20240524_1450_standardized_10s.csv
# Copied: filtered_219001518_20240524_1450-20240524_1505_standardized_10s.csv
# Copied: filtered_219001518_20240524_1505-20240524_1520_standardized_10s.csv
# Copied: filtered_219001518_20240524_1535-20240524_1550_standardized_10s.csv
# Copied: filtered_219001518_20240524_1605-20240524_1620_standardized_10s.csv
# Copied: filtered_219001518_20240524_1635-20240524_1650_standardized_10s.csv
# Copied: filtered_219001518_20240524_1705-20240524_1720_standardized_10s.csv
# Copied: filtered_219001518_20240524_1735-20240524_1750_standardized_10s.csv
# Copied: filtered_219001518_20240524_1820-20240524_1835_standardized_10s.csv
# Copied: filtered_219001518_20240524_1835-20240524_1850_standardized_10s.csv
# Copied: filtered_219001518_20240524_1905-20240524_1920_standardized_10s.csv
# Copied: filtered_219001518_20240524_1950-20240524_2005_standardized_10s.csv
# Copied: filtered_219001518_20240524_2020-20240524_2035_standardized_10s.csv
# Copied: filtered_219001518_20240524_2035-20240524_2050_standardized_10s.csv
# Copied: filtered_219001518_20240524_2120-20240524_2135_standardized_10s.csv
# Copied: filtered_219001518_20240524_2205-20240524_2220_standardized_10s.csv
# Copied: filtered_219001518_20240524_2220-20240524_2235_standardized_10s.csv
# Copied: filtered_219001518_20240524_2235-20240524_2250_standardized_10s.csv
# Copied: filtered_219001518_20240524_2305-20240524_2320_standardized_10s.csv
# Copied: filtered_219001518_20240524_2335-20240524_2350_standardized_10s.csv
# Copied: filtered_219001518_20240525_0000-20240525_0015_standardized_10s.csv
# Copied: filtered_219001518_20240525_0015-20240525_0030_standardized_10s.csv
# Copied: filtered_219001518_20240525_0045-20240525_0100_standardized_10s.csv
# Copied: filtered_219001518_20240525_0100-20240525_0115_standardized_10s.csv
# Copied: filtered_219001518_20240525_0130-20240525_0145_standardized_10s.csv
# Copied: filtered_219001518_20240525_0515-20240525_0530_standardized_10s.csv
# Copied: filtered_219001518_20240525_0545-20240525_0559_standardized_10s.csv
# Copied: filtered_219001518_20240525_0600-20240525_0614_standardized_10s.csv
# Copied: filtered_219001518_20240525_0615-20240525_0629_standardized_10s.csv
# Copied: filtered_219001518_20240525_0630-20240525_0645_standardized_10s.csv
# Copied: filtered_219001518_20240525_0700-20240525_0714_standardized_10s.csv
# Copied: filtered_219001518_20240525_0745-20240525_0800_standardized_10s.csv
# Copied: filtered_219001518_20240525_0845-20240525_0859_standardized_10s.csv
# Copied: filtered_219001518_20240525_0900-20240525_0914_standardized_10s.csv
# Copied: filtered_219001518_20240525_0915-20240525_0930_standardized_10s.csv
# Copied: filtered_219001518_20240525_0930-20240525_0945_standardized_10s.csv
# Copied: filtered_219001518_20240525_1045-20240525_1100_standardized_10s.csv
# Copied: filtered_219001518_20240525_1100-20240525_1115_standardized_10s.csv
# Copied: filtered_219001518_20240525_1130-20240525_1145_standardized_10s.csv
# Copied: filtered_219001518_20240525_1200-20240525_1215_standardized_10s.csv
# Copied: filtered_219001518_20240525_1230-20240525_1244_standardized_10s.csv
# Copied: filtered_219001518_20240525_1245-20240525_1300_standardized_10s.csv
# Copied: filtered_219001518_20240525_1315-20240525_1330_standardized_10s.csv
# Copied: filtered_219001518_20240525_1500-20240525_1515_standardized_10s.csv
# Copied: filtered_219001518_20240529_1239-20240529_1254_standardized_10s.csv
# Copied: filtered_219001518_20240529_1254-20240529_1309_standardized_10s.csv
# Copied: filtered_219001518_20240529_1309-20240529_1324_standardized_10s.csv
# Copied: filtered_219001518_20240529_1354-20240529_1409_standardized_10s.csv
# Copied: filtered_219001518_20240529_1524-20240529_1539_standardized_10s.csv
# Copied: filtered_219001518_20240529_1609-20240529_1624_standardized_10s.csv
# Copied: filtered_219001518_20240530_1154-20240530_1209_standardized_10s.csv
# Copied: filtered_219001518_20240530_1209-20240530_1224_standardized_10s.csv
# Copied: filtered_219001518_20240530_1224-20240530_1239_standardized_10s.csv
# Copied: filtered_219001518_20240530_1324-20240530_1339_standardized_10s.csv
# Copied: filtered_219001518_20240530_1354-20240530_1409_standardized_10s.csv
# Copied: filtered_219001518_20240530_1424-20240530_1439_standardized_10s.csv
# Copied: filtered_219001518_20240530_1454-20240530_1509_standardized_10s.csv
# Copied: filtered_219001518_20240530_1509-20240530_1524_standardized_10s.csv
# Copied: filtered_219001518_20240530_1624-20240530_1639_standardized_10s.csv
# Copied: filtered_219001518_20240530_1724-20240530_1739_standardized_10s.csv
# Copied: filtered_219001518_20240530_1754-20240530_1809_standardized_10s.csv
# Copied: filtered_219001518_20240530_1839-20240530_1854_standardized_10s.csv
# Copied: filtered_219001518_20240530_1939-20240530_1954_standardized_10s.csv
# Copied: filtered_219001518_20240530_1954-20240530_2009_standardized_10s.csv
# Copied: filtered_219001518_20240530_2039-20240530_2054_standardized_10s.csv
# Copied: filtered_219001518_20240530_2124-20240530_2139_standardized_10s.csv
# Copied: filtered_219001518_20240530_2154-20240530_2209_standardized_10s.csv
# Copied: filtered_219001518_20240530_2239-20240530_2254_standardized_10s.csv
# Copied: filtered_219001518_20240530_2309-20240530_2324_standardized_10s.csv
# Copied: filtered_219004203_20240523_0048-20240523_0103_standardized_10s.csv
# Copied: filtered_219004203_20240523_0118-20240523_0133_standardized_10s.csv
# Copied: filtered_219004203_20240523_0203-20240523_0218_standardized_10s.csv
# Copied: filtered_219004203_20240523_0218-20240523_0233_standardized_10s.csv
# Copied: filtered_219004203_20240523_0233-20240523_0248_standardized_10s.csv
# Copied: filtered_219004203_20240523_0303-20240523_0318_standardized_10s.csv
# Copied: filtered_219004203_20240523_0403-20240523_0418_standardized_10s.csv
# Copied: filtered_219004203_20240523_0418-20240523_0433_standardized_10s.csv
# Copied: filtered_219004203_20240523_0448-20240523_0503_standardized_10s.csv
# Copied: filtered_219004203_20240523_0503-20240523_0518_standardized_10s.csv
# Copied: filtered_219004203_20240523_0533-20240523_0548_standardized_10s.csv
# Copied: filtered_219004203_20240523_0618-20240523_0633_standardized_10s.csv
# Copied: filtered_219004203_20240523_0633-20240523_0648_standardized_10s.csv
# Copied: filtered_219004203_20240523_0648-20240523_0703_standardized_10s.csv
# Copied: filtered_219004203_20240523_0818-20240523_0833_standardized_10s.csv
# Copied: filtered_219004203_20240523_0903-20240523_0918_standardized_10s.csv
# Copied: filtered_219004203_20240523_0918-20240523_0933_standardized_10s.csv
# Copied: filtered_219004203_20240523_1003-20240523_1018_standardized_10s.csv
# Copied: filtered_219004203_20240523_1018-20240523_1033_standardized_10s.csv
# Copied: filtered_219004203_20240523_1033-20240523_1048_standardized_10s.csv
# Copied: filtered_219004203_20240523_1103-20240523_1118_standardized_10s.csv
# Copied: filtered_219004203_20240523_1118-20240523_1133_standardized_10s.csv
# Copied: filtered_219004203_20240523_1133-20240523_1148_standardized_10s.csv
# Copied: filtered_219004203_20240523_1333-20240523_1348_standardized_10s.csv
# Copied: filtered_219004203_20240523_1348-20240523_1403_standardized_10s.csv
# Copied: filtered_219004203_20240523_1418-20240523_1433_standardized_10s.csv
# Copied: filtered_219004203_20240523_1433-20240523_1448_standardized_10s.csv
# Copied: filtered_219004203_20240523_1448-20240523_1503_standardized_10s.csv
# Copied: filtered_219004203_20240523_1503-20240523_1518_standardized_10s.csv
# Copied: filtered_219004203_20240523_1518-20240523_1533_standardized_10s.csv
# Copied: filtered_219004203_20240523_1548-20240523_1603_standardized_10s.csv
# Copied: filtered_219004203_20240523_1603-20240523_1618_standardized_10s.csv
# Copied: filtered_219004203_20240523_1633-20240523_1648_standardized_10s.csv
# Copied: filtered_219004203_20240523_1648-20240523_1703_standardized_10s.csv
# Copied: filtered_219004203_20240523_1718-20240523_1733_standardized_10s.csv
# Copied: filtered_219004203_20240523_1818-20240523_1833_standardized_10s.csv
# Copied: filtered_219004203_20240523_1833-20240523_1848_standardized_10s.csv
# Copied: filtered_219004203_20240523_2003-20240523_2018_standardized_10s.csv
# Copied: filtered_219004203_20240523_2018-20240523_2033_standardized_10s.csv
# Copied: filtered_219004203_20240523_2048-20240523_2103_standardized_10s.csv
# Copied: filtered_219004203_20240523_2118-20240523_2133_standardized_10s.csv
# Copied: filtered_219004203_20240524_0603-20240524_0618_standardized_10s.csv
# Copied: filtered_219004203_20240524_0718-20240524_0733_standardized_10s.csv
# Copied: filtered_219004203_20240524_0933-20240524_0948_standardized_10s.csv
# Copied: filtered_219004203_20240524_0948-20240524_1003_standardized_10s.csv
# Copied: filtered_219004203_20240524_1003-20240524_1018_standardized_10s.csv
# Copied: filtered_219004203_20240524_1048-20240524_1103_standardized_10s.csv
# Copied: filtered_219004203_20240524_1403-20240524_1418_standardized_10s.csv
# Copied: filtered_219004203_20240524_1548-20240524_1603_standardized_10s.csv
# Copied: filtered_219004203_20240524_1603-20240524_1618_standardized_10s.csv
# Copied: filtered_219004203_20240524_1618-20240524_1633_standardized_10s.csv
# Copied: filtered_219004203_20240524_1633-20240524_1648_standardized_10s.csv
# Copied: filtered_219004203_20240524_1818-20240524_1833_standardized_10s.csv
# Copied: filtered_219004203_20240524_1833-20240524_1848_standardized_10s.csv
# Copied: filtered_219004203_20240524_1848-20240524_1903_standardized_10s.csv
# Copied: filtered_219004203_20240524_1918-20240524_1933_standardized_10s.csv
# Copied: filtered_219004203_20240524_1933-20240524_1948_standardized_10s.csv
# Copied: filtered_219004203_20240524_1948-20240524_2003_standardized_10s.csv
# Copied: filtered_219004203_20240524_2003-20240524_2018_standardized_10s.csv
# Copied: filtered_219004203_20240524_2018-20240524_2033_standardized_10s.csv
# Copied: filtered_219004203_20240524_2033-20240524_2048_standardized_10s.csv
# Copied: filtered_219004203_20240524_2048-20240524_2103_standardized_10s.csv
# Copied: filtered_219004203_20240525_0005-20240525_0020_standardized_10s.csv
# Copied: filtered_219004203_20240525_0035-20240525_0050_standardized_10s.csv
# Copied: filtered_219004203_20240525_0050-20240525_0105_standardized_10s.csv
# Copied: filtered_219004203_20240525_0105-20240525_0120_standardized_10s.csv
# Copied: filtered_219004203_20240525_0120-20240525_0135_standardized_10s.csv
# Copied: filtered_219004203_20240525_0220-20240525_0235_standardized_10s.csv
# Copied: filtered_219004203_20240525_0250-20240525_0305_standardized_10s.csv
# Copied: filtered_219004203_20240525_0320-20240525_0335_standardized_10s.csv
# Copied: filtered_219004203_20240525_0336-20240525_0350_standardized_10s.csv
# Copied: filtered_219004203_20240525_0420-20240525_0435_standardized_10s.csv
# Copied: filtered_219004203_20240525_0451-20240525_0505_standardized_10s.csv
# Copied: filtered_219004203_20240525_0606-20240525_0620_standardized_10s.csv
# Copied: filtered_219004203_20240525_0621-20240525_0635_standardized_10s.csv
# Copied: filtered_219004203_20240525_0905-20240525_0920_standardized_10s.csv
# Copied: filtered_219004203_20240525_0920-20240525_0935_standardized_10s.csv
# Copied: filtered_219004203_20240525_1035-20240525_1050_standardized_10s.csv
# Copied: filtered_219004203_20240525_1120-20240525_1135_standardized_10s.csv
# Copied: filtered_219004203_20240525_1305-20240525_1320_standardized_10s.csv
# Copied: filtered_219004203_20240525_1321-20240525_1335_standardized_10s.csv
# Copied: filtered_219004203_20240525_1350-20240525_1405_standardized_10s.csv
# Copied: filtered_219004203_20240525_1450-20240525_1505_standardized_10s.csv
# Copied: filtered_219004203_20240525_1520-20240525_1535_standardized_10s.csv
# Copied: filtered_219004203_20240525_1550-20240525_1605_standardized_10s.csv
# Copied: filtered_219004203_20240525_1651-20240525_1705_standardized_10s.csv
# Copied: filtered_219004203_20240525_1935-20240525_1950_standardized_10s.csv
# Copied: filtered_219004203_20240525_2020-20240525_2035_standardized_10s.csv
# Copied: filtered_219004203_20240525_2051-20240525_2105_standardized_10s.csv
# Copied: filtered_219004203_20240525_2120-20240525_2135_standardized_10s.csv
# Copied: filtered_219004203_20240525_2150-20240525_2205_standardized_10s.csv
# Copied: filtered_219004203_20240526_0350-20240526_0405_standardized_10s.csv
# Copied: filtered_219004203_20240526_0420-20240526_0435_standardized_10s.csv
# Copied: filtered_219004203_20240526_0450-20240526_0505_standardized_10s.csv
# Copied: filtered_219004203_20240526_0505-20240526_0520_standardized_10s.csv
# Copied: filtered_219004203_20240526_0520-20240526_0535_standardized_10s.csv
# Copied: filtered_219004203_20240526_0721-20240526_0735_standardized_10s.csv
# Copied: filtered_219004203_20240526_0805-20240526_0820_standardized_10s.csv
# Copied: filtered_219004203_20240526_0850-20240526_0905_standardized_10s.csv
# Copied: filtered_219004203_20240526_0920-20240526_0935_standardized_10s.csv
# Copied: filtered_219004203_20240526_1006-20240526_1020_standardized_10s.csv
# Copied: filtered_219004203_20240526_1021-20240526_1035_standardized_10s.csv
# Copied: filtered_219004203_20240526_1050-20240526_1105_standardized_10s.csv
# Copied: filtered_219004203_20240526_1335-20240526_1350_standardized_10s.csv
# Copied: filtered_219004203_20240526_1350-20240526_1405_standardized_10s.csv
# Copied: filtered_219004203_20240526_1421-20240526_1435_standardized_10s.csv
# Copied: filtered_219004203_20240526_1520-20240526_1535_standardized_10s.csv
# Copied: filtered_219004203_20240526_1920-20240526_1935_standardized_10s.csv
# Copied: filtered_219004203_20240526_2005-20240526_2020_standardized_10s.csv
# Copied: filtered_219004203_20240526_2120-20240526_2135_standardized_10s.csv
# Copied: filtered_219004203_20240526_2135-20240526_2150_standardized_10s.csv
# Copied: filtered_219004203_20240526_2150-20240526_2205_standardized_10s.csv
# Copied: filtered_219004203_20240526_2205-20240526_2220_standardized_10s.csv
# Copied: filtered_219004203_20240526_2305-20240526_2320_standardized_10s.csv
# Copied: filtered_219004203_20240527_0005-20240527_0020_standardized_10s.csv
# Copied: filtered_219004203_20240527_0035-20240527_0050_standardized_10s.csv
# Copied: filtered_219004203_20240527_0050-20240527_0105_standardized_10s.csv
# Copied: filtered_219004203_20240527_0136-20240527_0150_standardized_10s.csv
# Copied: filtered_219004203_20240527_0250-20240527_0305_standardized_10s.csv
# Copied: filtered_219004203_20240527_0335-20240527_0350_standardized_10s.csv
# Copied: filtered_219004203_20240527_0405-20240527_0420_standardized_10s.csv
# Copied: filtered_219004203_20240527_0905-20240527_0920_standardized_10s.csv
# Copied: filtered_219004203_20240527_0920-20240527_0935_standardized_10s.csv
# Copied: filtered_219004203_20240527_1005-20240527_1020_standardized_10s.csv
# Copied: filtered_219004203_20240527_1020-20240527_1035_standardized_10s.csv
# Copied: filtered_219004203_20240527_1106-20240527_1120_standardized_10s.csv
# Copied: filtered_219004203_20240527_1135-20240527_1150_standardized_10s.csv
# Copied: filtered_219004203_20240527_1150-20240527_1205_standardized_10s.csv
# Copied: filtered_219004203_20240527_1205-20240527_1220_standardized_10s.csv
# Copied: filtered_219004203_20240527_1235-20240527_1250_standardized_10s.csv
# Copied: filtered_219004203_20240527_1305-20240527_1320_standardized_10s.csv
# Copied: filtered_219004203_20240527_1405-20240527_1420_standardized_10s.csv
# Copied: filtered_219004203_20240527_2321-20240527_2335_standardized_10s.csv
# Copied: filtered_219004203_20240528_0000-20240528_0014_standardized_10s.csv
# Copied: filtered_219004203_20240528_0015-20240528_0029_standardized_10s.csv
# Copied: filtered_219004203_20240528_0030-20240528_0044_standardized_10s.csv
# Copied: filtered_219004203_20240528_0045-20240528_0059_standardized_10s.csv
# Copied: filtered_219004203_20240528_0100-20240528_0114_standardized_10s.csv
# Copied: filtered_219004203_20240528_0115-20240528_0129_standardized_10s.csv
# Copied: filtered_219004203_20240528_0130-20240528_0144_standardized_10s.csv
# Copied: filtered_219004203_20240530_2000-20240530_2014_standardized_10s.csv
# Copied: filtered_219004203_20240530_2015-20240530_2029_standardized_10s.csv
# Copied: filtered_219004203_20240530_2030-20240530_2045_standardized_10s.csv
# Copied: filtered_219004203_20240530_2100-20240530_2114_standardized_10s.csv
# Copied: filtered_219005867_20240524_0650-20240524_0705_standardized_10s.csv
# Copied: filtered_219005867_20240524_0705-20240524_0720_standardized_10s.csv
# Copied: filtered_219005867_20240524_0720-20240524_0735_standardized_10s.csv
# Copied: filtered_219005867_20240524_0735-20240524_0750_standardized_10s.csv
# Copied: filtered_219005867_20240524_0750-20240524_0805_standardized_10s.csv
# Copied: filtered_219005867_20240524_0835-20240524_0850_standardized_10s.csv
# Copied: filtered_219005867_20240524_0905-20240524_0920_standardized_10s.csv
# Copied: filtered_219005867_20240524_0935-20240524_0950_standardized_10s.csv
# Copied: filtered_219005867_20240524_0950-20240524_1005_standardized_10s.csv
# Copied: filtered_219005867_20240524_1005-20240524_1020_standardized_10s.csv
# Copied: filtered_219005867_20240524_1035-20240524_1050_standardized_10s.csv
# Copied: filtered_219005867_20240524_1050-20240524_1105_standardized_10s.csv
# Copied: filtered_219005867_20240524_1105-20240524_1120_standardized_10s.csv
# Copied: filtered_219005867_20240524_1120-20240524_1135_standardized_10s.csv
# Copied: filtered_219005867_20240524_1135-20240524_1150_standardized_10s.csv
# Copied: filtered_219005867_20240524_1205-20240524_1220_standardized_10s.csv
# Copied: filtered_219005867_20240524_1305-20240524_1320_standardized_10s.csv
# Copied: filtered_219005867_20240524_1320-20240524_1335_standardized_10s.csv
# Copied: filtered_219005867_20240524_1335-20240524_1350_standardized_10s.csv
# Copied: filtered_219005867_20240524_1405-20240524_1420_standardized_10s.csv
# Copied: filtered_219005867_20240524_1420-20240524_1435_standardized_10s.csv
# Copied: filtered_219005867_20240524_1435-20240524_1450_standardized_10s.csv
# Copied: filtered_219005867_20240524_1450-20240524_1505_standardized_10s.csv
# Copied: filtered_219005867_20240524_1520-20240524_1535_standardized_10s.csv
# Copied: filtered_219005867_20240524_1550-20240524_1605_standardized_10s.csv
# Copied: filtered_219005867_20240524_1605-20240524_1620_standardized_10s.csv
# Copied: filtered_219005867_20240524_1620-20240524_1635_standardized_10s.csv
# Copied: filtered_219005867_20240524_1635-20240524_1650_standardized_10s.csv
# Copied: filtered_219005867_20240525_0337-20240525_0352_standardized_10s.csv
# Copied: filtered_219005867_20240525_0407-20240525_0422_standardized_10s.csv
# Copied: filtered_219005867_20240525_0437-20240525_0452_standardized_10s.csv
# Copied: filtered_219005867_20240525_0522-20240525_0537_standardized_10s.csv
# Copied: filtered_219005867_20240525_0552-20240525_0607_standardized_10s.csv
# Copied: filtered_219005867_20240525_0652-20240525_0707_standardized_10s.csv
# Copied: filtered_219005867_20240525_0707-20240525_0722_standardized_10s.csv
# Copied: filtered_219005867_20240525_0722-20240525_0737_standardized_10s.csv
# Copied: filtered_219005867_20240525_0807-20240525_0822_standardized_10s.csv
# Copied: filtered_219005867_20240525_0837-20240525_0852_standardized_10s.csv
# Copied: filtered_219005867_20240525_0852-20240525_0907_standardized_10s.csv
# Copied: filtered_219005867_20240525_0922-20240525_0937_standardized_10s.csv
# Copied: filtered_219005867_20240525_0937-20240525_0952_standardized_10s.csv
# Copied: filtered_219005867_20240525_0952-20240525_1007_standardized_10s.csv
# Copied: filtered_219005867_20240525_1052-20240525_1107_standardized_10s.csv
# Copied: filtered_219005867_20240525_1122-20240525_1137_standardized_10s.csv
# Copied: filtered_219005867_20240525_1152-20240525_1207_standardized_10s.csv
# Copied: filtered_219005867_20240525_1237-20240525_1252_standardized_10s.csv
# Copied: filtered_219005867_20240525_1337-20240525_1352_standardized_10s.csv
# Copied: filtered_219005867_20240525_1407-20240525_1422_standardized_10s.csv
# Copied: filtered_219005867_20240525_1437-20240525_1452_standardized_10s.csv
# Copied: filtered_219005867_20240525_1452-20240525_1507_standardized_10s.csv
# Copied: filtered_219005867_20240525_1522-20240525_1537_standardized_10s.csv
# Copied: filtered_219005867_20240525_1552-20240525_1607_standardized_10s.csv
# Copied: filtered_219005867_20240525_1637-20240525_1652_standardized_10s.csv
# Copied: filtered_219005867_20240525_1707-20240525_1722_standardized_10s.csv
# Copied: filtered_219005867_20240525_1822-20240525_1837_standardized_10s.csv
# Copied: filtered_219005867_20240525_1922-20240525_1937_standardized_10s.csv
# Copied: filtered_219005867_20240526_0407-20240526_0422_standardized_10s.csv
# Copied: filtered_219005867_20240526_0437-20240526_0452_standardized_10s.csv
# Copied: filtered_219005867_20240526_0507-20240526_0522_standardized_10s.csv
# Copied: filtered_219005867_20240526_0622-20240526_0637_standardized_10s.csv
# Copied: filtered_219005867_20240526_0652-20240526_0707_standardized_10s.csv
# Copied: filtered_219005867_20240526_0822-20240526_0837_standardized_10s.csv
# Copied: filtered_219005867_20240526_0837-20240526_0852_standardized_10s.csv
# Copied: filtered_219005867_20240526_0852-20240526_0907_standardized_10s.csv
# Copied: filtered_219005867_20240526_0922-20240526_0937_standardized_10s.csv
# Copied: filtered_219005867_20240526_0952-20240526_1007_standardized_10s.csv
# Copied: filtered_219005867_20240526_1022-20240526_1037_standardized_10s.csv
# Copied: filtered_219005867_20240526_1037-20240526_1052_standardized_10s.csv
# Copied: filtered_219005867_20240526_1122-20240526_1137_standardized_10s.csv
# Copied: filtered_219005867_20240526_1137-20240526_1152_standardized_10s.csv
# Copied: filtered_219005867_20240526_1207-20240526_1222_standardized_10s.csv
# Copied: filtered_219005867_20240526_1237-20240526_1252_standardized_10s.csv
# Copied: filtered_219005867_20240526_1337-20240526_1352_standardized_10s.csv
# Copied: filtered_219005867_20240526_1352-20240526_1407_standardized_10s.csv
# Copied: filtered_219005867_20240526_1407-20240526_1422_standardized_10s.csv
# Copied: filtered_219005867_20240526_1437-20240526_1452_standardized_10s.csv
# Copied: filtered_219005867_20240526_1522-20240526_1537_standardized_10s.csv
# Copied: filtered_219005867_20240526_1622-20240526_1637_standardized_10s.csv
# Copied: filtered_219005867_20240526_1707-20240526_1722_standardized_10s.csv
# Copied: filtered_219005867_20240526_1737-20240526_1752_standardized_10s.csv
# Copied: filtered_219005867_20240526_1807-20240526_1822_standardized_10s.csv
# Copied: filtered_219005867_20240526_1837-20240526_1852_standardized_10s.csv
# Copied: filtered_219005867_20240526_1907-20240526_1922_standardized_10s.csv
# Copied: filtered_219013178_20240522_2314-20240522_2329_standardized_10s.csv
# Copied: filtered_219013178_20240522_2344-20240522_2359_standardized_10s.csv
# Copied: filtered_219013178_20240523_0044-20240523_0059_standardized_10s.csv
# Copied: filtered_219013178_20240523_0059-20240523_0114_standardized_10s.csv
# Copied: filtered_219013178_20240523_0129-20240523_0144_standardized_10s.csv
# Copied: filtered_219013178_20240523_0214-20240523_0229_standardized_10s.csv
# Copied: filtered_219013178_20240523_0229-20240523_0244_standardized_10s.csv
# Copied: filtered_219013178_20240523_0244-20240523_0259_standardized_10s.csv
# Copied: filtered_219013178_20240523_0329-20240523_0344_standardized_10s.csv
# Copied: filtered_219013178_20240523_0359-20240523_0414_standardized_10s.csv
# Copied: filtered_219013178_20240523_0514-20240523_0529_standardized_10s.csv
# Copied: filtered_219013178_20240523_0614-20240523_0629_standardized_10s.csv
# Copied: filtered_219013178_20240523_0729-20240523_0744_standardized_10s.csv
# Copied: filtered_219013178_20240523_0759-20240523_0814_standardized_10s.csv
# Copied: filtered_219013178_20240523_0844-20240523_0859_standardized_10s.csv
# Copied: filtered_219013178_20240523_0914-20240523_0929_standardized_10s.csv
# Copied: filtered_219013178_20240523_0944-20240523_0959_standardized_10s.csv
# Copied: filtered_219013178_20240523_1014-20240523_1029_standardized_10s.csv
# Copied: filtered_219013178_20240523_1029-20240523_1044_standardized_10s.csv
# Copied: filtered_219013178_20240523_1059-20240523_1114_standardized_10s.csv
# Copied: filtered_219013178_20240523_1129-20240523_1144_standardized_10s.csv
# Copied: filtered_219013178_20240523_1229-20240523_1244_standardized_10s.csv
# Copied: filtered_219013178_20240523_1244-20240523_1259_standardized_10s.csv
# Copied: filtered_219013178_20240523_1259-20240523_1314_standardized_10s.csv
# Copied: filtered_219013178_20240523_1329-20240523_1344_standardized_10s.csv
# Copied: filtered_219013178_20240523_1429-20240523_1444_standardized_10s.csv
# Copied: filtered_219013178_20240523_1514-20240523_1529_standardized_10s.csv
# Copied: filtered_219013178_20240523_1544-20240523_1559_standardized_10s.csv
# Copied: filtered_219013178_20240523_1559-20240523_1614_standardized_10s.csv
# Copied: filtered_219013178_20240523_1644-20240523_1659_standardized_10s.csv
# Copied: filtered_219013178_20240523_1714-20240523_1729_standardized_10s.csv
# Copied: filtered_219013178_20240523_1759-20240523_1814_standardized_10s.csv
# Copied: filtered_219013178_20240523_1914-20240523_1929_standardized_10s.csv
# Copied: filtered_219013178_20240523_1944-20240523_1959_standardized_10s.csv
# Copied: filtered_219013178_20240523_2044-20240523_2059_standardized_10s.csv
# Copied: filtered_219013178_20240523_2144-20240523_2159_standardized_10s.csv
# Copied: filtered_219013178_20240523_2159-20240523_2214_standardized_10s.csv
# Copied: filtered_219013178_20240523_2229-20240523_2244_standardized_10s.csv
# Copied: filtered_219013178_20240523_2259-20240523_2314_standardized_10s.csv
# Copied: filtered_219013178_20240523_2359-20240524_0014_standardized_10s.csv
# Copied: filtered_219013178_20240524_0014-20240524_0029_standardized_10s.csv
# Copied: filtered_219013178_20240524_0059-20240524_0114_standardized_10s.csv
# Copied: filtered_219013178_20240524_0129-20240524_0144_standardized_10s.csv
# Copied: filtered_219013178_20240524_0229-20240524_0244_standardized_10s.csv
# Copied: filtered_219013178_20240524_0329-20240524_0344_standardized_10s.csv
# Copied: filtered_219013178_20240524_0344-20240524_0359_standardized_10s.csv
# Copied: filtered_219013178_20240524_0414-20240524_0429_standardized_10s.csv
# Copied: filtered_219013178_20240524_0429-20240524_0444_standardized_10s.csv
# Copied: filtered_219013178_20240524_0514-20240524_0529_standardized_10s.csv
# Copied: filtered_219013178_20240524_0614-20240524_0629_standardized_10s.csv
# Copied: filtered_219013178_20240524_0659-20240524_0714_standardized_10s.csv
# Copied: filtered_219013178_20240524_0744-20240524_0759_standardized_10s.csv
# Copied: filtered_219013178_20240524_0844-20240524_0859_standardized_10s.csv
# Copied: filtered_219013178_20240524_0859-20240524_0914_standardized_10s.csv
# Copied: filtered_219013178_20240524_0929-20240524_0944_standardized_10s.csv
# Copied: filtered_219013178_20240524_0944-20240524_0959_standardized_10s.csv
# Copied: filtered_219013178_20240524_1014-20240524_1029_standardized_10s.csv
# Copied: filtered_219013178_20240524_1044-20240524_1059_standardized_10s.csv
# Copied: filtered_219013178_20240524_1059-20240524_1114_standardized_10s.csv
# Copied: filtered_219013178_20240524_1159-20240524_1214_standardized_10s.csv
# Copied: filtered_219013178_20240524_1214-20240524_1229_standardized_10s.csv
# Copied: filtered_219013178_20240524_2144-20240524_2159_standardized_10s.csv
# Copied: filtered_219013178_20240524_2214-20240524_2229_standardized_10s.csv
# Copied: filtered_219013178_20240524_2259-20240524_2314_standardized_10s.csv
# Copied: filtered_219013178_20240524_2344-20240524_2359_standardized_10s.csv
# Copied: filtered_219013178_20240525_0000-20240525_0014_standardized_10s.csv
# Copied: filtered_219013178_20240525_0015-20240525_0030_standardized_10s.csv
# Copied: filtered_219013178_20240525_0030-20240525_0045_standardized_10s.csv
# Copied: filtered_219013178_20240525_0130-20240525_0144_standardized_10s.csv
# Copied: filtered_219013178_20240525_0200-20240525_0215_standardized_10s.csv
# Copied: filtered_219013178_20240525_0230-20240525_0245_standardized_10s.csv
# Copied: filtered_219013178_20240525_0300-20240525_0314_standardized_10s.csv
# Copied: filtered_219013178_20240525_0315-20240525_0330_standardized_10s.csv
# Copied: filtered_219013178_20240525_0330-20240525_0345_standardized_10s.csv
# Copied: filtered_219013178_20240525_0345-20240525_0400_standardized_10s.csv
# Copied: filtered_219013178_20240525_0400-20240525_0415_standardized_10s.csv
# Copied: filtered_219013178_20240525_0415-20240525_0430_standardized_10s.csv
# Copied: filtered_219013178_20240525_0430-20240525_0445_standardized_10s.csv
# Copied: filtered_219013178_20240525_0445-20240525_0500_standardized_10s.csv
# Copied: filtered_219013178_20240525_0515-20240525_0530_standardized_10s.csv
# Copied: filtered_219013178_20240525_0530-20240525_0545_standardized_10s.csv
# Copied: filtered_219013178_20240525_0615-20240525_0630_standardized_10s.csv
# Copied: filtered_219013178_20240525_0630-20240525_0645_standardized_10s.csv
# Copied: filtered_219013178_20240525_0700-20240525_0715_standardized_10s.csv
# Copied: filtered_219013178_20240525_0715-20240525_0730_standardized_10s.csv
# Copied: filtered_219013178_20240525_0730-20240525_0745_standardized_10s.csv
# Copied: filtered_219013178_20240525_0830-20240525_0844_standardized_10s.csv
# Copied: filtered_219013178_20240525_0900-20240525_0915_standardized_10s.csv
# Copied: filtered_219013178_20240525_0915-20240525_0930_standardized_10s.csv
# Copied: filtered_219013178_20240525_0945-20240525_1000_standardized_10s.csv
# Copied: filtered_219013178_20240525_1000-20240525_1015_standardized_10s.csv
# Copied: filtered_219013178_20240526_0730-20240526_0745_standardized_10s.csv
# Copied: filtered_219013178_20240526_0745-20240526_0800_standardized_10s.csv
# Copied: filtered_219013178_20240526_0800-20240526_0815_standardized_10s.csv
# Copied: filtered_219013178_20240526_0915-20240526_0930_standardized_10s.csv
# Copied: filtered_219013178_20240526_1000-20240526_1015_standardized_10s.csv
# Copied: filtered_219013178_20240526_1015-20240526_1030_standardized_10s.csv
# Copied: filtered_219013178_20240526_1115-20240526_1130_standardized_10s.csv
# Copied: filtered_219013178_20240526_1130-20240526_1145_standardized_10s.csv
# Copied: filtered_219013178_20240526_1145-20240526_1200_standardized_10s.csv
# Copied: filtered_219013178_20240526_1200-20240526_1215_standardized_10s.csv
# Copied: filtered_219013178_20240526_1215-20240526_1230_standardized_10s.csv
# Copied: filtered_219013178_20240526_1230-20240526_1245_standardized_10s.csv
# Copied: filtered_219013178_20240526_1245-20240526_1300_standardized_10s.csv
# Copied: filtered_219013178_20240526_1300-20240526_1315_standardized_10s.csv
# Copied: filtered_219013178_20240526_1330-20240526_1345_standardized_10s.csv
# Copied: filtered_219013178_20240526_1400-20240526_1415_standardized_10s.csv
# Copied: filtered_219013178_20240526_1415-20240526_1430_standardized_10s.csv
# Copied: filtered_219013178_20240526_1430-20240526_1445_standardized_10s.csv
# Copied: filtered_219013178_20240526_1445-20240526_1500_standardized_10s.csv
# Copied: filtered_219013178_20240526_1515-20240526_1530_standardized_10s.csv
# Copied: filtered_219013178_20240526_1530-20240526_1545_standardized_10s.csv
# Copied: filtered_219013178_20240526_1600-20240526_1615_standardized_10s.csv
# Copied: filtered_219013178_20240526_1615-20240526_1630_standardized_10s.csv
# Copied: filtered_219013178_20240526_1630-20240526_1645_standardized_10s.csv
# Copied: filtered_219013178_20240526_1645-20240526_1700_standardized_10s.csv
# Copied: filtered_219013178_20240526_1730-20240526_1745_standardized_10s.csv
# Copied: filtered_219013178_20240526_1745-20240526_1800_standardized_10s.csv
# Copied: filtered_219013178_20240526_1800-20240526_1815_standardized_10s.csv
# Copied: filtered_219013178_20240526_1830-20240526_1845_standardized_10s.csv
# Copied: filtered_219013178_20240526_1930-20240526_1945_standardized_10s.csv
# Copied: filtered_219013178_20240526_1945-20240526_2000_standardized_10s.csv
# Copied: filtered_219013178_20240526_2015-20240526_2030_standardized_10s.csv
# Copied: filtered_219013178_20240526_2030-20240526_2045_standardized_10s.csv
# Copied: filtered_219013178_20240526_2045-20240526_2100_standardized_10s.csv
# Copied: filtered_219013178_20240526_2100-20240526_2115_standardized_10s.csv
# Copied: filtered_219013178_20240526_2115-20240526_2130_standardized_10s.csv
# Copied: filtered_219013178_20240527_0600-20240527_0615_standardized_10s.csv
# Copied: filtered_219013178_20240527_0615-20240527_0630_standardized_10s.csv
# Copied: filtered_219013178_20240527_0645-20240527_0700_standardized_10s.csv
# Copied: filtered_219013178_20240527_0700-20240527_0715_standardized_10s.csv
# Copied: filtered_219013178_20240527_0715-20240527_0730_standardized_10s.csv
# Copied: filtered_219013178_20240527_0730-20240527_0745_standardized_10s.csv
# Copied: filtered_219013178_20240527_0745-20240527_0800_standardized_10s.csv
# Copied: filtered_219013178_20240527_0800-20240527_0815_standardized_10s.csv
# Copied: filtered_219013178_20240527_0815-20240527_0830_standardized_10s.csv
# Copied: filtered_219013178_20240527_0830-20240527_0845_standardized_10s.csv
# Copied: filtered_219013178_20240527_0915-20240527_0930_standardized_10s.csv
# Copied: filtered_219013178_20240527_0945-20240527_1000_standardized_10s.csv
# Copied: filtered_219013178_20240527_1015-20240527_1030_standardized_10s.csv
# Copied: filtered_219013178_20240527_1100-20240527_1115_standardized_10s.csv
# Copied: filtered_219013178_20240527_1145-20240527_1200_standardized_10s.csv
# Copied: filtered_219013178_20240527_1200-20240527_1215_standardized_10s.csv
# Copied: filtered_219013178_20240527_1215-20240527_1230_standardized_10s.csv
# Copied: filtered_219013178_20240527_1245-20240527_1300_standardized_10s.csv
# Copied: filtered_219013178_20240527_1300-20240527_1315_standardized_10s.csv
# Copied: filtered_219013178_20240527_1315-20240527_1330_standardized_10s.csv
# Copied: filtered_219013178_20240527_1430-20240527_1445_standardized_10s.csv
# Copied: filtered_219013178_20240527_1515-20240527_1530_standardized_10s.csv
# Copied: filtered_219013178_20240527_1530-20240527_1545_standardized_10s.csv
# Copied: filtered_219013178_20240527_1545-20240527_1600_standardized_10s.csv
# Copied: filtered_219013178_20240527_1600-20240527_1615_standardized_10s.csv
# Copied: filtered_219013178_20240527_1615-20240527_1630_standardized_10s.csv
# Copied: filtered_219013178_20240527_1645-20240527_1700_standardized_10s.csv
# Copied: filtered_219013178_20240527_1700-20240527_1715_standardized_10s.csv
# Copied: filtered_219013178_20240527_1715-20240527_1730_standardized_10s.csv
# Copied: filtered_219013178_20240527_1730-20240527_1745_standardized_10s.csv
# Copied: filtered_219013178_20240527_1745-20240527_1800_standardized_10s.csv
# Copied: filtered_219013178_20240527_1815-20240527_1830_standardized_10s.csv
# Copied: filtered_219013178_20240527_1845-20240527_1900_standardized_10s.csv
# Copied: filtered_219013178_20240527_1915-20240527_1930_standardized_10s.csv
# Copied: filtered_219013178_20240527_1930-20240527_1945_standardized_10s.csv
# Copied: filtered_219013178_20240527_1945-20240527_2000_standardized_10s.csv
# Copied: filtered_219013178_20240527_2000-20240527_2015_standardized_10s.csv
# Copied: filtered_219013178_20240527_2015-20240527_2030_standardized_10s.csv
# Copied: filtered_219013178_20240527_2045-20240527_2100_standardized_10s.csv
# Copied: filtered_219013178_20240527_2130-20240527_2145_standardized_10s.csv
# Copied: filtered_219013178_20240527_2145-20240527_2200_standardized_10s.csv
# Copied: filtered_219013178_20240527_2215-20240527_2230_standardized_10s.csv
# Copied: filtered_219013178_20240527_2230-20240527_2245_standardized_10s.csv
# Copied: filtered_219013178_20240527_2315-20240527_2330_standardized_10s.csv
# Copied: filtered_219013178_20240528_0145-20240528_0159_standardized_10s.csv
# Copied: filtered_219013178_20240528_0245-20240528_0259_standardized_10s.csv
# Copied: filtered_219013178_20240528_0300-20240528_0314_standardized_10s.csv
# Copied: filtered_219013178_20240528_0315-20240528_0329_standardized_10s.csv
# Copied: filtered_219013178_20240528_0330-20240528_0344_standardized_10s.csv
# Copied: filtered_219013178_20240528_0415-20240528_0429_standardized_10s.csv
# Copied: filtered_219013178_20240528_0630-20240528_0644_standardized_10s.csv
# Copied: filtered_219013178_20240528_0715-20240528_0729_standardized_10s.csv
# Copied: filtered_219013178_20240528_0800-20240528_0814_standardized_10s.csv
# Copied: filtered_219013178_20240528_0815-20240528_0829_standardized_10s.csv
# Copied: filtered_219013178_20240528_0830-20240528_0844_standardized_10s.csv
# Copied: filtered_219013178_20240528_0900-20240528_0914_standardized_10s.csv
# Copied: filtered_219013178_20240528_0915-20240528_0929_standardized_10s.csv
# Copied: filtered_219013178_20240528_0945-20240528_0959_standardized_10s.csv
# Copied: filtered_219013178_20240528_1015-20240528_1029_standardized_10s.csv
# Copied: filtered_219013178_20240528_1045-20240528_1059_standardized_10s.csv
# ...
# Copied: filtered_261004881_20240522_1030-20240522_1045_standardized_10s.csv
# Copied: filtered_261004881_20240522_1100-20240522_1115_standardized_10s.csv
# Copied: filtered_261004881_20240522_1115-20240522_1130_standardized_10s.csv
# Copied: filtered_261004881_20240522_1200-20240522_1215_standardized_10s.csv
# Copied: filtered_261004881_20240522_1330-20240522_1345_standardized_10s.csv
# Copied: filtered_261004881_20240522_1400-20240522_1415_standardized_10s.csv
# Copied: filtered_261004881_20240522_1415-20240522_1430_standardized_10s.csv
# Copied: filtered_261004881_20240522_1445-20240522_1500_standardized_10s.csv
# Copied: filtered_261004881_20240522_1515-20240522_1530_standardized_10s.csv
# Copied: filtered_261004881_20240522_1530-20240522_1545_standardized_10s.csv
# Copied: filtered_261004881_20240522_1630-20240522_1645_standardized_10s.csv
# Copied: filtered_261004881_20240522_1645-20240522_1700_standardized_10s.csv
# Copied: filtered_261004881_20240522_1700-20240522_1715_standardized_10s.csv
# Copied: filtered_261004881_20240522_1800-20240522_1815_standardized_10s.csv
# Copied: filtered_261004881_20240522_1815-20240522_1830_standardized_10s.csv
# Copied: filtered_261004881_20240522_1900-20240522_1915_standardized_10s.csv
# Copied: filtered_261004881_20240522_1930-20240522_1945_standardized_10s.csv
# Copied: filtered_261004881_20240522_2000-20240522_2015_standardized_10s.csv
# Copied: filtered_261004881_20240522_2045-20240522_2100_standardized_10s.csv
# Copied: filtered_261004881_20240522_2100-20240522_2115_standardized_10s.csv
# Copied: filtered_261004881_20240522_2115-20240522_2130_standardized_10s.csv
# Copied: filtered_261004881_20240522_2200-20240522_2215_standardized_10s.csv
# Copied: filtered_261004881_20240522_2215-20240522_2230_standardized_10s.csv
# Copied: filtered_261004881_20240522_2230-20240522_2245_standardized_10s.csv
# Copied: filtered_261004881_20240522_2245-20240522_2300_standardized_10s.csv
# Copied: filtered_261004881_20240522_2300-20240522_2315_standardized_10s.csv
# Copied: filtered_261004881_20240522_2315-20240522_2330_standardized_10s.csv
# Copied: filtered_261004881_20240522_2330-20240522_2345_standardized_10s.csv
# Copied: filtered_261004881_20240523_0000-20240523_0015_standardized_10s.csv
# Copied: filtered_261004881_20240523_0015-20240523_0030_standardized_10s.csv
# Copied: filtered_261004881_20240523_0045-20240523_0100_standardized_10s.csv
# Copied: filtered_261004881_20240523_0100-20240523_0115_standardized_10s.csv
# Copied: filtered_261004881_20240523_0145-20240523_0200_standardized_10s.csv
# Copied: filtered_261004881_20240523_0200-20240523_0215_standardized_10s.csv
# Copied: filtered_261004881_20240523_0215-20240523_0230_standardized_10s.csv
# Copied: filtered_261004881_20240523_0230-20240523_0245_standardized_10s.csv
# Copied: filtered_261004881_20240523_0245-20240523_0300_standardized_10s.csv
# Copied: filtered_261004881_20240523_0300-20240523_0315_standardized_10s.csv
# Copied: filtered_261004881_20240523_0330-20240523_0345_standardized_10s.csv
# Copied: filtered_261004881_20240523_0345-20240523_0400_standardized_10s.csv
# Copied: filtered_261004881_20240523_0430-20240523_0445_standardized_10s.csv
# Copied: filtered_261004881_20240523_0500-20240523_0515_standardized_10s.csv
# Copied: filtered_261004881_20240523_0515-20240523_0530_standardized_10s.csv
# Copied: filtered_261004881_20240523_0600-20240523_0615_standardized_10s.csv
# Copied: filtered_261004881_20240523_0615-20240523_0630_standardized_10s.csv
# Copied: filtered_261004881_20240523_0630-20240523_0645_standardized_10s.csv
# Copied: filtered_261004881_20240523_0715-20240523_0730_standardized_10s.csv
# Copied: filtered_261004881_20240523_0745-20240523_0800_standardized_10s.csv
# Copied: filtered_261004881_20240523_0800-20240523_0815_standardized_10s.csv
# Copied: filtered_261004881_20240523_1000-20240523_1015_standardized_10s.csv
# Copied: filtered_261004881_20240523_1015-20240523_1030_standardized_10s.csv
# Copied: filtered_261004881_20240523_1030-20240523_1045_standardized_10s.csv
# Copied: filtered_261004881_20240523_1215-20240523_1230_standardized_10s.csv
# Copied: filtered_261004881_20240523_1330-20240523_1345_standardized_10s.csv
# Copied: filtered_261004881_20240523_1345-20240523_1400_standardized_10s.csv
# Copied: filtered_261004881_20240523_1400-20240523_1415_standardized_10s.csv
# Copied: filtered_261004881_20240523_1500-20240523_1515_standardized_10s.csv
# Copied: filtered_261004881_20240523_1515-20240523_1530_standardized_10s.csv
# Copied: filtered_261004881_20240523_1645-20240523_1700_standardized_10s.csv
# Copied: filtered_261004881_20240523_1700-20240523_1715_standardized_10s.csv
# Copied: filtered_261004881_20240523_1800-20240523_1815_standardized_10s.csv
# Copied: filtered_261004881_20240523_1830-20240523_1845_standardized_10s.csv
# Copied: filtered_261004881_20240523_1930-20240523_1945_standardized_10s.csv
# Copied: filtered_261004881_20240523_1945-20240523_2000_standardized_10s.csv
# Copied: filtered_261004881_20240523_2000-20240523_2015_standardized_10s.csv
# Copied: filtered_261004881_20240523_2015-20240523_2030_standardized_10s.csv
# Copied: filtered_261004881_20240523_2030-20240523_2045_standardized_10s.csv
# Copied: filtered_261004881_20240524_0445-20240524_0500_standardized_10s.csv
# Copied: filtered_261004881_20240524_0600-20240524_0615_standardized_10s.csv
# Copied: filtered_261004881_20240524_0615-20240524_0630_standardized_10s.csv
# Copied: filtered_261004881_20240524_0630-20240524_0645_standardized_10s.csv
# Copied: filtered_261004881_20240524_0730-20240524_0745_standardized_10s.csv
# Copied: filtered_261004881_20240524_0800-20240524_0815_standardized_10s.csv
# Copied: filtered_261004881_20240524_0830-20240524_0845_standardized_10s.csv
# Copied: filtered_261004881_20240524_0845-20240524_0900_standardized_10s.csv
# Copied: filtered_261004881_20240524_0915-20240524_0930_standardized_10s.csv
# Copied: filtered_261004881_20240524_0930-20240524_0945_standardized_10s.csv
# Copied: filtered_261004881_20240524_1100-20240524_1115_standardized_10s.csv
# Copied: filtered_261004881_20240524_1130-20240524_1145_standardized_10s.csv
# Copied: filtered_261004881_20240524_1245-20240524_1300_standardized_10s.csv
# Copied: filtered_261004881_20240524_1445-20240524_1500_standardized_10s.csv
# Copied: filtered_261004881_20240524_1500-20240524_1515_standardized_10s.csv
# Copied: filtered_261004881_20240524_1515-20240524_1530_standardized_10s.csv
# Copied: filtered_261004881_20240524_1615-20240524_1630_standardized_10s.csv
# Copied: filtered_261004881_20240524_1645-20240524_1700_standardized_10s.csv
# Copied: filtered_261004881_20240524_1715-20240524_1730_standardized_10s.csv
# Copied: filtered_261004881_20240524_1745-20240524_1800_standardized_10s.csv
# Copied: filtered_261004881_20240524_1800-20240524_1815_standardized_10s.csv
# Copied: filtered_261004881_20240524_1830-20240524_1845_standardized_10s.csv
# Copied: filtered_261004881_20240524_1845-20240524_1900_standardized_10s.csv
# Copied: filtered_261004881_20240524_1900-20240524_1915_standardized_10s.csv
# Copied: filtered_261004881_20240524_1915-20240524_1930_standardized_10s.csv
# Copied: filtered_261004881_20240524_1930-20240524_1945_standardized_10s.csv
# Copied: filtered_261004881_20240524_1945-20240524_2000_standardized_10s.csv
# Copied: filtered_261004881_20240524_2000-20240524_2015_standardized_10s.csv
# Copied: filtered_261004881_20240524_2015-20240524_2030_standardized_10s.csv
# Copied: filtered_261004881_20240524_2115-20240524_2130_standardized_10s.csv
# Copied: filtered_261004881_20240524_2215-20240524_2230_standardized_10s.csv
# Copied: filtered_261004881_20240524_2230-20240524_2245_standardized_10s.csv
# Copied: filtered_261004881_20240525_0015-20240525_0029_standardized_10s.csv
# Copied: filtered_261004881_20240525_0045-20240525_0100_standardized_10s.csv
# Copied: filtered_261004881_20240525_0115-20240525_0129_standardized_10s.csv
# Copied: filtered_261004881_20240525_0130-20240525_0145_standardized_10s.csv
# Copied: filtered_261004881_20240525_0230-20240525_0244_standardized_10s.csv
# Copied: filtered_261004881_20240525_0300-20240525_0315_standardized_10s.csv
# Copied: filtered_261004881_20240525_0330-20240525_0345_standardized_10s.csv
# Copied: filtered_261004881_20240525_0400-20240525_0415_standardized_10s.csv
# Copied: filtered_261004881_20240525_0430-20240525_0444_standardized_10s.csv
# Copied: filtered_261004881_20240525_0445-20240525_0459_standardized_10s.csv
# Copied: filtered_261004881_20240525_0500-20240525_0514_standardized_10s.csv
# Copied: filtered_261004881_20240525_0515-20240525_0529_standardized_10s.csv
# Copied: filtered_261004881_20240525_0545-20240525_0600_standardized_10s.csv
# Copied: filtered_261004881_20240525_0600-20240525_0614_standardized_10s.csv
# Copied: filtered_261004881_20240525_0615-20240525_0629_standardized_10s.csv
# Copied: filtered_261004881_20240525_0730-20240525_0745_standardized_10s.csv
# Copied: filtered_261004881_20240525_0800-20240525_0814_standardized_10s.csv
# Copied: filtered_261004881_20240525_0815-20240525_0829_standardized_10s.csv
# Copied: filtered_261004881_20240525_0830-20240525_0845_standardized_10s.csv
# Copied: filtered_261004881_20240525_0900-20240525_0914_standardized_10s.csv
# Copied: filtered_261004881_20240525_1000-20240525_1015_standardized_10s.csv
# Copied: filtered_261004881_20240525_1045-20240525_1059_standardized_10s.csv
# Copied: filtered_261004881_20240525_1100-20240525_1115_standardized_10s.csv
# Copied: filtered_261004881_20240525_1145-20240525_1200_standardized_10s.csv
# Copied: filtered_261004881_20240525_1215-20240525_1229_standardized_10s.csv
# Copied: filtered_261004881_20240525_1230-20240525_1244_standardized_10s.csv
# Copied: filtered_261004881_20240525_1300-20240525_1314_standardized_10s.csv
# Copied: filtered_261004881_20240525_1315-20240525_1329_standardized_10s.csv
# Copied: filtered_261004881_20240525_1400-20240525_1414_standardized_10s.csv
# Copied: filtered_261004881_20240525_1415-20240525_1430_standardized_10s.csv
# Copied: filtered_261004881_20240525_1500-20240525_1515_standardized_10s.csv
# Copied: filtered_261004881_20240525_1530-20240525_1544_standardized_10s.csv
# Copied: filtered_261004881_20240525_1545-20240525_1559_standardized_10s.csv
# Copied: filtered_261004881_20240525_1600-20240525_1614_standardized_10s.csv
# Copied: filtered_261004881_20240525_1615-20240525_1629_standardized_10s.csv
# Copied: filtered_261004881_20240525_1700-20240525_1714_standardized_10s.csv
# Copied: filtered_261004881_20240525_1800-20240525_1814_standardized_10s.csv
# Copied: filtered_261004881_20240525_1815-20240525_1829_standardized_10s.csv
# Copied: filtered_261004881_20240525_2000-20240525_2015_standardized_10s.csv
# Copied: filtered_261004881_20240525_2030-20240525_2045_standardized_10s.csv
# Copied: filtered_261004881_20240525_2100-20240525_2114_standardized_10s.csv
# Copied: filtered_261004881_20240525_2145-20240525_2200_standardized_10s.csv
# Copied: filtered_261004881_20240525_2345-20240525_2359_standardized_10s.csv
# Copied: filtered_261004881_20240526_0000-20240526_0014_standardized_10s.csv
# Copied: filtered_261004881_20240526_0215-20240526_0230_standardized_10s.csv
# Copied: filtered_261004881_20240526_0415-20240526_0429_standardized_10s.csv
# Copied: filtered_261004881_20240526_0430-20240526_0444_standardized_10s.csv
# Copied: filtered_261004881_20240526_0445-20240526_0459_standardized_10s.csv
# Copied: filtered_261004881_20240526_0500-20240526_0515_standardized_10s.csv
# Copied: filtered_261004881_20240526_0630-20240526_0644_standardized_10s.csv
# Copied: filtered_261004881_20240526_0700-20240526_0714_standardized_10s.csv
# Copied: filtered_261004881_20240526_0800-20240526_0814_standardized_10s.csv
# Copied: filtered_261004881_20240526_0815-20240526_0830_standardized_10s.csv
# Copied: filtered_261004881_20240526_0915-20240526_0929_standardized_10s.csv
# Copied: filtered_261004881_20240526_0945-20240526_0959_standardized_10s.csv
# Copied: filtered_261004881_20240526_1015-20240526_1029_standardized_10s.csv
# Copied: filtered_261004881_20240526_1030-20240526_1045_standardized_10s.csv
# Copied: filtered_261004881_20240526_1100-20240526_1115_standardized_10s.csv
# Copied: filtered_261004881_20240526_1315-20240526_1329_standardized_10s.csv
# Copied: filtered_261004881_20240526_1415-20240526_1429_standardized_10s.csv
# Copied: filtered_261004881_20240526_1430-20240526_1444_standardized_10s.csv
# Copied: filtered_261004881_20240526_1500-20240526_1514_standardized_10s.csv
# Copied: filtered_261004881_20240526_1545-20240526_1559_standardized_10s.csv
# Copied: filtered_261004881_20240526_1600-20240526_1614_standardized_10s.csv
# Copied: filtered_261004881_20240526_1615-20240526_1630_standardized_10s.csv
# Copied: filtered_261004881_20240526_1630-20240526_1645_standardized_10s.csv
# Copied: filtered_261004881_20240526_1715-20240526_1729_standardized_10s.csv
# Copied: filtered_261004881_20240526_1730-20240526_1744_standardized_10s.csv
# Copied: filtered_261004881_20240526_1745-20240526_1759_standardized_10s.csv
# Copied: filtered_261004881_20240526_1800-20240526_1814_standardized_10s.csv
# Copied: filtered_261004881_20240526_1815-20240526_1829_standardized_10s.csv
# Copied: filtered_261004881_20240526_1845-20240526_1859_standardized_10s.csv
# Copied: filtered_261004881_20240526_1900-20240526_1915_standardized_10s.csv
# Copied: filtered_261004881_20240526_1930-20240526_1944_standardized_10s.csv
# Copied: filtered_261004881_20240526_1945-20240526_1959_standardized_10s.csv
# Copied: filtered_261004881_20240526_2000-20240526_2014_standardized_10s.csv
# Copied: filtered_261004881_20240526_2015-20240526_2030_standardized_10s.csv
# Copied: filtered_261004881_20240526_2045-20240526_2100_standardized_10s.csv
# Copied: filtered_261004881_20240526_2115-20240526_2129_standardized_10s.csv
# Copied: filtered_261004881_20240526_2200-20240526_2214_standardized_10s.csv
# Copied: filtered_261004881_20240530_0400-20240530_0414_standardized_10s.csv
# Copied: filtered_261004881_20240530_0415-20240530_0430_standardized_10s.csv
# Copied: filtered_261004881_20240530_0500-20240530_0515_standardized_10s.csv
# Copied: filtered_261004881_20240530_0530-20240530_0545_standardized_10s.csv
# Copied: filtered_261004881_20240530_0615-20240530_0630_standardized_10s.csv
# Copied: filtered_261004881_20240530_0645-20240530_0659_standardized_10s.csv
# Copied: filtered_261004881_20240530_0715-20240530_0730_standardized_10s.csv
# Copied: filtered_261004881_20240530_0730-20240530_0745_standardized_10s.csv
# Copied: filtered_261004881_20240530_0815-20240530_0830_standardized_10s.csv
# Copied: filtered_261004881_20240530_0830-20240530_0844_standardized_10s.csv
# Copied: filtered_261004881_20240530_0845-20240530_0900_standardized_10s.csv
# Copied: filtered_261004881_20240530_0915-20240530_0930_standardized_10s.csv
# Copied: filtered_261004881_20240530_0945-20240530_1000_standardized_10s.csv
# Copied: filtered_261004881_20240530_1030-20240530_1044_standardized_10s.csv
# Copied: filtered_261004881_20240530_1045-20240530_1059_standardized_10s.csv
# Copied: filtered_261004881_20240530_1115-20240530_1130_standardized_10s.csv
# Copied: filtered_261004881_20240530_1130-20240530_1145_standardized_10s.csv
# Copied: filtered_261004881_20240530_1215-20240530_1230_standardized_10s.csv
# Copied: filtered_261004881_20240530_1400-20240530_1414_standardized_10s.csv
# Copied: filtered_261004881_20240530_1515-20240530_1529_standardized_10s.csv
# Copied: filtered_261004881_20240530_1530-20240530_1545_standardized_10s.csv
# Copied: filtered_261004881_20240530_1745-20240530_1759_standardized_10s.csv
# Copied: filtered_261004881_20240530_1900-20240530_1915_standardized_10s.csv
# Copied: filtered_261004881_20240530_1945-20240530_2000_standardized_10s.csv
# Copied: filtered_261004881_20240530_2015-20240530_2030_standardized_10s.csv
# Copied: filtered_261004881_20240530_2045-20240530_2059_standardized_10s.csv
# Copied: filtered_261004881_20240530_2130-20240530_2144_standardized_10s.csv
# Copied: filtered_261004881_20240530_2200-20240530_2215_standardized_10s.csv
# Copied: filtered_261004881_20240530_2230-20240530_2244_standardized_10s.csv
# Copied: filtered_261004881_20240530_2315-20240530_2329_standardized_10s.csv
# Copied: filtered_261004881_20240530_2330-20240530_2344_standardized_10s.csv
# Script execution completed.

# %% [markdown]
# ## Model Script

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# Paths to the folders
folder_underway = "./input/underway_using_engine"
folder_fishing = "./input/engaged_in_fishing"

# Parameters
sequence_length = 60  # Length of time sequences (e.g., 1 hour if sampled every minute)
features = ['SOG', 'COG', 'Heading']  # Columns to use as features

# Function to load and preprocess data
def load_and_preprocess_data(folder, label, sequence_length, features):
    data = []
    labels = []
    file_origins = []
    for file in os.listdir(folder):
        if file.endswith('.csv'):
            df = pd.read_csv(os.path.join(folder, file))
            # Normalize SOG
            scaler = MinMaxScaler()
            df['SOG'] = scaler.fit_transform(df[['SOG']])
            
            # Encode COG and Heading cyclically
            df['COG_x'] = np.sin(np.radians(df['COG']))
            df['COG_y'] = np.cos(np.radians(df['COG']))
            df['Heading_x'] = np.sin(np.radians(df['Heading']))
            df['Heading_y'] = np.cos(np.radians(df['Heading']))
            
            # Select features
            feature_columns = ['SOG', 'COG_x', 'COG_y', 'Heading_x', 'Heading_y']
            df = df[feature_columns]
            
            # Create sequences
            for i in range(len(df) - sequence_length + 1):
                sequence = df.iloc[i:i + sequence_length].values
                data.append(sequence)
                labels.append(label)
                file_origins.append(file)  # Track the file name for this sequence
    return np.array(data), np.array(labels), np.array(file_origins)

# Load data from both folders
data_underway, labels_underway, files_underway = load_and_preprocess_data(folder_underway, 0, sequence_length, features)
data_fishing, labels_fishing, files_fishing = load_and_preprocess_data(folder_fishing, 1, sequence_length, features)

# Combine data
X = np.concatenate([data_underway, data_fishing], axis=0)
y = np.concatenate([labels_underway, labels_fishing], axis=0)
file_origins = np.concatenate([files_underway, files_fishing], axis=0)

# Train-test split (include file origins)
X_train, X_test, y_train, y_test, files_train, files_test = train_test_split(
    X, y, file_origins, test_size=0.2, random_state=42, stratify=y
)

# Build the LSTM model
model = Sequential([
    LSTM(64, input_shape=(sequence_length, X.shape[2]), return_sequences=True),
    Dropout(0.3),
    LSTM(32),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {accuracy:.2f}")

# Predict probabilities and binary labels
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype('int')

# Store results in a DataFrame
results = pd.DataFrame({
    'file': files_test,
    'true_label': y_test,
    'predicted_label': y_pred.flatten()
})

# Add a column for misclassification
results['misclassified'] = results['true_label'] != results['predicted_label']

# Group by file and count misclassifications
misclassified_summary = results.groupby('file')['misclassified'].sum().reset_index()
misclassified_summary = misclassified_summary.sort_values(by='misclassified', ascending=False)

# Display files with the most misclassifications
print("Files with the most misclassified sequences:")
print(misclassified_summary.head(10))

# Save misclassification summary to a CSV file
misclassified_summary.to_csv('misclassified_summary.csv', index=False)

# Plot Learning Curves
def plot_learning_curve(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# ROC Curve
def plot_roc_curve(y_true, y_pred_prob):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='b', label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.title('Receiver Operating Characteristic Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show()

# Confusion Matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Underway', 'Fishing'], yticklabels=['Underway', 'Fishing'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# Print Classification Report
def print_classification_report(y_true, y_pred):
    print(classification_report(y_true, y_pred))

# Visualizations and Metrics
plot_learning_curve(history)
plot_roc_curve(y_test, y_pred_prob)
plot_confusion_matrix(y_test, y_pred)
print_classification_report(y_test, y_pred)
# Out:
# Epoch 1/200
# 5990/5990 [==============================] - 71s 10ms/step - loss: 0.6357 - accuracy: 0.6342 - val_loss: 0.6171 - val_accuracy: 0.6522
# Epoch 2/200
# 5990/5990 [==============================] - 61s 10ms/step - loss: 0.6076 - accuracy: 0.6621 - val_loss: 0.5899 - val_accuracy: 0.6822
# Epoch 3/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.5877 - accuracy: 0.6811 - val_loss: 0.5755 - val_accuracy: 0.6936
# Epoch 4/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.5661 - accuracy: 0.6951 - val_loss: 0.5620 - val_accuracy: 0.6981
# Epoch 5/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.5499 - accuracy: 0.7032 - val_loss: 0.5410 - val_accuracy: 0.7126
# Epoch 6/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.5302 - accuracy: 0.7164 - val_loss: 0.5266 - val_accuracy: 0.7205
# Epoch 7/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.5137 - accuracy: 0.7256 - val_loss: 0.4987 - val_accuracy: 0.7351
# Epoch 8/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.4994 - accuracy: 0.7352 - val_loss: 0.4880 - val_accuracy: 0.7389
# Epoch 9/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.4904 - accuracy: 0.7408 - val_loss: 0.4885 - val_accuracy: 0.7392
# Epoch 10/200
# 5990/5990 [==============================] - 58s 10ms/step - loss: 0.4764 - accuracy: 0.7488 - val_loss: 0.4646 - val_accuracy: 0.7575
# Epoch 11/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.4652 - accuracy: 0.7576 - val_loss: 0.4545 - val_accuracy: 0.7651
# Epoch 12/200
# 5990/5990 [==============================] - 60s 10ms/step - loss: 0.4534 - accuracy: 0.7656 - val_loss: 0.4326 - val_accuracy: 0.7759
# Epoch 13/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.4455 - accuracy: 0.7709 - val_loss: 0.4264 - val_accuracy: 0.7838
# Epoch 14/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.4310 - accuracy: 0.7795 - val_loss: 0.4300 - val_accuracy: 0.7832
# Epoch 15/200
# 5990/5990 [==============================] - 58s 10ms/step - loss: 0.4248 - accuracy: 0.7858 - val_loss: 0.4052 - val_accuracy: 0.7977
# Epoch 16/200
# 5990/5990 [==============================] - 59s 10ms/step - loss: 0.4084 - accuracy: 0.7943 - val_loss: 0.4014 - val_accuracy: 0.8000
# Epoch 130/200
# 5990/5990 [==============================] - 61s 10ms/step - loss: 0.0894 - accuracy: 0.9674 - val_loss: 0.0837 - val_accuracy: 0.9710
# Test Accuracy: 0.97
# 1872/1872 [==============================] - 8s 4ms/step
# Files with the most misclassified sequences:
#                                                    file  misclassified
# 6474  filtered_220368000_20240523_0126-20240523_0141...             11
# 1413  filtered_219014012_20240525_1142-20240525_1157...             10
# 1685  filtered_219014851_20240527_0527-20240527_0542...              9
# 9449  filtered_314525000_20241124_1347-20241124_1401...              9
# 4631  filtered_219793000_20240530_2014-20240530_2028...              9
# 2271  filtered_219017895_20240528_2230-20240528_2244...              9
# 1283  filtered_219013178_20240529_0715-20240529_0729...              9
# 2279  filtered_219017895_20240529_0030-20240529_0044...              8
# 2151  filtered_219017895_20240527_0135-20240527_0150...              8
# 1146  filtered_219013178_20240526_1000-20240526_1015...              8
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     34999
#            1       0.97      0.96      0.97     24900
#
#     accuracy                           0.97     59899
#    macro avg       0.97      0.97      0.97     59899
# weighted avg       0.97      0.97      0.97     59899

# %%
# Save the model
model.save("navigational_status_classifier.h5")

# %% [markdown]
# # Explanation:
#
# ### 1. **Loading CSV Files from the Folder:**
#    - The function loops through the CSV files in the given folder, one by one. It reads each CSV file using `pandas.read_csv()` and processes the data.
#    - These CSV files contain the vessel's movement data with columns like `SOG`, `COG`, and `Heading`.
#
#    **Example of data loaded from a CSV file:**
#
#    | Timestamp | SOG | COG  | Heading |
#    |-----------|-----|------|---------|
#    | 00:00     | 5.4 | 45   | 60      |
#    | 00:01     | 5.6 | 47   | 61      |
#    | 00:02     | 5.7 | 50   | 62      |
#    | ...       | ... | ...  | ...     |
#
#    Here, **SOG** is the speed of the vessel, **COG** is the course (direction), and **Heading** is the heading angle.
#
# ### 2. **Normalization of `SOG` (Speed Over Ground):**
#    - The `SOG` column is normalized using a `MinMaxScaler`, which scales all values to a range between 0 and 1.
#    - **Normalization** is important because it brings different feature scales (e.g., speed vs. angle) to a similar range, making the training process more efficient.
#
#    **Before normalization:**
#
#    | Timestamp | SOG | COG  | Heading |
#    |-----------|-----|------|---------|
#    | 00:00     | 5.4 | 45   | 60      |
#    | 00:01     | 5.6 | 47   | 61      |
#
#    **After normalization:**
#
#    The new values for `SOG` are calculated using:
#    \[
#    \text{Normalized SOG} = \frac{\text{SOG} - \text{min(SOG)}}{\text{max(SOG)} - \text{min(SOG)}}
#    \]
#
#    | Timestamp | Normalized SOG | COG  | Heading |
#    |-----------|----------------|------|---------|
#    | 00:00     | 0.00           | 45   | 60      |
#    | 00:01     | 0.33           | 47   | 61      |
#
# ### 3. **Cyclic Encoding of `COG` and `Heading`:**
#    - Both `COG` (Course Over Ground) and `Heading` are angular values, and as such, they have a **cyclic nature**: 0 degrees is the same as 360 degrees.
#    - To properly handle this, **sine** and **cosine** transformations are applied:
#      \[
#      \text{COG}_x = \sin(\text{COG})
#      \]
#      \[
#      \text{COG}_y = \cos(\text{COG})
#      \]
#      Similarly for `Heading`:
#      \[
#      \text{Heading}_x = \sin(\text{Heading})
#      \]
#      \[
#      \text{Heading}_y = \cos(\text{Heading})
#      \]
#    - These transformations convert the angular values into two components that are easier for the model to learn from and capture cyclic relationships.
#
#    **Example before and after cyclic encoding:**
#
#    - **Before** (COG = 350 degrees, Heading = 10 degrees):
#
#    | Timestamp | COG | Heading |
#    |-----------|-----|---------|
#    | 00:00     | 350 | 10      |
#
#    - **After** (Apply sine and cosine transformations):
#
#    | Timestamp | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|------------|------------|------------|------------|
#    | 00:00     | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#
# ### 4. **Selecting Relevant Features:**
#    - After encoding the `COG` and `Heading`, the relevant features are selected: `SOG`, `COG_x`, `COG_y`, `Heading_x`, and `Heading_y`.
#    - These features represent the vessel's speed and directional information in a form that the LSTM model can process.
#
#    **Features selected for each time step:**
#
#    | Timestamp | Normalized SOG | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|----------------|------------|------------|------------|------------|
#    | 00:00     | 0.00           | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#
# ### 5. **Creating Sequences:**
#    - The LSTM model requires input data in the form of sequences (i.e., multiple time steps). Here, a sliding window approach is used to create sequences of `sequence_length` (e.g., 60 time steps).
#    - For each sequence of 60 time steps, the features for those 60 steps are stacked into a 3D array (time steps, features per time step, and the number of sequences).
#    - This helps the model learn patterns over time (e.g., how the vessel's behavior changes over an hour).
#
#    **Example of sequences:**
#
#    For a sequence length of 3, if the first 3 time steps look like this:
#
#    | Timestamp | Normalized SOG | COG_x      | COG_y      | Heading_x  | Heading_y  |
#    |-----------|----------------|------------|------------|------------|------------|
#    | 00:00     | 0.00           | 0.1745     | 0.9848     | 0.1736     | 0.9848     |
#    | 00:01     | 0.33           | 0.1736     | 0.9848     | 0.1732     | 0.9849     |
#    | 00:02     | 0.50           | 0.1727     | 0.9850     | 0.1725     | 0.9850     |
#
#    The model will receive a sequence of these 3 time steps as input for training.
#
# ### 6. **Labeling the Sequences:**
#    - Each sequence is labeled with a binary value, depending on the activity of the vessel:
#      - **0** for "underway using engine".
#      - **1** for "engaged in fishing".
#    - This label helps the model learn the relationship between the features and the vessel's activity.
#
# ### 7. **Loading and Combining Data:**
#    - The function `load_and_preprocess_data` is called twice, once for the "underway" data and once for the "fishing" data.
#    - After processing, the resulting feature arrays (`data_underway` and `data_fishing`) are concatenated together to form the complete dataset `X`, and their corresponding labels (`labels_underway` and `labels_fishing`) are concatenated to form the labels array `y`.
#
# ### Final Data Structure:
#    After combining the data, you end up with:
#
#    - **X**: A 3D array where each element represents a sequence of features (e.g., 60 time steps × 5 features per step = 300 features per sequence).
#
#    - **y**: A 1D array with binary labels (0 or 1) indicating the vessel activity for each sequence.
#
# ---
#
# ### **Visualization of Sequences:**
#
# Here’s how the sequences would look when plotted for `SOG`, `COG_x`, and `Heading_x` for a few time steps:
#
# #### Example:
#
# - **Sequence Data (3 time steps):**
#
#   - `SOG`: [0.00, 0.33, 0.50]
#   - `COG_x`: [0.1745, 0.1736, 0.1727]
#   - `Heading_x`: [0.1736, 0.1732, 0.1725]

# %%
# Example sequences, like explained above.

import matplotlib.pyplot as plt

time_steps = [0, 1, 2]
SOG = [0.00, 0.33, 0.50]
COG_x = [0.1745, 0.1736, 0.1727]
Heading_x = [0.1736, 0.1732, 0.1725]

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(time_steps, SOG, label="SOG", color="blue")
plt.title("SOG over Time")
plt.xlabel("Time Steps")
plt.ylabel("Normalized SOG")

plt.subplot(1, 3, 2)
plt.plot(time_steps, COG_x, label="COG_x", color="green")
plt.title("COG_x over Time")
plt.xlabel("Time Steps")
plt.ylabel("COG_x")

plt.subplot(1, 3, 3)
plt.plot(time_steps, Heading_x, label="Heading_x", color="red")
plt.title("Heading_x over Time")
plt.xlabel("Time Steps")
plt.ylabel("Heading_x")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sliding Window in Sequence Creation
#
# In the current model setup, the **sliding window** approach is used to create sequences of a fixed length. This means that the **length of each sequence is constant** throughout the model's training process.
#
# ### What is the Sliding Window Approach?
#
# The sliding window technique extracts **overlapping sequences** from the raw time series data. The key idea is that the **window size** (i.e., the number of time steps per sequence) remains constant, and the window "slides" over the data to generate sequences.
#
# ### Key Points:
# 1. **Fixed Sequence Length**:
#    - The length of each sequence remains **constant**. In this case, the sequence length is defined by the `sequence_length` parameter (e.g., 60 time steps).
#    - This means every sequence the model receives has exactly the same number of time steps, no matter where the window starts.
#
# 2. **Sliding Window**:
#    - As the window moves across the dataset, each new sequence will **overlap** with the previous one by all but one time step.
#    - The window shifts one time step at a time, ensuring that each sequence captures information over a fixed duration.
#
# ### Example:
# Let’s assume we have raw data sampled every minute, and we set `sequence_length = 60`, meaning each sequence will consist of 60 time steps. If the raw data is as follows:
#
# | Timestamp | SOG | COG | Heading |
# |-----------|-----|-----|---------|
# | 00:00     | 5.4 | 45  | 60      |
# | 00:01     | 5.6 | 47  | 61      |
# | ...       | ... | ... | ...     |
# | 00:59     | 5.7 | 50  | 62      |
# | 01:00     | 5.8 | 52  | 63      |
#
# Then the sliding window works as follows:
# - **First sequence**: Consists of data from `00:00` to `00:59` (60 time steps).
# - **Second sequence**: Starts at `00:01` and goes to `01:00` (another 60 time steps).
# - **Third sequence**: Starts at `00:02` and goes to `01:01` (another 60 time steps), and so on.
#
# ### Sequence Structure:
# For each sequence, the LSTM model will receive a 3D array with:
# - **Time Steps (e.g., 60)**: The number of time steps per sequence.
# - **Features per Time Step (e.g., 5)**: The number of features recorded for each time step (like `SOG`, `COG_x`, `Heading_x`).
# - **Number of Sequences**: The number of sequences generated from the raw data.
#
# In this case, each sequence consists of **60 time steps**, and the sequence length does not vary.
#
# ### Why Use Sliding Window?
# - **Consistent Length**: Having sequences of a constant length helps the model learn consistent patterns across time.
# - **Temporal Dependencies**: The sliding window captures how the data evolves over time by looking at overlapping segments.
# - **Efficient Training**: The technique allows the model to train on overlapping portions of the data, making better use of available data.
