# %% [markdown]
# now only fish/engine

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Paths
data_folder = "./time_sets_standardized"

# Function to load and process individual vessel data
def load_and_process_vessel_data(folder_path):
    data, labels = [], []
    status_counts = {}

    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(folder_path, file))

            if "Heading" not in df.columns or df["Heading"].isnull().any():
                continue  # Skip files with missing or invalid data
            
            # Extract the time series features
            sog = df["SOG"].values
            cog = df["COG"].values
            heading = df["Heading"].values

            # Adjust COG and Heading by subtracting the initial COG
            initial_cog = cog[0]
            cog = cog - initial_cog
            heading = heading - initial_cog

            # Normalize angles to the range [0, 360) after subtraction
            cog = np.mod(cog, 360)
            heading = np.mod(heading, 360)

            # Cyclical encoding for COG and Heading
            cog_sin = np.sin(np.radians(cog))
            cog_cos = np.cos(np.radians(cog))
            heading_sin = np.sin(np.radians(heading))
            heading_cos = np.cos(np.radians(heading))

            # Extract label
            label = df["Navigational status"].iloc[0]
            if label in ["Under way using engine", "Engaged in fishing"]:
                # Calculate statistics for each feature
                sog_mean = np.mean(sog)
                sog_min = np.min(sog)
                sog_max = np.max(sog)
                sog_std = np.std(sog)
                
                cog_sin_mean = np.mean(cog_sin)
                cog_cos_mean = np.mean(cog_cos)
                heading_sin_mean = np.mean(heading_sin)
                heading_cos_mean = np.mean(heading_cos)
                
                sog_slope = np.polyfit(range(len(sog)), sog, 1)[0]  # Linear fit slope

                # Add to the dataset
                features = [
                    sog_mean, sog_min, sog_max, sog_std, sog_slope,
                    cog_sin_mean, cog_cos_mean,
                    heading_sin_mean, heading_cos_mean
                ]
                
                data.append(features)
                labels.append(label)
                
                if label not in status_counts:
                    status_counts[label] = 0
                status_counts[label] += 1

    return np.array(data), np.array(labels), status_counts

# Load and preprocess data
data, labels, status_counts = load_and_process_vessel_data(data_folder)

# Encode labels (e.g., "Under way using engine" -> 0, "Engaged in fishing" -> 1)
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Print class distribution
print("Class distribution:", dict(zip(label_encoder.classes_, np.bincount(labels))))

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Apply undersampling to balance the classes
def undersample_data(X, y):
    class_0 = X[y == 0]  # Minority class (0)
    class_1 = X[y == 1]  # Majority class (1)
    
    class_1_undersampled = resample(class_1, replace=False, n_samples=len(class_0), random_state=42)
    
    X_balanced = np.vstack((class_0, class_1_undersampled))
    y_balanced = np.hstack((np.zeros(len(class_0)), np.ones(len(class_1_undersampled))))
    
    return X_balanced, y_balanced

X_train_balanced, y_train_balanced = undersample_data(X_train, y_train)

# Standardize the data (normalizing it to have zero mean and unit variance)
scaler = StandardScaler()
X_train_balanced = scaler.fit_transform(X_train_balanced)  # Fit and transform on training data
X_test = scaler.transform(X_test)  # Only transform test data

# Build the model (simplified for brevity)
model = Sequential([
    Dense(128, activation='relu', input_dim=X_train_balanced.shape[1]),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(2, activation='softmax')  # Output layer for binary classification
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_balanced, y_train_balanced, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# Class distribution: {'Engaged in fishing': 4429, 'Under way using engine': 7944}
# Epoch 1/100
# 220/220 [==============================] - 2s 4ms/step - loss: 0.5116 - accuracy: 0.7372 - val_loss: 0.4568 - val_accuracy: 0.7669
# Epoch 2/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4718 - accuracy: 0.7725 - val_loss: 0.4632 - val_accuracy: 0.7677
# Epoch 3/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4584 - accuracy: 0.7804 - val_loss: 0.4477 - val_accuracy: 0.7709
# Epoch 4/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4488 - accuracy: 0.7843 - val_loss: 0.4440 - val_accuracy: 0.7749
# Epoch 5/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4469 - accuracy: 0.7885 - val_loss: 0.4555 - val_accuracy: 0.7717
# Epoch 6/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4411 - accuracy: 0.7918 - val_loss: 0.4352 - val_accuracy: 0.7810
# Epoch 7/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4361 - accuracy: 0.7947 - val_loss: 0.4338 - val_accuracy: 0.7830
# Epoch 8/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4326 - accuracy: 0.7956 - val_loss: 0.4253 - val_accuracy: 0.7846
# Epoch 9/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4277 - accuracy: 0.8005 - val_loss: 0.4228 - val_accuracy: 0.7947
# Epoch 10/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4272 - accuracy: 0.7993 - val_loss: 0.4321 - val_accuracy: 0.7859
# Epoch 11/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4265 - accuracy: 0.7996 - val_loss: 0.4301 - val_accuracy: 0.7875
# Epoch 12/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4207 - accuracy: 0.8042 - val_loss: 0.4237 - val_accuracy: 0.7996
# Epoch 13/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4191 - accuracy: 0.8047 - val_loss: 0.4244 - val_accuracy: 0.7931
# Epoch 14/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4195 - accuracy: 0.8043 - val_loss: 0.4317 - val_accuracy: 0.7964
# Epoch 15/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4189 - accuracy: 0.8020 - val_loss: 0.4239 - val_accuracy: 0.7895
# Epoch 16/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4164 - accuracy: 0.8067 - val_loss: 0.4344 - val_accuracy: 0.7846
# Epoch 17/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4134 - accuracy: 0.8053 - val_loss: 0.4165 - val_accuracy: 0.7907
# Epoch 18/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4133 - accuracy: 0.8056 - val_loss: 0.4287 - val_accuracy: 0.7891
# Epoch 19/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4117 - accuracy: 0.8079 - val_loss: 0.4220 - val_accuracy: 0.7919
# Epoch 20/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4102 - accuracy: 0.8033 - val_loss: 0.4185 - val_accuracy: 0.7976
# Epoch 21/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4069 - accuracy: 0.8131 - val_loss: 0.4121 - val_accuracy: 0.8036
# Epoch 22/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4102 - accuracy: 0.8126 - val_loss: 0.4196 - val_accuracy: 0.7935
# Epoch 23/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4093 - accuracy: 0.8116 - val_loss: 0.4209 - val_accuracy: 0.7911
# Epoch 24/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4071 - accuracy: 0.8124 - val_loss: 0.4163 - val_accuracy: 0.7931
# Epoch 25/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4043 - accuracy: 0.8113 - val_loss: 0.4262 - val_accuracy: 0.7923
# Epoch 26/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4055 - accuracy: 0.8131 - val_loss: 0.4190 - val_accuracy: 0.7960
# Epoch 27/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4037 - accuracy: 0.8123 - val_loss: 0.4211 - val_accuracy: 0.7919
# Epoch 28/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4050 - accuracy: 0.8129 - val_loss: 0.4131 - val_accuracy: 0.7980
# Epoch 29/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4048 - accuracy: 0.8124 - val_loss: 0.4255 - val_accuracy: 0.7960
# Epoch 30/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4008 - accuracy: 0.8140 - val_loss: 0.4275 - val_accuracy: 0.7883
# Epoch 31/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4019 - accuracy: 0.8106 - val_loss: 0.4174 - val_accuracy: 0.7947
# Epoch 32/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4023 - accuracy: 0.8126 - val_loss: 0.4276 - val_accuracy: 0.7956
# Epoch 33/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3985 - accuracy: 0.8117 - val_loss: 0.4272 - val_accuracy: 0.7988
# Epoch 34/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3986 - accuracy: 0.8134 - val_loss: 0.4122 - val_accuracy: 0.8032
# Epoch 35/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3964 - accuracy: 0.8127 - val_loss: 0.4151 - val_accuracy: 0.8028
# Epoch 36/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3998 - accuracy: 0.8147 - val_loss: 0.4149 - val_accuracy: 0.7980
# Epoch 37/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3978 - accuracy: 0.8158 - val_loss: 0.4212 - val_accuracy: 0.7923
# Epoch 38/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3985 - accuracy: 0.8137 - val_loss: 0.4195 - val_accuracy: 0.7960
# Epoch 39/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3957 - accuracy: 0.8171 - val_loss: 0.4173 - val_accuracy: 0.7976
# Epoch 40/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3936 - accuracy: 0.8173 - val_loss: 0.4251 - val_accuracy: 0.7956
# Epoch 41/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3936 - accuracy: 0.8183 - val_loss: 0.4169 - val_accuracy: 0.7943
# Epoch 42/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3984 - accuracy: 0.8166 - val_loss: 0.4105 - val_accuracy: 0.8012
# Epoch 43/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3885 - accuracy: 0.8248 - val_loss: 0.4170 - val_accuracy: 0.7947
# Epoch 44/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3906 - accuracy: 0.8191 - val_loss: 0.4143 - val_accuracy: 0.8036
# Epoch 45/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3884 - accuracy: 0.8198 - val_loss: 0.4194 - val_accuracy: 0.8032
# Epoch 46/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3912 - accuracy: 0.8177 - val_loss: 0.4100 - val_accuracy: 0.8073
# Epoch 47/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3892 - accuracy: 0.8215 - val_loss: 0.4203 - val_accuracy: 0.7996
# Epoch 48/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3924 - accuracy: 0.8161 - val_loss: 0.4053 - val_accuracy: 0.8097
# Epoch 49/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3908 - accuracy: 0.8201 - val_loss: 0.4271 - val_accuracy: 0.8012
# Epoch 50/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3914 - accuracy: 0.8191 - val_loss: 0.4085 - val_accuracy: 0.8089
# Epoch 51/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3885 - accuracy: 0.8245 - val_loss: 0.4058 - val_accuracy: 0.8008
# Epoch 52/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3877 - accuracy: 0.8210 - val_loss: 0.4141 - val_accuracy: 0.8020
# Epoch 53/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3888 - accuracy: 0.8194 - val_loss: 0.4095 - val_accuracy: 0.8000
# Epoch 54/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3860 - accuracy: 0.8220 - val_loss: 0.4052 - val_accuracy: 0.8020
# Epoch 55/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3895 - accuracy: 0.8205 - val_loss: 0.4212 - val_accuracy: 0.8004
# Epoch 56/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3846 - accuracy: 0.8220 - val_loss: 0.4153 - val_accuracy: 0.7980
# Epoch 57/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3872 - accuracy: 0.8225 - val_loss: 0.4008 - val_accuracy: 0.8097
# Epoch 58/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3912 - accuracy: 0.8210 - val_loss: 0.4201 - val_accuracy: 0.8008
# Epoch 59/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3880 - accuracy: 0.8191 - val_loss: 0.4074 - val_accuracy: 0.7996
# Epoch 60/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3861 - accuracy: 0.8214 - val_loss: 0.4024 - val_accuracy: 0.8028
# Epoch 61/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3850 - accuracy: 0.8249 - val_loss: 0.4134 - val_accuracy: 0.7956
# Epoch 62/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3853 - accuracy: 0.8242 - val_loss: 0.4050 - val_accuracy: 0.8057
# Epoch 63/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3861 - accuracy: 0.8237 - val_loss: 0.4181 - val_accuracy: 0.8048
# Epoch 64/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3848 - accuracy: 0.8231 - val_loss: 0.4134 - val_accuracy: 0.7996
# Epoch 65/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3809 - accuracy: 0.8242 - val_loss: 0.4168 - val_accuracy: 0.7984
# Epoch 66/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3792 - accuracy: 0.8249 - val_loss: 0.4066 - val_accuracy: 0.8016
# Epoch 67/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3816 - accuracy: 0.8279 - val_loss: 0.4110 - val_accuracy: 0.8053
# Epoch 68/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3797 - accuracy: 0.8271 - val_loss: 0.4168 - val_accuracy: 0.7968
# Epoch 69/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3827 - accuracy: 0.8212 - val_loss: 0.4125 - val_accuracy: 0.8032
# Epoch 70/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3794 - accuracy: 0.8259 - val_loss: 0.4136 - val_accuracy: 0.8069
# Epoch 71/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3841 - accuracy: 0.8195 - val_loss: 0.4124 - val_accuracy: 0.8012
# Epoch 72/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3807 - accuracy: 0.8222 - val_loss: 0.4128 - val_accuracy: 0.8024
# Epoch 73/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3784 - accuracy: 0.8241 - val_loss: 0.4055 - val_accuracy: 0.8077
# Epoch 74/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3802 - accuracy: 0.8237 - val_loss: 0.4155 - val_accuracy: 0.7988
# Epoch 75/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3831 - accuracy: 0.8235 - val_loss: 0.4204 - val_accuracy: 0.8044
# Epoch 76/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3785 - accuracy: 0.8265 - val_loss: 0.4110 - val_accuracy: 0.8016
# Epoch 77/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3738 - accuracy: 0.8302 - val_loss: 0.4248 - val_accuracy: 0.7931
# Epoch 78/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3788 - accuracy: 0.8257 - val_loss: 0.4113 - val_accuracy: 0.8024
# Epoch 79/100
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3798 - accuracy: 0.8255 - val_loss: 0.4128 - val_accuracy: 0.8008
# Epoch 80/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3770 - accuracy: 0.8237 - val_loss: 0.4171 - val_accuracy: 0.7952
# Epoch 81/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3767 - accuracy: 0.8261 - val_loss: 0.4181 - val_accuracy: 0.8048
# Epoch 82/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3748 - accuracy: 0.8275 - val_loss: 0.4096 - val_accuracy: 0.8044
# Epoch 83/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3792 - accuracy: 0.8224 - val_loss: 0.4053 - val_accuracy: 0.8101
# Epoch 84/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3748 - accuracy: 0.8285 - val_loss: 0.4201 - val_accuracy: 0.7992
# Epoch 85/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3782 - accuracy: 0.8268 - val_loss: 0.4090 - val_accuracy: 0.8097
# Epoch 86/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3726 - accuracy: 0.8323 - val_loss: 0.4209 - val_accuracy: 0.8057
# Epoch 87/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3771 - accuracy: 0.8276 - val_loss: 0.4124 - val_accuracy: 0.8032
# Epoch 88/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3747 - accuracy: 0.8269 - val_loss: 0.4163 - val_accuracy: 0.8085
# Epoch 89/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3714 - accuracy: 0.8309 - val_loss: 0.4226 - val_accuracy: 0.8000
# Epoch 90/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3735 - accuracy: 0.8276 - val_loss: 0.4146 - val_accuracy: 0.8012
# Epoch 91/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3700 - accuracy: 0.8315 - val_loss: 0.4225 - val_accuracy: 0.8040
# Epoch 92/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3765 - accuracy: 0.8271 - val_loss: 0.4122 - val_accuracy: 0.8048
# Epoch 93/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3719 - accuracy: 0.8323 - val_loss: 0.4180 - val_accuracy: 0.8008
# Epoch 94/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3737 - accuracy: 0.8271 - val_loss: 0.4099 - val_accuracy: 0.8044
# Epoch 95/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3712 - accuracy: 0.8301 - val_loss: 0.4147 - val_accuracy: 0.8113
# Epoch 96/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3701 - accuracy: 0.8318 - val_loss: 0.4174 - val_accuracy: 0.8081
# Epoch 97/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3710 - accuracy: 0.8306 - val_loss: 0.4072 - val_accuracy: 0.8093
# Epoch 98/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3723 - accuracy: 0.8284 - val_loss: 0.4102 - val_accuracy: 0.8057
# Epoch 99/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3708 - accuracy: 0.8313 - val_loss: 0.4091 - val_accuracy: 0.8113
# Epoch 100/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3700 - accuracy: 0.8305 - val_loss: 0.4266 - val_accuracy: 0.7980
# 78/78 [==============================] - 0s 2ms/step - loss: 0.4266 - accuracy: 0.7980
# Test Accuracy: 0.80

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
import seaborn as sns

# Train the model (previously fitted)
# history = model.fit(X_train_balanced, y_train_balanced, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Plot the learning curve
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# Predict on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Get the class with the highest probability

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Precision, Recall, F1-Score
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_)
print(report)

# ROC Curve and AUC
y_pred_prob = model.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob[:, 1])  # Only for positive class (class 1)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# Calculate and display accuracy, precision, recall, and F1 score
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes, average=None)
recall = recall_score(y_test, y_pred_classes, average=None)
f1 = f1_score(y_test, y_pred_classes, average=None)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision (Class 0): {precision[0]:.4f}')
print(f'Precision (Class 1): {precision[1]:.4f}')
print(f'Recall (Class 0): {recall[0]:.4f}')
print(f'Recall (Class 1): {recall[1]:.4f}')
print(f'F1-Score (Class 0): {f1[0]:.4f}')
print(f'F1-Score (Class 1): {f1[1]:.4f}')
print("\nClassification Report:\n", report)
print(f'\nAUC: {roc_auc:.4f}')
# Out:
# 78/78 [==============================] - 0s 2ms/step
#                         precision    recall  f1-score   support
#
#     Engaged in fishing       0.67      0.88      0.76       913
# Under way using engine       0.92      0.75      0.82      1562
#
#               accuracy                           0.80      2475
#              macro avg       0.79      0.82      0.79      2475
#           weighted avg       0.83      0.80      0.80      2475
#
# 78/78 [==============================] - 0s 2ms/step
# Accuracy: 0.7980
# Precision (Class 0): 0.6717
# Precision (Class 1): 0.9175
# Recall (Class 0): 0.8850
# Recall (Class 1): 0.7471
# F1-Score (Class 0): 0.7637
# F1-Score (Class 1): 0.8236
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#     Engaged in fishing       0.67      0.88      0.76       913
# Under way using engine       0.92      0.75      0.82      1562
#
#               accuracy                           0.80      2475
#              macro avg       0.79      0.82      0.79      2475
#           weighted avg       0.83      0.80      0.80      2475
#
#
# AUC: 0.8887
