# %% [markdown]
# now only fish/engine

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Paths
data_folder = "./time_sets_standardized"

# Function to load and process individual vessel data
def load_and_process_vessel_data(folder_path):
    data, labels = [], []
    status_counts = {}

    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(folder_path, file))

            if "Heading" not in df.columns or df["Heading"].isnull().any():
                continue  # Skip files with missing or invalid data
            
            # Extract the time series features
            sog = df["SOG"].values
            cog = df["COG"].values
            heading = df["Heading"].values

            # Extract label
            label = df["Navigational status"].iloc[0]
            if label in ["Under way using engine", "Engaged in fishing"]:
                # Calculate statistics for each feature
                sog_mean = np.mean(sog)
                sog_min = np.min(sog)
                sog_max = np.max(sog)
                sog_std = np.std(sog)
                
                cog_mean = np.mean(cog)
                cog_min = np.min(cog)
                cog_max = np.max(cog)
                cog_std = np.std(cog)
                
                heading_mean = np.mean(heading)
                heading_min = np.min(heading)
                heading_max = np.max(heading)
                heading_std = np.std(heading)
                
                # Rate of change (slope) for SOG and COG
                sog_slope = np.polyfit(range(len(sog)), sog, 1)[0]  # Linear fit slope
                cog_slope = np.polyfit(range(len(cog)), cog, 1)[0]  # Linear fit slope

                # Add to the dataset
                features = [
                    sog_mean, sog_min, sog_max, sog_std, sog_slope,
                    cog_mean, cog_min, cog_max, cog_std, cog_slope,
                    heading_mean, heading_min, heading_max, heading_std
                ]
                
                data.append(features)
                labels.append(label)
                
                if label not in status_counts:
                    status_counts[label] = 0
                status_counts[label] += 1

    return np.array(data), np.array(labels), status_counts

# Load and preprocess data
data, labels, status_counts = load_and_process_vessel_data(data_folder)

# Encode labels (e.g., "Under way using engine" -> 0, "Engaged in fishing" -> 1)
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Print class distribution
print("Class distribution:", dict(zip(label_encoder.classes_, np.bincount(labels))))

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Apply undersampling to balance the classes
def undersample_data(X, y):
    class_0 = X[y == 0]  # Minority class (0)
    class_1 = X[y == 1]  # Majority class (1)
    
    class_1_undersampled = resample(class_1, replace=False, n_samples=len(class_0), random_state=42)
    
    X_balanced = np.vstack((class_0, class_1_undersampled))
    y_balanced = np.hstack((np.zeros(len(class_0)), np.ones(len(class_1_undersampled))))
    
    return X_balanced, y_balanced

X_train_balanced, y_train_balanced = undersample_data(X_train, y_train)

# Standardize the data (normalizing it to have zero mean and unit variance)
scaler = StandardScaler()
X_train_balanced = scaler.fit_transform(X_train_balanced)  # Fit and transform on training data
X_test = scaler.transform(X_test)  # Only transform test data

# Build the model (simplified for brevity)
model = Sequential([
    Dense(128, activation='relu', input_dim=X_train_balanced.shape[1]),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(2, activation='softmax')  # Output layer for binary classification
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_balanced, y_train_balanced, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# Class distribution: {'Engaged in fishing': 4429, 'Under way using engine': 7944}
# Epoch 1/100
# 220/220 [==============================] - 2s 4ms/step - loss: 0.5041 - accuracy: 0.7474 - val_loss: 0.4573 - val_accuracy: 0.7681
# Epoch 2/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4566 - accuracy: 0.7848 - val_loss: 0.4302 - val_accuracy: 0.7863
# Epoch 3/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4401 - accuracy: 0.7956 - val_loss: 0.4263 - val_accuracy: 0.7875
# Epoch 4/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4326 - accuracy: 0.7978 - val_loss: 0.4306 - val_accuracy: 0.7834
# Epoch 5/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4264 - accuracy: 0.8032 - val_loss: 0.4246 - val_accuracy: 0.7931
# Epoch 6/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4231 - accuracy: 0.8025 - val_loss: 0.4207 - val_accuracy: 0.7927
# Epoch 7/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4186 - accuracy: 0.8053 - val_loss: 0.4219 - val_accuracy: 0.7964
# Epoch 8/100
# 220/220 [==============================] - 1s 3ms/step - loss: 0.4169 - accuracy: 0.8121 - val_loss: 0.4382 - val_accuracy: 0.7754
# Epoch 9/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4131 - accuracy: 0.8099 - val_loss: 0.4129 - val_accuracy: 0.8040
# Epoch 10/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4105 - accuracy: 0.8123 - val_loss: 0.4239 - val_accuracy: 0.7907
# Epoch 11/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4060 - accuracy: 0.8143 - val_loss: 0.4205 - val_accuracy: 0.7988
# Epoch 12/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4056 - accuracy: 0.8150 - val_loss: 0.4172 - val_accuracy: 0.8004
# Epoch 13/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4031 - accuracy: 0.8158 - val_loss: 0.4078 - val_accuracy: 0.8020
# Epoch 14/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4001 - accuracy: 0.8205 - val_loss: 0.4064 - val_accuracy: 0.8004
# Epoch 15/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3992 - accuracy: 0.8208 - val_loss: 0.4183 - val_accuracy: 0.7927
# Epoch 16/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3942 - accuracy: 0.8228 - val_loss: 0.4265 - val_accuracy: 0.7939
# Epoch 17/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3969 - accuracy: 0.8195 - val_loss: 0.4100 - val_accuracy: 0.7972
# Epoch 18/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3954 - accuracy: 0.8205 - val_loss: 0.4034 - val_accuracy: 0.8048
# Epoch 19/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3917 - accuracy: 0.8248 - val_loss: 0.4243 - val_accuracy: 0.8012
# Epoch 20/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3923 - accuracy: 0.8241 - val_loss: 0.4180 - val_accuracy: 0.7984
# Epoch 21/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3889 - accuracy: 0.8271 - val_loss: 0.4128 - val_accuracy: 0.8012
# Epoch 22/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3851 - accuracy: 0.8294 - val_loss: 0.4151 - val_accuracy: 0.8036
# Epoch 23/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3866 - accuracy: 0.8275 - val_loss: 0.4101 - val_accuracy: 0.8069
# Epoch 24/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3841 - accuracy: 0.8264 - val_loss: 0.4141 - val_accuracy: 0.7996
# Epoch 25/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3813 - accuracy: 0.8279 - val_loss: 0.4134 - val_accuracy: 0.8016
# Epoch 26/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3835 - accuracy: 0.8296 - val_loss: 0.4185 - val_accuracy: 0.8000
# Epoch 27/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3824 - accuracy: 0.8289 - val_loss: 0.4022 - val_accuracy: 0.8081
# Epoch 28/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3771 - accuracy: 0.8278 - val_loss: 0.4244 - val_accuracy: 0.7972
# Epoch 29/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3786 - accuracy: 0.8299 - val_loss: 0.3993 - val_accuracy: 0.8028
# Epoch 30/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3756 - accuracy: 0.8323 - val_loss: 0.4062 - val_accuracy: 0.8085
# Epoch 31/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3724 - accuracy: 0.8348 - val_loss: 0.4246 - val_accuracy: 0.7960
# Epoch 32/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3735 - accuracy: 0.8321 - val_loss: 0.4067 - val_accuracy: 0.8069
# Epoch 33/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3697 - accuracy: 0.8328 - val_loss: 0.4102 - val_accuracy: 0.8065
# Epoch 34/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3692 - accuracy: 0.8355 - val_loss: 0.3996 - val_accuracy: 0.8117
# Epoch 35/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3718 - accuracy: 0.8348 - val_loss: 0.4062 - val_accuracy: 0.8077
# Epoch 36/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3693 - accuracy: 0.8330 - val_loss: 0.4024 - val_accuracy: 0.8117
# Epoch 37/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3648 - accuracy: 0.8400 - val_loss: 0.4028 - val_accuracy: 0.8089
# Epoch 38/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3667 - accuracy: 0.8369 - val_loss: 0.4085 - val_accuracy: 0.8048
# Epoch 39/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3609 - accuracy: 0.8414 - val_loss: 0.4124 - val_accuracy: 0.8073
# Epoch 40/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3648 - accuracy: 0.8386 - val_loss: 0.3994 - val_accuracy: 0.8105
# Epoch 41/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3634 - accuracy: 0.8385 - val_loss: 0.3977 - val_accuracy: 0.8133
# Epoch 42/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3636 - accuracy: 0.8375 - val_loss: 0.3987 - val_accuracy: 0.8145
# Epoch 43/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3617 - accuracy: 0.8406 - val_loss: 0.4052 - val_accuracy: 0.8170
# Epoch 44/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3641 - accuracy: 0.8402 - val_loss: 0.3994 - val_accuracy: 0.8093
# Epoch 45/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3635 - accuracy: 0.8410 - val_loss: 0.3932 - val_accuracy: 0.8137
# Epoch 46/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3571 - accuracy: 0.8443 - val_loss: 0.4011 - val_accuracy: 0.8154
# Epoch 47/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3608 - accuracy: 0.8397 - val_loss: 0.4038 - val_accuracy: 0.8105
# Epoch 48/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3555 - accuracy: 0.8443 - val_loss: 0.3916 - val_accuracy: 0.8174
# Epoch 49/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3585 - accuracy: 0.8424 - val_loss: 0.3932 - val_accuracy: 0.8145
# Epoch 50/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3553 - accuracy: 0.8406 - val_loss: 0.4022 - val_accuracy: 0.8117
# Epoch 51/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3552 - accuracy: 0.8450 - val_loss: 0.3953 - val_accuracy: 0.8210
# Epoch 52/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3539 - accuracy: 0.8419 - val_loss: 0.4015 - val_accuracy: 0.8121
# Epoch 53/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3572 - accuracy: 0.8414 - val_loss: 0.3969 - val_accuracy: 0.8149
# Epoch 54/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3543 - accuracy: 0.8437 - val_loss: 0.4157 - val_accuracy: 0.8137
# Epoch 55/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3529 - accuracy: 0.8458 - val_loss: 0.4060 - val_accuracy: 0.8141
# Epoch 56/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3513 - accuracy: 0.8470 - val_loss: 0.4071 - val_accuracy: 0.8162
# Epoch 57/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3510 - accuracy: 0.8467 - val_loss: 0.3998 - val_accuracy: 0.8166
# Epoch 58/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3496 - accuracy: 0.8481 - val_loss: 0.4062 - val_accuracy: 0.8133
# Epoch 59/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3528 - accuracy: 0.8447 - val_loss: 0.4053 - val_accuracy: 0.8149
# Epoch 60/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3516 - accuracy: 0.8461 - val_loss: 0.4002 - val_accuracy: 0.8170
# Epoch 61/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3454 - accuracy: 0.8511 - val_loss: 0.3830 - val_accuracy: 0.8275
# Epoch 62/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3465 - accuracy: 0.8466 - val_loss: 0.3984 - val_accuracy: 0.8186
# Epoch 63/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3528 - accuracy: 0.8454 - val_loss: 0.3992 - val_accuracy: 0.8190
# Epoch 64/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3447 - accuracy: 0.8481 - val_loss: 0.3943 - val_accuracy: 0.8198
# Epoch 65/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3487 - accuracy: 0.8485 - val_loss: 0.3907 - val_accuracy: 0.8246
# Epoch 66/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3438 - accuracy: 0.8497 - val_loss: 0.4089 - val_accuracy: 0.8097
# Epoch 67/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3444 - accuracy: 0.8456 - val_loss: 0.3905 - val_accuracy: 0.8182
# Epoch 68/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3447 - accuracy: 0.8507 - val_loss: 0.3906 - val_accuracy: 0.8206
# Epoch 69/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3433 - accuracy: 0.8542 - val_loss: 0.3966 - val_accuracy: 0.8234
# Epoch 70/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3423 - accuracy: 0.8501 - val_loss: 0.3920 - val_accuracy: 0.8202
# Epoch 71/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3422 - accuracy: 0.8510 - val_loss: 0.3987 - val_accuracy: 0.8222
# Epoch 72/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3438 - accuracy: 0.8521 - val_loss: 0.3869 - val_accuracy: 0.8255
# Epoch 73/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3378 - accuracy: 0.8491 - val_loss: 0.3937 - val_accuracy: 0.8206
# Epoch 74/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3349 - accuracy: 0.8572 - val_loss: 0.4054 - val_accuracy: 0.8154
# Epoch 75/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3372 - accuracy: 0.8545 - val_loss: 0.3903 - val_accuracy: 0.8210
# Epoch 76/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3374 - accuracy: 0.8554 - val_loss: 0.4029 - val_accuracy: 0.8263
# Epoch 77/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3425 - accuracy: 0.8544 - val_loss: 0.3869 - val_accuracy: 0.8214
# Epoch 78/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3406 - accuracy: 0.8504 - val_loss: 0.4093 - val_accuracy: 0.8182
# Epoch 79/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3378 - accuracy: 0.8551 - val_loss: 0.3979 - val_accuracy: 0.8242
# Epoch 80/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3356 - accuracy: 0.8561 - val_loss: 0.3954 - val_accuracy: 0.8234
# Epoch 81/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3383 - accuracy: 0.8547 - val_loss: 0.3881 - val_accuracy: 0.8246
# Epoch 82/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3366 - accuracy: 0.8548 - val_loss: 0.4021 - val_accuracy: 0.8202
# Epoch 83/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3358 - accuracy: 0.8549 - val_loss: 0.3857 - val_accuracy: 0.8283
# Epoch 84/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3324 - accuracy: 0.8567 - val_loss: 0.3864 - val_accuracy: 0.8311
# Epoch 85/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3366 - accuracy: 0.8549 - val_loss: 0.4015 - val_accuracy: 0.8259
# Epoch 86/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3335 - accuracy: 0.8555 - val_loss: 0.3963 - val_accuracy: 0.8222
# Epoch 87/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3294 - accuracy: 0.8599 - val_loss: 0.4132 - val_accuracy: 0.8154
# Epoch 88/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3338 - accuracy: 0.8564 - val_loss: 0.3878 - val_accuracy: 0.8299
# Epoch 89/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3312 - accuracy: 0.8537 - val_loss: 0.3973 - val_accuracy: 0.8246
# Epoch 90/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3308 - accuracy: 0.8554 - val_loss: 0.3997 - val_accuracy: 0.8226
# Epoch 91/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3268 - accuracy: 0.8594 - val_loss: 0.3953 - val_accuracy: 0.8226
# Epoch 92/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3304 - accuracy: 0.8561 - val_loss: 0.3892 - val_accuracy: 0.8299
# Epoch 93/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3350 - accuracy: 0.8541 - val_loss: 0.3905 - val_accuracy: 0.8226
# Epoch 94/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3302 - accuracy: 0.8567 - val_loss: 0.3944 - val_accuracy: 0.8214
# Epoch 95/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3308 - accuracy: 0.8568 - val_loss: 0.4059 - val_accuracy: 0.8174
# Epoch 96/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3235 - accuracy: 0.8572 - val_loss: 0.3940 - val_accuracy: 0.8275
# Epoch 97/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3298 - accuracy: 0.8575 - val_loss: 0.3929 - val_accuracy: 0.8263
# Epoch 98/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3267 - accuracy: 0.8592 - val_loss: 0.3959 - val_accuracy: 0.8279
# Epoch 99/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3275 - accuracy: 0.8591 - val_loss: 0.3950 - val_accuracy: 0.8275
# Epoch 100/100
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3254 - accuracy: 0.8596 - val_loss: 0.3953 - val_accuracy: 0.8303
# 78/78 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8303
# Test Accuracy: 0.83

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
import seaborn as sns

# Train the model (previously fitted)
# history = model.fit(X_train_balanced, y_train_balanced, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Plot the learning curve
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# Predict on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Get the class with the highest probability

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Precision, Recall, F1-Score
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_)
print(report)

# ROC Curve and AUC
y_pred_prob = model.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob[:, 1])  # Only for positive class (class 1)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# Calculate and display accuracy, precision, recall, and F1 score
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes, average=None)
recall = recall_score(y_test, y_pred_classes, average=None)
f1 = f1_score(y_test, y_pred_classes, average=None)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision (Class 0): {precision[0]:.4f}')
print(f'Precision (Class 1): {precision[1]:.4f}')
print(f'Recall (Class 0): {recall[0]:.4f}')
print(f'Recall (Class 1): {recall[1]:.4f}')
print(f'F1-Score (Class 0): {f1[0]:.4f}')
print(f'F1-Score (Class 1): {f1[1]:.4f}')
print("\nClassification Report:\n", report)
print(f'\nAUC: {roc_auc:.4f}')
# Out:
# 78/78 [==============================] - 0s 2ms/step
#                         precision    recall  f1-score   support
#
#     Engaged in fishing       0.71      0.91      0.80       913
# Under way using engine       0.94      0.78      0.85      1562
#
#               accuracy                           0.83      2475
#              macro avg       0.82      0.85      0.83      2475
#           weighted avg       0.85      0.83      0.83      2475
#
# 78/78 [==============================] - 0s 2ms/step
# Accuracy: 0.8303
# Precision (Class 0): 0.7101
# Precision (Class 1): 0.9386
# Recall (Class 0): 0.9124
# Recall (Class 1): 0.7823
# F1-Score (Class 0): 0.7987
# F1-Score (Class 1): 0.8534
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#     Engaged in fishing       0.71      0.91      0.80       913
# Under way using engine       0.94      0.78      0.85      1562
#
#               accuracy                           0.83      2475
#              macro avg       0.82      0.85      0.83      2475
#           weighted avg       0.85      0.83      0.83      2475
#
#
# AUC: 0.9015
