# %% [markdown]
# now only fish/engine

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Paths
data_folder = "./time_sets_standardized"

# Function to load and process individual vessel data
def load_and_process_vessel_data(folder_path):
    data, labels = [], []
    status_counts = {}

    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(folder_path, file))

            if "Heading" not in df.columns or df["Heading"].isnull().any():
                continue  # Skip files with missing or invalid data
            
            # Extract the time series features
            sog = df["SOG"].values
            cog = df["COG"].values
            heading = df["Heading"].values

            # Extract label
            label = df["Navigational status"].iloc[0]
            if label in ["Under way using engine", "Engaged in fishing"]:
                # Calculate statistics for each feature
                sog_mean = np.mean(sog)
                sog_min = np.min(sog)
                sog_max = np.max(sog)
                sog_std = np.std(sog)
                
                cog_mean = np.mean(cog)
                cog_min = np.min(cog)
                cog_max = np.max(cog)
                cog_std = np.std(cog)
                
                heading_mean = np.mean(heading)
                heading_min = np.min(heading)
                heading_max = np.max(heading)
                heading_std = np.std(heading)
                
                # Rate of change (slope) for SOG and COG
                sog_slope = np.polyfit(range(len(sog)), sog, 1)[0]  # Linear fit slope
                cog_slope = np.polyfit(range(len(cog)), cog, 1)[0]  # Linear fit slope

                # Add to the dataset
                features = [
                    sog_mean, sog_min, sog_max, sog_std, sog_slope,
                    cog_mean, cog_min, cog_max, cog_std, cog_slope,
                    heading_mean, heading_min, heading_max, heading_std
                ]
                
                data.append(features)
                labels.append(label)
                
                if label not in status_counts:
                    status_counts[label] = 0
                status_counts[label] += 1

    return np.array(data), np.array(labels), status_counts

# Load and preprocess data
data, labels, status_counts = load_and_process_vessel_data(data_folder)

# Encode labels (e.g., "Under way using engine" -> 0, "Engaged in fishing" -> 1)
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Print class distribution
print("Class distribution:", dict(zip(label_encoder.classes_, np.bincount(labels))))

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Apply undersampling to balance the classes
def undersample_data(X, y):
    class_0 = X[y == 0]  # Minority class (0)
    class_1 = X[y == 1]  # Majority class (1)
    
    class_1_undersampled = resample(class_1, replace=False, n_samples=len(class_0), random_state=42)
    
    X_balanced = np.vstack((class_0, class_1_undersampled))
    y_balanced = np.hstack((np.zeros(len(class_0)), np.ones(len(class_1_undersampled))))
    
    return X_balanced, y_balanced

X_train_balanced, y_train_balanced = undersample_data(X_train, y_train)

# Build the model (simplified for brevity)
model = Sequential([
    Dense(128, activation='relu', input_dim=X_train_balanced.shape[1]),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(2, activation='softmax')  # Output layer for binary classification
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_balanced, y_train_balanced, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 2024-12-26 12:59:51.771188: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-26 12:59:51.772624: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-26 12:59:51.775601: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-26 12:59:51.784299: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735217991.798932   41334 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735217991.803159   41334 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-26 12:59:51.818655: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Class distribution: {np.str_('Engaged in fishing'): np.int64(4429), np.str_('Under way using engine'): np.int64(7944)}
# Epoch 1/100
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-12-26 13:00:13.611844: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5228 - loss: 16.2122 - val_accuracy: 0.5366 - val_loss: 0.7060
# Epoch 2/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5339 - loss: 0.9321 - val_accuracy: 0.3887 - val_loss: 0.7255
# Epoch 3/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5329 - loss: 0.7166 - val_accuracy: 0.4925 - val_loss: 0.6767
# Epoch 4/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5269 - loss: 0.7086 - val_accuracy: 0.6469 - val_loss: 0.6446
# Epoch 5/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5569 - loss: 0.6880 - val_accuracy: 0.4473 - val_loss: 0.6900
# Epoch 6/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5948 - loss: 0.6722 - val_accuracy: 0.6772 - val_loss: 0.6382
# Epoch 7/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5937 - loss: 0.6733 - val_accuracy: 0.7135 - val_loss: 0.5909
# Epoch 8/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6264 - loss: 0.6408 - val_accuracy: 0.6998 - val_loss: 0.5908
# Epoch 9/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6608 - loss: 0.6249 - val_accuracy: 0.7600 - val_loss: 0.5328
# Epoch 10/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6807 - loss: 0.6040 - val_accuracy: 0.7515 - val_loss: 0.5084
# Epoch 11/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7068 - loss: 0.5808 - val_accuracy: 0.7188 - val_loss: 0.5539
# Epoch 12/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7090 - loss: 0.5733 - val_accuracy: 0.7556 - val_loss: 0.4961
# Epoch 13/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7134 - loss: 0.5780 - val_accuracy: 0.7451 - val_loss: 0.5071
# Epoch 14/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7342 - loss: 0.5548 - val_accuracy: 0.7576 - val_loss: 0.4883
# Epoch 15/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7392 - loss: 0.5423 - val_accuracy: 0.7552 - val_loss: 0.4904
# Epoch 16/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7233 - loss: 0.5568 - val_accuracy: 0.7511 - val_loss: 0.4932
# Epoch 17/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7226 - loss: 0.5473 - val_accuracy: 0.7519 - val_loss: 0.4904
# Epoch 18/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7496 - loss: 0.5213 - val_accuracy: 0.7511 - val_loss: 0.5005
# Epoch 19/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7330 - loss: 0.5386 - val_accuracy: 0.7669 - val_loss: 0.4598
# Epoch 20/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7532 - loss: 0.5125 - val_accuracy: 0.7552 - val_loss: 0.4862
# Epoch 21/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7414 - loss: 0.5327 - val_accuracy: 0.7689 - val_loss: 0.4649
# Epoch 22/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7394 - loss: 0.5354 - val_accuracy: 0.7301 - val_loss: 0.5372
# Epoch 23/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7346 - loss: 0.5350 - val_accuracy: 0.7612 - val_loss: 0.4717
# Epoch 24/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7358 - loss: 0.5247 - val_accuracy: 0.7568 - val_loss: 0.4726
# Epoch 25/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7560 - loss: 0.5183 - val_accuracy: 0.7729 - val_loss: 0.4722
# Epoch 26/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7506 - loss: 0.5139 - val_accuracy: 0.7628 - val_loss: 0.4749
# Epoch 27/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7590 - loss: 0.5068 - val_accuracy: 0.7677 - val_loss: 0.4700
# Epoch 28/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7545 - loss: 0.5042 - val_accuracy: 0.7547 - val_loss: 0.4862
# Epoch 29/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7567 - loss: 0.5055 - val_accuracy: 0.7616 - val_loss: 0.4730
# Epoch 30/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7621 - loss: 0.5005 - val_accuracy: 0.7657 - val_loss: 0.4630
# Epoch 31/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7608 - loss: 0.4981 - val_accuracy: 0.7786 - val_loss: 0.4425
# Epoch 32/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7653 - loss: 0.4855 - val_accuracy: 0.7705 - val_loss: 0.4726
# Epoch 33/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7636 - loss: 0.4908 - val_accuracy: 0.7741 - val_loss: 0.4450
# Epoch 34/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7625 - loss: 0.4969 - val_accuracy: 0.7786 - val_loss: 0.4381
# Epoch 35/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7682 - loss: 0.4816 - val_accuracy: 0.7701 - val_loss: 0.4495
# Epoch 36/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7655 - loss: 0.4915 - val_accuracy: 0.7713 - val_loss: 0.4608
# Epoch 37/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7672 - loss: 0.4876 - val_accuracy: 0.7770 - val_loss: 0.4429
# Epoch 38/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7668 - loss: 0.4876 - val_accuracy: 0.7709 - val_loss: 0.4458
# Epoch 39/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7758 - loss: 0.4748 - val_accuracy: 0.7842 - val_loss: 0.4321
# Epoch 40/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7787 - loss: 0.4754 - val_accuracy: 0.7798 - val_loss: 0.4488
# Epoch 41/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7871 - loss: 0.4674 - val_accuracy: 0.7851 - val_loss: 0.4391
# Epoch 42/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7774 - loss: 0.4735 - val_accuracy: 0.7717 - val_loss: 0.4590
# Epoch 43/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7868 - loss: 0.4683 - val_accuracy: 0.7814 - val_loss: 0.4394
# Epoch 44/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7727 - loss: 0.4785 - val_accuracy: 0.7616 - val_loss: 0.4801
# Epoch 45/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8108 - loss: 0.4258 - val_accuracy: 0.8008 - val_loss: 0.4084
# Epoch 82/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7942 - loss: 0.4422 - val_accuracy: 0.8000 - val_loss: 0.4312
# Epoch 83/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8071 - loss: 0.4362 - val_accuracy: 0.8020 - val_loss: 0.4098
# Epoch 84/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7941 - loss: 0.4449 - val_accuracy: 0.7899 - val_loss: 0.4528
# Epoch 85/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8014 - loss: 0.4372 - val_accuracy: 0.8020 - val_loss: 0.4060
# Epoch 86/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8058 - loss: 0.4304 - val_accuracy: 0.8044 - val_loss: 0.4070
# Epoch 87/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7940 - loss: 0.4408 - val_accuracy: 0.7851 - val_loss: 0.4507
# Epoch 88/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8114 - loss: 0.4239 - val_accuracy: 0.8061 - val_loss: 0.4047
# Epoch 89/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8048 - loss: 0.4375 - val_accuracy: 0.7980 - val_loss: 0.4220
# Epoch 90/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8051 - loss: 0.4308 - val_accuracy: 0.7992 - val_loss: 0.4296
# Epoch 91/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8145 - loss: 0.4310 - val_accuracy: 0.7980 - val_loss: 0.4088
# Epoch 92/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8031 - loss: 0.4416 - val_accuracy: 0.7947 - val_loss: 0.4233
# Epoch 93/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8111 - loss: 0.4334 - val_accuracy: 0.7980 - val_loss: 0.4340
# Epoch 94/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8113 - loss: 0.4158 - val_accuracy: 0.7883 - val_loss: 0.4467
# Epoch 95/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8048 - loss: 0.4318 - val_accuracy: 0.7721 - val_loss: 0.4652
# Epoch 96/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7972 - loss: 0.4464 - val_accuracy: 0.7778 - val_loss: 0.4559
# Epoch 97/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7986 - loss: 0.4437 - val_accuracy: 0.8012 - val_loss: 0.4170
# Epoch 98/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8002 - loss: 0.4452 - val_accuracy: 0.8028 - val_loss: 0.4185
# Epoch 99/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8118 - loss: 0.4226 - val_accuracy: 0.7919 - val_loss: 0.4436
# Epoch 100/100
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7969 - loss: 0.4342 - val_accuracy: 0.7952 - val_loss: 0.4243
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7974 - loss: 0.4235
# Test Accuracy: 0.80

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
import seaborn as sns

# Train the model (previously fitted)
# history = model.fit(X_train_balanced, y_train_balanced, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Plot the learning curve
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# Predict on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Get the class with the highest probability

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Precision, Recall, F1-Score
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_)
print(report)

# ROC Curve and AUC
y_pred_prob = model.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob[:, 1])  # Only for positive class (class 1)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# Calculate and display accuracy, precision, recall, and F1 score
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes, average=None)
recall = recall_score(y_test, y_pred_classes, average=None)
f1 = f1_score(y_test, y_pred_classes, average=None)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision (Class 0): {precision[0]:.4f}')
print(f'Precision (Class 1): {precision[1]:.4f}')
print(f'Recall (Class 0): {recall[0]:.4f}')
print(f'Recall (Class 1): {recall[1]:.4f}')
print(f'F1-Score (Class 0): {f1[0]:.4f}')
print(f'F1-Score (Class 1): {f1[1]:.4f}')
print("\nClassification Report:\n", report)
print(f'\nAUC: {roc_auc:.4f}')
# Out:
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#                         precision    recall  f1-score   support
#
#     Engaged in fishing       0.66      0.94      0.77       912
# Under way using engine       0.95      0.71      0.81      1563
#
#               accuracy                           0.80      2475
#              macro avg       0.80      0.82      0.79      2475
#           weighted avg       0.84      0.80      0.80      2475
#
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step
# Accuracy: 0.7952
# Precision (Class 0): 0.6556
# Precision (Class 1): 0.9497
# Recall (Class 0): 0.9353
# Recall (Class 1): 0.7134
# F1-Score (Class 0): 0.7709
# F1-Score (Class 1): 0.8148
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#     Engaged in fishing       0.66      0.94      0.77       912
# Under way using engine       0.95      0.71      0.81      1563
#
#               accuracy                           0.80      2475
#              macro avg       0.80      0.82      0.79      2475
#           weighted avg       0.84      0.80      0.80      2475
#
#
# AUC: 0.8795
