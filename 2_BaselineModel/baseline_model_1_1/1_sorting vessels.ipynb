# %%
import pandas as pd
import os
from tqdm import tqdm  # For progress bars

# Specify the path to the CSV file and the output folder
csv_file_path = './temp_ais_data/aisdk-2024-11-26.csv'
output_folder = 'grouped_files'  # e.g., 'output_files/'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Set the chunk size (e.g., 100,000 rows at a time)
chunk_size = 100000

# Initialize an empty dictionary to accumulate data by MMSI
mmsi_dict = {}

# Get the total number of rows in the CSV to estimate progress
total_rows = sum(1 for _ in open(csv_file_path)) - 1  # Subtract 1 for the header
total_chunks = total_rows // chunk_size + 1  # Number of chunks to process

# Read the file in chunks and process
with tqdm(total=total_chunks, desc="Processing chunks", unit="chunk") as chunk_progress:
    for chunk in pd.read_csv(csv_file_path, chunksize=chunk_size):
        # Filter out rows where 'Navigational status' is 'Unknown value'
        chunk_filtered = chunk[chunk['Navigational status'] != 'Unknown value']
        
        # Group the filtered chunk by MMSI and accumulate in the dictionary
        with tqdm(total=chunk_filtered['MMSI'].nunique(), desc="Processing MMSI", unit="MMSI") as mmsi_progress:
            for mmsi, group in chunk_filtered.groupby('MMSI'):
                if mmsi not in mmsi_dict:
                    mmsi_dict[mmsi] = group
                else:
                    mmsi_dict[mmsi] = pd.concat([mmsi_dict[mmsi], group])
                mmsi_progress.update(1)  # Update the MMSI progress
        chunk_progress.update(1)  # Update the chunk progress

# Now save each MMSI group to a separate CSV file with progress output
with tqdm(total=len(mmsi_dict), desc="Saving MMSI files", unit="file") as save_progress:
    for mmsi, group in mmsi_dict.items():
        output_filename = os.path.join(output_folder, f"mmsi_{mmsi}.csv")
        group.to_csv(output_filename, index=False)
        save_progress.update(1)  # Update progress after saving each file

print("All MMSI files have been saved successfully!")
# Out:
# Processing MMSI: 100%|██████████| 1387/1387 [00:00<00:00, 22755.19MMSI/s]
# Processing MMSI: 100%|██████████| 1395/1395 [00:00<00:00, 1977.10MMSI/s]
# Processing MMSI: 100%|██████████| 1393/1393 [00:00<00:00, 2277.71MMSI/s]
# Processing MMSI: 100%|██████████| 1403/1403 [00:00<00:00, 2085.42MMSI/s]
# Processing MMSI: 100%|██████████| 1405/1405 [00:00<00:00, 2250.50MMSI/s]
# Processing MMSI: 100%|██████████| 1416/1416 [00:00<00:00, 2090.99MMSI/s]
# Processing MMSI: 100%|██████████| 1422/1422 [00:00<00:00, 2068.18MMSI/s]
# Processing MMSI: 100%|██████████| 1410/1410 [00:00<00:00, 1838.76MMSI/s]
# Processing MMSI: 100%|██████████| 1408/1408 [00:00<00:00, 2093.58MMSI/s]
# Processing MMSI: 100%|██████████| 1407/1407 [00:00<00:00, 2032.99MMSI/s]
# Processing MMSI: 100%|██████████| 1420/1420 [00:00<00:00, 1962.69MMSI/s]
# Processing MMSI: 100%|██████████| 1414/1414 [00:00<00:00, 1560.62MMSI/s]
# Processing MMSI: 100%|██████████| 1405/1405 [00:00<00:00, 1677.51MMSI/s]
# Processing MMSI: 100%|██████████| 1411/1411 [00:00<00:00, 1896.71MMSI/s]
# Processing MMSI: 100%|██████████| 1415/1415 [00:00<00:00, 1868.20MMSI/s]
# Processing MMSI: 100%|██████████| 1419/1419 [00:00<00:00, 1777.85MMSI/s]
# Processing MMSI: 100%|██████████| 1415/1415 [00:00<00:00, 1570.93MMSI/s]
# Processing MMSI: 100%|██████████| 1418/1418 [00:00<00:00, 1721.96MMSI/s]
# Processing MMSI: 100%|██████████| 1416/1416 [00:00<00:00, 1765.27MMSI/s]
# Processing MMSI: 100%|██████████| 1419/1419 [00:00<00:00, 1700.51MMSI/s]
# Processing MMSI: 100%|██████████| 1414/1414 [00:00<00:00, 1513.94MMSI/s]
# Processing MMSI: 100%|██████████| 1418/1418 [00:00<00:00, 1488.62MMSI/s]
# Processing MMSI: 100%|██████████| 1415/1415 [00:00<00:00, 1595.78MMSI/s]
# Processing MMSI: 100%|██████████| 1406/1406 [00:00<00:00, 1643.01MMSI/s]
# Processing MMSI: 100%|██████████| 1419/1419 [00:00<00:00, 1488.70MMSI/s]
# Processing MMSI: 100%|██████████| 1415/1415 [00:00<00:00, 1430.08MMSI/s]
# Processing MMSI: 100%|██████████| 1415/1415 [00:00<00:00, 1495.09MMSI/s]
# Processing MMSI: 100%|██████████| 1413/1413 [00:00<00:00, 1547.81MMSI/s]
# Processing MMSI: 100%|██████████| 1407/1407 [00:00<00:00, 1559.39MMSI/s]
# Processing MMSI: 100%|██████████| 1415/1415 [00:01<00:00, 1307.12MMSI/s]
# Processing MMSI: 100%|██████████| 1416/1416 [00:01<00:00, 1382.03MMSI/s]
# Processing MMSI: 100%|██████████| 1417/1417 [00:00<00:00, 1472.27MMSI/s]
# Processing MMSI: 100%|██████████| 1412/1412 [00:00<00:00, 1467.59MMSI/s]
# Processing MMSI: 100%|██████████| 1408/1408 [00:01<00:00, 1293.91MMSI/s]
# Processing MMSI: 100%|██████████| 1410/1410 [00:01<00:00, 1313.65MMSI/s]
# Processing MMSI: 100%|██████████| 1415/1415 [00:00<00:00, 1415.36MMSI/s]
# Processing MMSI: 100%|██████████| 1410/1410 [00:01<00:00, 1380.79MMSI/s]
# Processing MMSI: 100%|██████████| 1418/1418 [00:01<00:00, 1217.47MMSI/s]
# Processing MMSI: 100%|██████████| 1416/1416 [00:01<00:00, 1273.75MMSI/s]
# Processing MMSI: 100%|██████████| 1414/1414 [00:01<00:00, 1356.36MMSI/s]
# Processing MMSI: 100%|██████████| 1418/1418 [00:01<00:00, 1339.45MMSI/s]
# Processing MMSI: 100%|██████████| 1417/1417 [00:01<00:00, 1307.17MMSI/s]
# Processing MMSI: 100%|██████████| 1422/1422 [00:01<00:00, 1113.19MMSI/s]
# Processing MMSI: 100%|██████████| 1418/1418 [00:01<00:00, 1299.96MMSI/s]
# Processing MMSI: 100%|██████████| 1418/1418 [00:01<00:00, 1292.78MMSI/s]
# Processing MMSI: 100%|██████████| 1418/1418 [00:01<00:00, 1159.09MMSI/s]
# Processing MMSI: 100%|██████████| 1420/1420 [00:01<00:00, 1102.80MMSI/s]
# Processing MMSI: 100%|██████████| 1421/1421 [00:01<00:00, 1257.68MMSI/s]
# Processing MMSI: 100%|██████████| 1419/1419 [00:01<00:00, 1223.68MMSI/s]
# Processing MMSI: 100%|██████████| 1405/1405 [00:01<00:00, 1188.62MMSI/s]
# Processing MMSI: 100%|██████████| 1416/1416 [00:01<00:00, 1156.71MMSI/s]
# Processing MMSI: 100%|██████████| 1420/1420 [00:01<00:00, 1111.46MMSI/s]
# Processing MMSI: 100%|██████████| 1426/1426 [00:01<00:00, 1108.43MMSI/s]
# Processing MMSI: 100%|██████████| 1423/1423 [00:01<00:00, 1139.50MMSI/s]
# Processing MMSI: 100%|██████████| 1418/1418 [00:01<00:00, 1144.83MMSI/s]
# Processing MMSI: 100%|██████████| 1421/1421 [00:01<00:00, 1063.31MMSI/s]
# Processing MMSI: 100%|██████████| 1422/1422 [00:01<00:00, 1129.79MMSI/s]
# Processing MMSI: 100%|██████████| 1418/1418 [00:01<00:00, 1087.51MMSI/s]
# Processing MMSI: 100%|██████████| 1419/1419 [00:01<00:00, 1076.90MMSI/s]
# Processing MMSI: 100%|██████████| 1428/1428 [00:01<00:00, 1050.60MMSI/s]
# Processing MMSI: 100%|██████████| 1413/1413 [00:01<00:00, 1013.89MMSI/s]
# Processing MMSI: 100%|██████████| 1414/1414 [00:01<00:00, 1073.11MMSI/s]
# Processing MMSI: 100%|██████████| 1417/1417 [00:01<00:00, 1054.32MMSI/s]
# Processing MMSI: 100%|██████████| 1422/1422 [00:01<00:00, 1080.36MMSI/s]
# Processing MMSI: 100%|██████████| 1407/1407 [00:01<00:00, 955.65MMSI/s]
# Processing MMSI: 100%|██████████| 1410/1410 [00:01<00:00, 979.90MMSI/s]
# Processing MMSI: 100%|██████████| 1408/1408 [00:01<00:00, 1059.00MMSI/s]
# Processing MMSI: 100%|██████████| 1398/1398 [00:01<00:00, 985.22MMSI/s]
# Processing MMSI: 100%|██████████| 1406/1406 [00:01<00:00, 945.22MMSI/s]
# Processing MMSI: 100%|██████████| 1405/1405 [00:01<00:00, 1022.71MMSI/s]
# Processing MMSI: 100%|██████████| 1394/1394 [00:01<00:00, 1000.09MMSI/s]
# Processing MMSI: 100%|██████████| 1400/1400 [00:01<00:00, 930.77MMSI/s]
# Processing MMSI: 100%|██████████| 1405/1405 [00:01<00:00, 1005.91MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:01<00:00, 908.87MMSI/s]
# Processing MMSI: 100%|██████████| 1393/1393 [00:01<00:00, 893.33MMSI/s]
# Processing MMSI: 100%|██████████| 1393/1393 [00:01<00:00, 975.75MMSI/s]
# Processing MMSI: 100%|██████████| 1396/1396 [00:01<00:00, 847.74MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:01<00:00, 829.30MMSI/s]
# Processing MMSI: 100%|██████████| 1396/1396 [00:01<00:00, 964.71MMSI/s]
# Processing MMSI: 100%|██████████| 1389/1389 [00:01<00:00, 931.81MMSI/s]
# Processing MMSI: 100%|██████████| 1391/1391 [00:01<00:00, 903.11MMSI/s]
# Processing MMSI: 100%|██████████| 1395/1395 [00:01<00:00, 937.74MMSI/s]
# Processing MMSI: 100%|██████████| 1387/1387 [00:01<00:00, 817.34MMSI/s]
# Processing MMSI: 100%|██████████| 1387/1387 [00:01<00:00, 872.50MMSI/s]
# Processing MMSI: 100%|██████████| 1383/1383 [00:01<00:00, 916.86MMSI/s]
# Processing MMSI: 100%|██████████| 1390/1390 [00:01<00:00, 895.32MMSI/s]
# Processing MMSI: 100%|██████████| 1380/1380 [00:01<00:00, 810.80MMSI/s]
# Processing MMSI: 100%|██████████| 1384/1384 [00:01<00:00, 887.31MMSI/s]
# Processing MMSI: 100%|██████████| 1381/1381 [00:01<00:00, 810.62MMSI/s]
# Processing MMSI: 100%|██████████| 1391/1391 [00:01<00:00, 895.15MMSI/s]
# Processing MMSI: 100%|██████████| 1405/1405 [00:01<00:00, 859.59MMSI/s]
# Processing MMSI: 100%|██████████| 1396/1396 [00:01<00:00, 770.16MMSI/s]
# Processing MMSI: 100%|██████████| 1386/1386 [00:01<00:00, 860.40MMSI/s]
# Processing MMSI: 100%|██████████| 1388/1388 [00:01<00:00, 784.28MMSI/s]
# Processing MMSI: 100%|██████████| 1381/1381 [00:01<00:00, 812.99MMSI/s]
# Processing MMSI: 100%|██████████| 1390/1390 [00:01<00:00, 774.95MMSI/s]
# Processing MMSI: 100%|██████████| 1386/1386 [00:01<00:00, 825.34MMSI/s]
# Processing MMSI: 100%|██████████| 1394/1394 [00:01<00:00, 807.74MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:01<00:00, 794.50MMSI/s]
# Processing MMSI: 100%|██████████| 1387/1387 [00:01<00:00, 838.00MMSI/s]
# Processing MMSI: 100%|██████████| 1407/1407 [00:01<00:00, 755.62MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:01<00:00, 808.41MMSI/s]
# Processing MMSI: 100%|██████████| 1393/1393 [00:01<00:00, 796.19MMSI/s]
# Processing MMSI: 100%|██████████| 1395/1395 [00:01<00:00, 806.70MMSI/s]
# Processing MMSI: 100%|██████████| 1402/1402 [00:01<00:00, 761.59MMSI/s]
# Processing MMSI: 100%|██████████| 1398/1398 [00:01<00:00, 767.91MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:01<00:00, 789.78MMSI/s]
# Processing MMSI: 100%|██████████| 1404/1404 [00:01<00:00, 800.53MMSI/s]
# Processing MMSI: 100%|██████████| 1404/1404 [00:02<00:00, 669.67MMSI/s]
# Processing MMSI: 100%|██████████| 1413/1413 [00:01<00:00, 788.51MMSI/s]
# Processing MMSI: 100%|██████████| 1406/1406 [00:01<00:00, 750.09MMSI/s]
# Processing MMSI: 100%|██████████| 1414/1414 [00:01<00:00, 764.98MMSI/s]
# Processing MMSI: 100%|██████████| 1395/1395 [00:01<00:00, 751.05MMSI/s]
# Processing MMSI: 100%|██████████| 1387/1387 [00:02<00:00, 656.33MMSI/s]
# Processing MMSI: 100%|██████████| 1399/1399 [00:01<00:00, 771.43MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:01<00:00, 723.99MMSI/s]
# Processing MMSI: 100%|██████████| 1395/1395 [00:01<00:00, 754.72MMSI/s]
# Processing MMSI: 100%|██████████| 1402/1402 [00:02<00:00, 697.49MMSI/s]
# Processing MMSI: 100%|██████████| 1388/1388 [00:02<00:00, 665.67MMSI/s]
# Processing MMSI: 100%|██████████| 1389/1389 [00:01<00:00, 723.50MMSI/s]
# Processing MMSI: 100%|██████████| 1395/1395 [00:02<00:00, 693.90MMSI/s]
# Processing MMSI: 100%|██████████| 1403/1403 [00:02<00:00, 678.76MMSI/s]
# Processing MMSI: 100%|██████████| 1411/1411 [00:02<00:00, 691.21MMSI/s]
# Processing MMSI: 100%|██████████| 1407/1407 [00:01<00:00, 712.95MMSI/s]
# Processing MMSI: 100%|██████████| 1404/1404 [00:01<00:00, 713.12MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:02<00:00, 683.42MMSI/s]
# Processing MMSI: 100%|██████████| 1391/1391 [00:02<00:00, 666.40MMSI/s]
# Processing MMSI: 100%|██████████| 1404/1404 [00:02<00:00, 644.90MMSI/s]
# Processing MMSI: 100%|██████████| 1403/1403 [00:02<00:00, 699.77MMSI/s]
# Processing MMSI: 100%|██████████| 1400/1400 [00:02<00:00, 684.64MMSI/s]
# Processing MMSI: 100%|██████████| 1416/1416 [00:02<00:00, 630.93MMSI/s]
# Processing MMSI: 100%|██████████| 1415/1415 [00:02<00:00, 664.80MMSI/s]
# Processing MMSI: 100%|██████████| 1420/1420 [00:02<00:00, 675.02MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:02<00:00, 678.90MMSI/s]
# Processing MMSI: 100%|██████████| 1401/1401 [00:02<00:00, 673.31MMSI/s]
# Processing MMSI: 100%|██████████| 1385/1385 [00:02<00:00, 608.09MMSI/s]
# Processing MMSI: 100%|██████████| 1396/1396 [00:02<00:00, 677.87MMSI/s]
# Processing MMSI: 100%|██████████| 1386/1386 [00:02<00:00, 665.40MMSI/s]
# Processing MMSI: 100%|██████████| 1392/1392 [00:02<00:00, 670.71MMSI/s]
# Processing MMSI: 100%|██████████| 1394/1394 [00:02<00:00, 612.34MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:02<00:00, 637.03MMSI/s]
# Processing MMSI: 100%|██████████| 1399/1399 [00:02<00:00, 640.20MMSI/s]
# Processing MMSI: 100%|██████████| 1402/1402 [00:02<00:00, 654.79MMSI/s]
# Processing MMSI: 100%|██████████| 1397/1397 [00:02<00:00, 597.22MMSI/s]
# Processing MMSI: 100%|██████████| 1401/1401 [00:02<00:00, 620.82MMSI/s]
# Processing MMSI: 100%|██████████| 1398/1398 [00:02<00:00, 628.54MMSI/s]
# Processing MMSI: 100%|██████████| 1398/1398 [00:02<00:00, 641.47MMSI/s]
# Processing MMSI: 100%|██████████| 1404/1404 [00:02<00:00, 639.71MMSI/s]
# Processing MMSI: 100%|██████████| 1399/1399 [00:02<00:00, 577.66MMSI/s]
# Processing MMSI: 100%|██████████| 1408/1408 [00:02<00:00, 632.61MMSI/s]
# Processing MMSI: 100%|██████████| 1384/1384 [00:02<00:00, 617.95MMSI/s]
# Processing MMSI: 100%|██████████| 1388/1388 [00:02<00:00, 624.65MMSI/s]
# Processing MMSI: 100%|██████████| 1396/1396 [00:02<00:00, 567.45MMSI/s]
# Processing MMSI: 100%|██████████| 1386/1386 [00:02<00:00, 626.86MMSI/s]
# Processing MMSI: 100%|██████████| 1394/1394 [00:02<00:00, 612.46MMSI/s]
# Processing MMSI: 100%|██████████| 1388/1388 [00:02<00:00, 626.02MMSI/s]
# Processing MMSI: 100%|██████████| 1392/1392 [00:02<00:00, 587.51MMSI/s]
# Processing MMSI: 100%|██████████| 1385/1385 [00:02<00:00, 590.55MMSI/s]
# Processing MMSI: 100%|██████████| 1394/1394 [00:02<00:00, 609.59MMSI/s]
# Processing MMSI: 100%|██████████| 1412/1412 [00:02<00:00, 579.81MMSI/s]
# Processing MMSI: 100%|██████████| 1394/1394 [00:02<00:00, 560.39MMSI/s]
# Processing MMSI: 100%|██████████| 1158/1158 [00:02<00:00, 535.13MMSI/s]
# Processing chunks: 100%|██████████| 162/162 [04:51<00:00,  1.80s/chunk]
# Saving MMSI files: 100%|██████████| 1880/1880 [03:10<00:00,  9.86file/s]
# All MMSI files have been saved successfully!
