# %% [markdown]
# now only fish/engine

# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import keras_tuner as kt
import matplotlib.pyplot as plt

# Paths
data_folder = "./time_sets_standardized"

# Function to load and process individual vessel data
def load_and_process_vessel_data(folder_path):
    data, labels = [], []
    status_counts = {}

    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(folder_path, file))

            if "Heading" not in df.columns or df["Heading"].isnull().any():
                continue  # Skip files with missing or invalid data
            
            # Extract the time series features
            sog = df["SOG"].values
            cog = df["COG"].values
            heading = df["Heading"].values

            # Extract label
            label = df["Navigational status"].iloc[0]
            if label in ["Under way using engine", "Engaged in fishing"]:
                # Calculate statistics for each feature
                sog_mean = np.mean(sog)
                sog_min = np.min(sog)
                sog_max = np.max(sog)
                sog_std = np.std(sog)
                
                cog_mean = np.mean(cog)
                cog_min = np.min(cog)
                cog_max = np.max(cog)
                cog_std = np.std(cog)
                
                heading_mean = np.mean(heading)
                heading_min = np.min(heading)
                heading_max = np.max(heading)
                heading_std = np.std(heading)
                
                # Rate of change (slope) for SOG and COG
                sog_slope = np.polyfit(range(len(sog)), sog, 1)[0]  # Linear fit slope
                cog_slope = np.polyfit(range(len(cog)), cog, 1)[0]  # Linear fit slope

                # Add to the dataset
                features = [
                    sog_mean, sog_min, sog_max, sog_std, sog_slope,
                    cog_mean, cog_min, cog_max, cog_std, cog_slope,
                    heading_mean, heading_min, heading_max, heading_std
                ]
                
                data.append(features)
                labels.append(label)
                
                if label not in status_counts:
                    status_counts[label] = 0
                status_counts[label] += 1

    return np.array(data), np.array(labels), status_counts

# Load and preprocess data
data, labels, status_counts = load_and_process_vessel_data(data_folder)

# Encode labels
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Print class distribution
print("Class distribution:", dict(zip(label_encoder.classes_, np.bincount(labels))))

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Apply undersampling to balance the classes
def undersample_data(X, y):
    class_0 = X[y == 0]
    class_1 = X[y == 1]
    
    class_1_undersampled = resample(class_1, replace=False, n_samples=len(class_0), random_state=42)
    
    X_balanced = np.vstack((class_0, class_1_undersampled))
    y_balanced = np.hstack((np.zeros(len(class_0)), np.ones(len(class_1_undersampled))))
    
    return X_balanced, y_balanced

X_train_balanced, y_train_balanced = undersample_data(X_train, y_train)

# Standardize features
scaler = StandardScaler()
X_train_balanced = scaler.fit_transform(X_train_balanced)
X_test = scaler.transform(X_test)

# Define the model builder function for Keras Tuner
def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units_1', min_value=64, max_value=512, step=64),
                    activation=hp.Choice('activation_1', values=['relu', 'tanh']),
                    input_dim=X_train_balanced.shape[1]))
    model.add(Dropout(rate=hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    
    for i in range(hp.Int('num_layers', 1, 3)):
        model.add(Dense(units=hp.Int(f'units_{i+2}', min_value=64, max_value=512, step=64),
                        activation=hp.Choice(f'activation_{i+2}', values=['relu', 'tanh'])))
        model.add(Dropout(rate=hp.Float(f'dropout_{i+2}', min_value=0.1, max_value=0.5, step=0.1)))
    
    model.add(Dense(2, activation='softmax'))
    optimizer = tf.keras.optimizers.Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'))
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Set up the tuner
tuner = kt.BayesianOptimization(
    build_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=2,
    directory='kt_hyperparam_search',
    project_name='vessel_navigation_bayesian'
)

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Run the tuner
tuner.search(X_train_balanced, y_train_balanced, epochs=100, validation_data=(X_test, y_test),
             batch_size=32, callbacks=[early_stopping])

# Get the best hyperparameters and build the model
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
best_model = tuner.hypermodel.build(best_hps)

# Train the best model
history = best_model.fit(X_train_balanced, y_train_balanced, epochs=200, validation_data=(X_test, y_test),
                         batch_size=32, callbacks=[early_stopping])

# Evaluate the best model
loss, accuracy = best_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")

# Plot training history
def plot_history(history):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Loss')

    plt.show()

plot_history(history)
# Out:
# Trial 20 Complete [00h 01m 16s]
# val_accuracy: 0.8165656626224518
#
# Best val_accuracy So Far: 0.8169696927070618
# Total elapsed time: 00h 28m 14s
# Epoch 1/200
# 220/220 [==============================] - 2s 7ms/step - loss: 0.4957 - accuracy: 0.7587 - val_loss: 0.4616 - val_accuracy: 0.7701
# Epoch 2/200
# 220/220 [==============================] - 1s 6ms/step - loss: 0.4517 - accuracy: 0.7898 - val_loss: 0.4363 - val_accuracy: 0.7810
# Epoch 3/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.4393 - accuracy: 0.7971 - val_loss: 0.4295 - val_accuracy: 0.7863
# Epoch 4/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4307 - accuracy: 0.8035 - val_loss: 0.4373 - val_accuracy: 0.7818
# Epoch 5/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.4194 - accuracy: 0.8050 - val_loss: 0.4320 - val_accuracy: 0.7883
# Epoch 6/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.4160 - accuracy: 0.8083 - val_loss: 0.4391 - val_accuracy: 0.7875
# Epoch 7/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4112 - accuracy: 0.8140 - val_loss: 0.4230 - val_accuracy: 0.8004
# Epoch 8/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.4105 - accuracy: 0.8113 - val_loss: 0.4328 - val_accuracy: 0.7911
# Epoch 9/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.4052 - accuracy: 0.8174 - val_loss: 0.4471 - val_accuracy: 0.7903
# Epoch 10/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3980 - accuracy: 0.8181 - val_loss: 0.4163 - val_accuracy: 0.8012
# Epoch 11/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3993 - accuracy: 0.8228 - val_loss: 0.4249 - val_accuracy: 0.7939
# Epoch 12/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3935 - accuracy: 0.8228 - val_loss: 0.4107 - val_accuracy: 0.7996
# Epoch 13/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3942 - accuracy: 0.8205 - val_loss: 0.4106 - val_accuracy: 0.8053
# Epoch 14/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3900 - accuracy: 0.8207 - val_loss: 0.4290 - val_accuracy: 0.7976
# Epoch 15/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3842 - accuracy: 0.8258 - val_loss: 0.4280 - val_accuracy: 0.8008
# Epoch 16/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3845 - accuracy: 0.8298 - val_loss: 0.4207 - val_accuracy: 0.7976
# Epoch 17/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3812 - accuracy: 0.8329 - val_loss: 0.4158 - val_accuracy: 0.8036
# Epoch 18/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3772 - accuracy: 0.8291 - val_loss: 0.4149 - val_accuracy: 0.8081
# Epoch 19/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3776 - accuracy: 0.8309 - val_loss: 0.4144 - val_accuracy: 0.8057
# Epoch 20/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3740 - accuracy: 0.8332 - val_loss: 0.4028 - val_accuracy: 0.8109
# Epoch 21/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3745 - accuracy: 0.8336 - val_loss: 0.4181 - val_accuracy: 0.8024
# Epoch 22/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3704 - accuracy: 0.8326 - val_loss: 0.4024 - val_accuracy: 0.8129
# Epoch 23/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3716 - accuracy: 0.8336 - val_loss: 0.4045 - val_accuracy: 0.8032
# Epoch 24/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3668 - accuracy: 0.8363 - val_loss: 0.4148 - val_accuracy: 0.8105
# Epoch 25/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3618 - accuracy: 0.8426 - val_loss: 0.4082 - val_accuracy: 0.8186
# Epoch 26/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3616 - accuracy: 0.8397 - val_loss: 0.4089 - val_accuracy: 0.8089
# Epoch 27/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3615 - accuracy: 0.8397 - val_loss: 0.3997 - val_accuracy: 0.8137
# Epoch 28/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3609 - accuracy: 0.8355 - val_loss: 0.4042 - val_accuracy: 0.8065
# Epoch 29/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3573 - accuracy: 0.8424 - val_loss: 0.4061 - val_accuracy: 0.8125
# Epoch 30/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3546 - accuracy: 0.8439 - val_loss: 0.4492 - val_accuracy: 0.7939
# Epoch 31/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3520 - accuracy: 0.8449 - val_loss: 0.4014 - val_accuracy: 0.8105
# Epoch 32/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3504 - accuracy: 0.8457 - val_loss: 0.4124 - val_accuracy: 0.8093
# Epoch 33/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3474 - accuracy: 0.8491 - val_loss: 0.4250 - val_accuracy: 0.8081
# Epoch 34/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3503 - accuracy: 0.8468 - val_loss: 0.4137 - val_accuracy: 0.8040
# Epoch 35/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3438 - accuracy: 0.8483 - val_loss: 0.4137 - val_accuracy: 0.8040
# Epoch 36/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3393 - accuracy: 0.8497 - val_loss: 0.3946 - val_accuracy: 0.8194
# Epoch 37/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3428 - accuracy: 0.8521 - val_loss: 0.4241 - val_accuracy: 0.8036
# Epoch 38/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3419 - accuracy: 0.8525 - val_loss: 0.4221 - val_accuracy: 0.8154
# Epoch 39/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3380 - accuracy: 0.8521 - val_loss: 0.4168 - val_accuracy: 0.8166
# Epoch 40/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3399 - accuracy: 0.8528 - val_loss: 0.4120 - val_accuracy: 0.8154
# Epoch 41/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3351 - accuracy: 0.8522 - val_loss: 0.4149 - val_accuracy: 0.8222
# Epoch 42/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3345 - accuracy: 0.8577 - val_loss: 0.4439 - val_accuracy: 0.8113
# Epoch 43/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3381 - accuracy: 0.8542 - val_loss: 0.4016 - val_accuracy: 0.8234
# Epoch 44/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3296 - accuracy: 0.8582 - val_loss: 0.4185 - val_accuracy: 0.8166
# Epoch 45/200
# 220/220 [==============================] - 1s 4ms/step - loss: 0.3276 - accuracy: 0.8562 - val_loss: 0.4203 - val_accuracy: 0.8133
# Epoch 46/200
# 220/220 [==============================] - 1s 5ms/step - loss: 0.3284 - accuracy: 0.8598 - val_loss: 0.4342 - val_accuracy: 0.8158
# 78/78 [==============================] - 0s 2ms/step - loss: 0.3946 - accuracy: 0.8194
# Test Accuracy: 0.82

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import keras_tuner as kt

# Paths
data_folder = "./time_sets_standardized"

# Function to load and process individual vessel data
def load_and_process_vessel_data(folder_path):
    data, labels = [], []
    status_counts = {}

    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(folder_path, file))

            if "Heading" not in df.columns or df["Heading"].isnull().any():
                continue  # Skip files with missing or invalid data
            
            # Extract the time series features
            sog = df["SOG"].values
            cog = df["COG"].values
            heading = df["Heading"].values

            # Extract label
            label = df["Navigational status"].iloc[0]
            if label in ["Under way using engine", "Engaged in fishing"]:
                # Calculate statistics for each feature
                sog_mean = np.mean(sog)
                sog_min = np.min(sog)
                sog_max = np.max(sog)
                sog_std = np.std(sog)
                
                cog_mean = np.mean(cog)
                cog_min = np.min(cog)
                cog_max = np.max(cog)
                cog_std = np.std(cog)
                
                heading_mean = np.mean(heading)
                heading_min = np.min(heading)
                heading_max = np.max(heading)
                heading_std = np.std(heading)
                
                # Rate of change (slope) for SOG and COG
                sog_slope = np.polyfit(range(len(sog)), sog, 1)[0]  # Linear fit slope
                cog_slope = np.polyfit(range(len(cog)), cog, 1)[0]  # Linear fit slope

                # Add to the dataset
                features = [
                    sog_mean, sog_min, sog_max, sog_std, sog_slope,
                    cog_mean, cog_min, cog_max, cog_std, cog_slope,
                    heading_mean, heading_min, heading_max, heading_std
                ]
                
                data.append(features)
                labels.append(label)
                
                if label not in status_counts:
                    status_counts[label] = 0
                status_counts[label] += 1

    return np.array(data), np.array(labels), status_counts

# Load and preprocess data
data, labels, status_counts = load_and_process_vessel_data(data_folder)

# Encode labels (e.g., "Under way using engine" -> 0, "Engaged in fishing" -> 1)
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Apply undersampling to balance the classes
def undersample_data(X, y):
    class_0 = X[y == 0]  # Minority class (0)
    class_1 = X[y == 1]  # Majority class (1)
    
    class_1_undersampled = resample(class_1, replace=False, n_samples=len(class_0), random_state=42)
    
    X_balanced = np.vstack((class_0, class_1_undersampled))
    y_balanced = np.hstack((np.zeros(len(class_0)), np.ones(len(class_1_undersampled))))
    
    return X_balanced, y_balanced

X_train_balanced, y_train_balanced = undersample_data(X_train, y_train)

# Function to build the model for Keras Tuner
def build_model(hp):
    model = Sequential()
    model.add(Dense(
        units=hp.Int('units_layer_1', min_value=64, max_value=256, step=32),
        activation='relu',
        input_dim=X_train_balanced.shape[1]
    ))
    model.add(Dropout(rate=hp.Float('dropout_layer_1', min_value=0.2, max_value=0.5, step=0.1)))
    model.add(Dense(
        units=hp.Int('units_layer_2', min_value=32, max_value=128, step=16),
        activation='relu'
    ))
    model.add(Dropout(rate=hp.Float('dropout_layer_2', min_value=0.2, max_value=0.5, step=0.1)))
    model.add(Dense(2, activation='softmax'))  # Binary classification output
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# Reload the tuner
tuner = kt.BayesianOptimization(
    build_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=2,
    directory='kt_hyperparam_search',
    project_name='vessel_navigation_bayesian'
)

# Retrieve the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:", best_hps.values)

# Build and train the best model
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(
    X_train_balanced, y_train_balanced,
    epochs=200,  # Adjust as needed
    batch_size=64,
    validation_data=(X_test, y_test)
)

# Evaluate the model
test_loss, test_acc = best_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.2f}")
# Out:
# Reloading Tuner from kt_hyperparam_search\vessel_navigation_bayesian\tuner0.json
# Best Hyperparameters: {'units_1': 512, 'activation_1': 'relu', 'dropout_1': 0.2, 'num_layers': 3, 'units_2': 448, 'activation_2': 'relu', 'dropout_2': 0.2, 'learning_rate': 0.00021945155942647553, 'units_3': 448, 'activation_3': 'tanh', 'dropout_3': 0.30000000000000004, 'units_4': 256, 'activation_4': 'tanh', 'dropout_4': 0.1}
# Epoch 1/200
# 110/110 [==============================] - 2s 5ms/step - loss: 10.0835 - accuracy: 0.5122 - val_loss: 0.8906 - val_accuracy: 0.6234
# Epoch 2/200
# 110/110 [==============================] - 0s 3ms/step - loss: 2.2481 - accuracy: 0.5374 - val_loss: 0.8019 - val_accuracy: 0.4400
# Epoch 3/200
# 110/110 [==============================] - 0s 3ms/step - loss: 1.1201 - accuracy: 0.5326 - val_loss: 0.6762 - val_accuracy: 0.6347
# Epoch 4/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.9088 - accuracy: 0.5449 - val_loss: 0.6898 - val_accuracy: 0.5160
# Epoch 5/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.7896 - accuracy: 0.5356 - val_loss: 0.6874 - val_accuracy: 0.4485
# Epoch 6/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.7418 - accuracy: 0.5448 - val_loss: 0.6808 - val_accuracy: 0.4703
# Epoch 7/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.7145 - accuracy: 0.5593 - val_loss: 0.6709 - val_accuracy: 0.5208
# Epoch 8/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.6953 - accuracy: 0.5778 - val_loss: 0.6590 - val_accuracy: 0.5648
# Epoch 9/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.6810 - accuracy: 0.5961 - val_loss: 0.6703 - val_accuracy: 0.5543
# Epoch 10/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.6701 - accuracy: 0.6155 - val_loss: 0.6112 - val_accuracy: 0.6945
# Epoch 11/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.6552 - accuracy: 0.6189 - val_loss: 0.5803 - val_accuracy: 0.7131
# Epoch 12/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.6353 - accuracy: 0.6462 - val_loss: 0.5878 - val_accuracy: 0.6958
# Epoch 13/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.6193 - accuracy: 0.6544 - val_loss: 0.5804 - val_accuracy: 0.7063
# Epoch 14/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.6099 - accuracy: 0.6705 - val_loss: 0.5523 - val_accuracy: 0.7362
# Epoch 15/200
# 110/110 [==============================] - 0s 3ms/step - loss: 0.5999 - accuracy: 0.6768 - val_loss: 0.5383 - val_accuracy: 0.7366
# Epoch 16/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5932 - accuracy: 0.6839 - val_loss: 0.5486 - val_accuracy: 0.7362
# Epoch 17/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5928 - accuracy: 0.6863 - val_loss: 0.5253 - val_accuracy: 0.7459
# Epoch 18/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5809 - accuracy: 0.6988 - val_loss: 0.5226 - val_accuracy: 0.7394
# Epoch 19/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5753 - accuracy: 0.7028 - val_loss: 0.5275 - val_accuracy: 0.7414
# Epoch 20/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5815 - accuracy: 0.6991 - val_loss: 0.5109 - val_accuracy: 0.7507
# Epoch 21/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5750 - accuracy: 0.7032 - val_loss: 0.5050 - val_accuracy: 0.7547
# Epoch 22/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5702 - accuracy: 0.7157 - val_loss: 0.5129 - val_accuracy: 0.7523
# Epoch 23/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5731 - accuracy: 0.7080 - val_loss: 0.5066 - val_accuracy: 0.7475
# Epoch 24/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5626 - accuracy: 0.7153 - val_loss: 0.5071 - val_accuracy: 0.7495
# Epoch 25/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5627 - accuracy: 0.7153 - val_loss: 0.5194 - val_accuracy: 0.7515
# Epoch 26/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5588 - accuracy: 0.7140 - val_loss: 0.5336 - val_accuracy: 0.7483
# Epoch 27/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5525 - accuracy: 0.7240 - val_loss: 0.5373 - val_accuracy: 0.7349
# Epoch 28/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5524 - accuracy: 0.7197 - val_loss: 0.5025 - val_accuracy: 0.7580
# Epoch 29/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5471 - accuracy: 0.7260 - val_loss: 0.4970 - val_accuracy: 0.7560
# Epoch 30/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5544 - accuracy: 0.7231 - val_loss: 0.5278 - val_accuracy: 0.7455
# Epoch 31/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5498 - accuracy: 0.7210 - val_loss: 0.4887 - val_accuracy: 0.7564
# Epoch 32/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5466 - accuracy: 0.7218 - val_loss: 0.4930 - val_accuracy: 0.7608
# Epoch 33/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5419 - accuracy: 0.7311 - val_loss: 0.4857 - val_accuracy: 0.7604
# Epoch 34/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5383 - accuracy: 0.7317 - val_loss: 0.4775 - val_accuracy: 0.7620
# Epoch 35/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5393 - accuracy: 0.7349 - val_loss: 0.5289 - val_accuracy: 0.7523
# Epoch 36/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5347 - accuracy: 0.7358 - val_loss: 0.4731 - val_accuracy: 0.7636
# Epoch 37/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5313 - accuracy: 0.7373 - val_loss: 0.4910 - val_accuracy: 0.7584
# Epoch 38/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5354 - accuracy: 0.7288 - val_loss: 0.4736 - val_accuracy: 0.7665
# Epoch 39/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5256 - accuracy: 0.7402 - val_loss: 0.4766 - val_accuracy: 0.7657
# Epoch 40/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5265 - accuracy: 0.7439 - val_loss: 0.4844 - val_accuracy: 0.7624
# Epoch 41/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5283 - accuracy: 0.7371 - val_loss: 0.4897 - val_accuracy: 0.7628
# Epoch 42/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5178 - accuracy: 0.7497 - val_loss: 0.4785 - val_accuracy: 0.7653
# Epoch 43/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5176 - accuracy: 0.7511 - val_loss: 0.5073 - val_accuracy: 0.7547
# Epoch 44/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5152 - accuracy: 0.7524 - val_loss: 0.4867 - val_accuracy: 0.7608
# Epoch 45/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5141 - accuracy: 0.7517 - val_loss: 0.4607 - val_accuracy: 0.7665
# Epoch 46/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5063 - accuracy: 0.7575 - val_loss: 0.4644 - val_accuracy: 0.7717
# Epoch 47/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5096 - accuracy: 0.7503 - val_loss: 0.4694 - val_accuracy: 0.7632
# Epoch 48/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5043 - accuracy: 0.7547 - val_loss: 0.5043 - val_accuracy: 0.7515
# Epoch 49/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5086 - accuracy: 0.7514 - val_loss: 0.4720 - val_accuracy: 0.7531
# Epoch 50/200
# 110/110 [==============================] - 1s 5ms/step - loss: 0.5095 - accuracy: 0.7555 - val_loss: 0.4565 - val_accuracy: 0.7657
# Epoch 51/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.5021 - accuracy: 0.7601 - val_loss: 0.4719 - val_accuracy: 0.7511
# Epoch 52/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4987 - accuracy: 0.7554 - val_loss: 0.4988 - val_accuracy: 0.7596
# Epoch 53/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4983 - accuracy: 0.7555 - val_loss: 0.4812 - val_accuracy: 0.7608
# Epoch 54/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4980 - accuracy: 0.7577 - val_loss: 0.4589 - val_accuracy: 0.7616
# Epoch 55/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4976 - accuracy: 0.7582 - val_loss: 0.4520 - val_accuracy: 0.7657
# Epoch 56/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4904 - accuracy: 0.7686 - val_loss: 0.4604 - val_accuracy: 0.7632
# Epoch 57/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4912 - accuracy: 0.7609 - val_loss: 0.4517 - val_accuracy: 0.7644
# Epoch 58/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4944 - accuracy: 0.7641 - val_loss: 0.4713 - val_accuracy: 0.7612
# Epoch 59/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4882 - accuracy: 0.7629 - val_loss: 0.4633 - val_accuracy: 0.7697
# Epoch 60/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4859 - accuracy: 0.7698 - val_loss: 0.4638 - val_accuracy: 0.7657
# Epoch 61/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4903 - accuracy: 0.7625 - val_loss: 0.4613 - val_accuracy: 0.7721
# Epoch 62/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4814 - accuracy: 0.7749 - val_loss: 0.4466 - val_accuracy: 0.7830
# Epoch 63/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4907 - accuracy: 0.7649 - val_loss: 0.4406 - val_accuracy: 0.7745
# Epoch 64/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4852 - accuracy: 0.7703 - val_loss: 0.4392 - val_accuracy: 0.7774
# Epoch 65/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4791 - accuracy: 0.7693 - val_loss: 0.4608 - val_accuracy: 0.7669
# Epoch 66/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4780 - accuracy: 0.7730 - val_loss: 0.4635 - val_accuracy: 0.7693
# Epoch 67/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4833 - accuracy: 0.7696 - val_loss: 0.4476 - val_accuracy: 0.7733
# Epoch 68/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4772 - accuracy: 0.7743 - val_loss: 0.4415 - val_accuracy: 0.7762
# Epoch 69/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4745 - accuracy: 0.7745 - val_loss: 0.4380 - val_accuracy: 0.7802
# Epoch 70/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4642 - accuracy: 0.7858 - val_loss: 0.4474 - val_accuracy: 0.7806
# Epoch 71/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4683 - accuracy: 0.7821 - val_loss: 0.4541 - val_accuracy: 0.7802
# Epoch 72/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4737 - accuracy: 0.7790 - val_loss: 0.4374 - val_accuracy: 0.7790
# Epoch 73/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4712 - accuracy: 0.7783 - val_loss: 0.4583 - val_accuracy: 0.7794
# Epoch 74/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4734 - accuracy: 0.7750 - val_loss: 0.4412 - val_accuracy: 0.7859
# Epoch 75/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4688 - accuracy: 0.7776 - val_loss: 0.4480 - val_accuracy: 0.7875
# Epoch 76/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4696 - accuracy: 0.7824 - val_loss: 0.4372 - val_accuracy: 0.7846
# Epoch 77/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4630 - accuracy: 0.7847 - val_loss: 0.4512 - val_accuracy: 0.7733
# Epoch 78/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4595 - accuracy: 0.7831 - val_loss: 0.4519 - val_accuracy: 0.7806
# Epoch 79/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4646 - accuracy: 0.7840 - val_loss: 0.4449 - val_accuracy: 0.7749
# Epoch 80/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4540 - accuracy: 0.7883 - val_loss: 0.4510 - val_accuracy: 0.7826
# Epoch 81/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4662 - accuracy: 0.7837 - val_loss: 0.4498 - val_accuracy: 0.7871
# Epoch 82/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4595 - accuracy: 0.7834 - val_loss: 0.4462 - val_accuracy: 0.7846
# Epoch 83/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4595 - accuracy: 0.7851 - val_loss: 0.4610 - val_accuracy: 0.7685
# Epoch 84/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4637 - accuracy: 0.7784 - val_loss: 0.4707 - val_accuracy: 0.7717
# Epoch 85/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4607 - accuracy: 0.7800 - val_loss: 0.4433 - val_accuracy: 0.7802
# Epoch 86/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4641 - accuracy: 0.7840 - val_loss: 0.4542 - val_accuracy: 0.7806
# Epoch 87/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4611 - accuracy: 0.7793 - val_loss: 0.4283 - val_accuracy: 0.7923
# Epoch 88/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4568 - accuracy: 0.7819 - val_loss: 0.4414 - val_accuracy: 0.7846
# Epoch 89/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4558 - accuracy: 0.7894 - val_loss: 0.4353 - val_accuracy: 0.7911
# Epoch 90/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4522 - accuracy: 0.7881 - val_loss: 0.4361 - val_accuracy: 0.7871
# Epoch 91/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4525 - accuracy: 0.7850 - val_loss: 0.4346 - val_accuracy: 0.7851
# Epoch 92/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4462 - accuracy: 0.7920 - val_loss: 0.4333 - val_accuracy: 0.7871
# Epoch 93/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4534 - accuracy: 0.7884 - val_loss: 0.4539 - val_accuracy: 0.7818
# Epoch 94/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4488 - accuracy: 0.7959 - val_loss: 0.4337 - val_accuracy: 0.7883
# Epoch 95/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4509 - accuracy: 0.7888 - val_loss: 0.4342 - val_accuracy: 0.7875
# Epoch 96/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4418 - accuracy: 0.7969 - val_loss: 0.4557 - val_accuracy: 0.7814
# Epoch 97/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4449 - accuracy: 0.7925 - val_loss: 0.4606 - val_accuracy: 0.7810
# Epoch 98/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4485 - accuracy: 0.7907 - val_loss: 0.4406 - val_accuracy: 0.7842
# Epoch 99/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.7974 - val_loss: 0.4429 - val_accuracy: 0.7802
# Epoch 100/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.7959 - val_loss: 0.4345 - val_accuracy: 0.7939
# Epoch 101/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4481 - accuracy: 0.7908 - val_loss: 0.4431 - val_accuracy: 0.7758
# Epoch 102/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4390 - accuracy: 0.7968 - val_loss: 0.4359 - val_accuracy: 0.7834
# Epoch 103/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4424 - accuracy: 0.7971 - val_loss: 0.5122 - val_accuracy: 0.7451
# Epoch 104/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4472 - accuracy: 0.7937 - val_loss: 0.4387 - val_accuracy: 0.7818
# Epoch 105/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4421 - accuracy: 0.7939 - val_loss: 0.4541 - val_accuracy: 0.7814
# Epoch 106/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4352 - accuracy: 0.7979 - val_loss: 0.4253 - val_accuracy: 0.7867
# Epoch 107/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.7952 - val_loss: 0.4606 - val_accuracy: 0.7749
# Epoch 108/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.7908 - val_loss: 0.4422 - val_accuracy: 0.7826
# Epoch 109/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4379 - accuracy: 0.7974 - val_loss: 0.4469 - val_accuracy: 0.7867
# Epoch 110/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4405 - accuracy: 0.7952 - val_loss: 0.4538 - val_accuracy: 0.7822
# Epoch 111/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4403 - accuracy: 0.7955 - val_loss: 0.4601 - val_accuracy: 0.7762
# Epoch 112/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4376 - accuracy: 0.7998 - val_loss: 0.4559 - val_accuracy: 0.7826
# Epoch 113/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4383 - accuracy: 0.7979 - val_loss: 0.4448 - val_accuracy: 0.7855
# Epoch 114/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4368 - accuracy: 0.7964 - val_loss: 0.4317 - val_accuracy: 0.7899
# Epoch 115/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4367 - accuracy: 0.7996 - val_loss: 0.4514 - val_accuracy: 0.7851
# Epoch 116/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4345 - accuracy: 0.7989 - val_loss: 0.4508 - val_accuracy: 0.7842
# Epoch 117/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4344 - accuracy: 0.8001 - val_loss: 0.4327 - val_accuracy: 0.7939
# Epoch 118/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4432 - accuracy: 0.7984 - val_loss: 0.4516 - val_accuracy: 0.7778
# Epoch 119/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4382 - accuracy: 0.8002 - val_loss: 0.4606 - val_accuracy: 0.7810
# Epoch 120/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4305 - accuracy: 0.8015 - val_loss: 0.4522 - val_accuracy: 0.7814
# Epoch 121/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4427 - accuracy: 0.7974 - val_loss: 0.4415 - val_accuracy: 0.7842
# Epoch 122/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4300 - accuracy: 0.8022 - val_loss: 0.4355 - val_accuracy: 0.7838
# Epoch 123/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4289 - accuracy: 0.8052 - val_loss: 0.4354 - val_accuracy: 0.7895
# Epoch 124/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4354 - accuracy: 0.8011 - val_loss: 0.4399 - val_accuracy: 0.7834
# Epoch 125/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4315 - accuracy: 0.8040 - val_loss: 0.4304 - val_accuracy: 0.7935
# Epoch 126/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4298 - accuracy: 0.8019 - val_loss: 0.4435 - val_accuracy: 0.7879
# Epoch 127/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4310 - accuracy: 0.8015 - val_loss: 0.4861 - val_accuracy: 0.7596
# Epoch 128/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4286 - accuracy: 0.8028 - val_loss: 0.4322 - val_accuracy: 0.7838
# Epoch 129/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4299 - accuracy: 0.8047 - val_loss: 0.4325 - val_accuracy: 0.7903
# Epoch 130/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4305 - accuracy: 0.8039 - val_loss: 0.4692 - val_accuracy: 0.7733
# Epoch 131/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4322 - accuracy: 0.8005 - val_loss: 0.4555 - val_accuracy: 0.7842
# Epoch 132/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4281 - accuracy: 0.8025 - val_loss: 0.4357 - val_accuracy: 0.7911
# Epoch 133/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4285 - accuracy: 0.8002 - val_loss: 0.4583 - val_accuracy: 0.7818
# Epoch 134/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4234 - accuracy: 0.8069 - val_loss: 0.4615 - val_accuracy: 0.7754
# Epoch 135/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8069 - val_loss: 0.4459 - val_accuracy: 0.7826
# Epoch 136/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4262 - accuracy: 0.8067 - val_loss: 0.4502 - val_accuracy: 0.7891
# Epoch 137/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4291 - accuracy: 0.8046 - val_loss: 0.4382 - val_accuracy: 0.7943
# Epoch 138/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4240 - accuracy: 0.8072 - val_loss: 0.4438 - val_accuracy: 0.7931
# Epoch 139/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4256 - accuracy: 0.8050 - val_loss: 0.4398 - val_accuracy: 0.7915
# Epoch 140/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4240 - accuracy: 0.8052 - val_loss: 0.4422 - val_accuracy: 0.7863
# Epoch 141/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4252 - accuracy: 0.8066 - val_loss: 0.4400 - val_accuracy: 0.7927
# Epoch 142/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4241 - accuracy: 0.8093 - val_loss: 0.4421 - val_accuracy: 0.7875
# Epoch 143/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4243 - accuracy: 0.8079 - val_loss: 0.4309 - val_accuracy: 0.7919
# Epoch 144/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4236 - accuracy: 0.8082 - val_loss: 0.4672 - val_accuracy: 0.7762
# Epoch 145/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4230 - accuracy: 0.8079 - val_loss: 0.4364 - val_accuracy: 0.7895
# Epoch 146/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4281 - accuracy: 0.8018 - val_loss: 0.4468 - val_accuracy: 0.7822
# Epoch 147/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4192 - accuracy: 0.8094 - val_loss: 0.4254 - val_accuracy: 0.7947
# Epoch 148/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4267 - accuracy: 0.8049 - val_loss: 0.4488 - val_accuracy: 0.7859
# Epoch 149/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4264 - accuracy: 0.8065 - val_loss: 0.4417 - val_accuracy: 0.7891
# Epoch 150/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4228 - accuracy: 0.8065 - val_loss: 0.4548 - val_accuracy: 0.7790
# Epoch 151/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4202 - accuracy: 0.8084 - val_loss: 0.4492 - val_accuracy: 0.7814
# Epoch 152/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4256 - accuracy: 0.8110 - val_loss: 0.4524 - val_accuracy: 0.7822
# Epoch 153/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4237 - accuracy: 0.8060 - val_loss: 0.4832 - val_accuracy: 0.7564
# Epoch 154/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4298 - accuracy: 0.8050 - val_loss: 0.4621 - val_accuracy: 0.7717
# Epoch 155/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4210 - accuracy: 0.8075 - val_loss: 0.4450 - val_accuracy: 0.7939
# Epoch 156/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4282 - accuracy: 0.8057 - val_loss: 0.4634 - val_accuracy: 0.7818
# Epoch 157/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4264 - accuracy: 0.8045 - val_loss: 0.4478 - val_accuracy: 0.7822
# Epoch 158/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4235 - accuracy: 0.8062 - val_loss: 0.4659 - val_accuracy: 0.7802
# Epoch 159/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4153 - accuracy: 0.8111 - val_loss: 0.4294 - val_accuracy: 0.7931
# Epoch 160/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4283 - accuracy: 0.8042 - val_loss: 0.4394 - val_accuracy: 0.7855
# Epoch 161/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4228 - accuracy: 0.8093 - val_loss: 0.4340 - val_accuracy: 0.7911
# Epoch 162/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4195 - accuracy: 0.8103 - val_loss: 0.4247 - val_accuracy: 0.7923
# Epoch 163/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4205 - accuracy: 0.8103 - val_loss: 0.4852 - val_accuracy: 0.7620
# Epoch 164/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4272 - accuracy: 0.8045 - val_loss: 0.4297 - val_accuracy: 0.7907
# Epoch 165/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4151 - accuracy: 0.8116 - val_loss: 0.4478 - val_accuracy: 0.7871
# Epoch 166/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4253 - accuracy: 0.8045 - val_loss: 0.4254 - val_accuracy: 0.8008
# Epoch 167/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4158 - accuracy: 0.8129 - val_loss: 0.4633 - val_accuracy: 0.7794
# Epoch 168/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4180 - accuracy: 0.8067 - val_loss: 0.4473 - val_accuracy: 0.7806
# Epoch 169/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4191 - accuracy: 0.8056 - val_loss: 0.4451 - val_accuracy: 0.7822
# Epoch 170/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4200 - accuracy: 0.8104 - val_loss: 0.4270 - val_accuracy: 0.7915
# Epoch 171/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4206 - accuracy: 0.8082 - val_loss: 0.4229 - val_accuracy: 0.7939
# Epoch 172/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8111 - val_loss: 0.4546 - val_accuracy: 0.7834
# Epoch 173/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4193 - accuracy: 0.8131 - val_loss: 0.4344 - val_accuracy: 0.7895
# Epoch 174/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4160 - accuracy: 0.8113 - val_loss: 0.4365 - val_accuracy: 0.7943
# Epoch 175/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4214 - accuracy: 0.8084 - val_loss: 0.4216 - val_accuracy: 0.7915
# Epoch 176/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4197 - accuracy: 0.8096 - val_loss: 0.4484 - val_accuracy: 0.7863
# Epoch 177/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4178 - accuracy: 0.8077 - val_loss: 0.4325 - val_accuracy: 0.7943
# Epoch 178/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4184 - accuracy: 0.8107 - val_loss: 0.4361 - val_accuracy: 0.7956
# Epoch 179/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4130 - accuracy: 0.8111 - val_loss: 0.4333 - val_accuracy: 0.7927
# Epoch 180/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4219 - accuracy: 0.8072 - val_loss: 0.4333 - val_accuracy: 0.7976
# Epoch 181/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4168 - accuracy: 0.8114 - val_loss: 0.4342 - val_accuracy: 0.7923
# Epoch 182/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8056 - val_loss: 0.4551 - val_accuracy: 0.7842
# Epoch 183/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4178 - accuracy: 0.8109 - val_loss: 0.4441 - val_accuracy: 0.7907
# Epoch 184/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4223 - accuracy: 0.8062 - val_loss: 0.4690 - val_accuracy: 0.7758
# Epoch 185/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4198 - accuracy: 0.8148 - val_loss: 0.4370 - val_accuracy: 0.7972
# Epoch 186/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4220 - accuracy: 0.8052 - val_loss: 0.4723 - val_accuracy: 0.7802
# Epoch 187/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4212 - accuracy: 0.8096 - val_loss: 0.4365 - val_accuracy: 0.7927
# Epoch 188/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4142 - accuracy: 0.8120 - val_loss: 0.4321 - val_accuracy: 0.7875
# Epoch 189/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4188 - accuracy: 0.8072 - val_loss: 0.4441 - val_accuracy: 0.7927
# Epoch 190/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4163 - accuracy: 0.8134 - val_loss: 0.4271 - val_accuracy: 0.7939
# Epoch 191/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4133 - accuracy: 0.8116 - val_loss: 0.4520 - val_accuracy: 0.7806
# Epoch 192/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4176 - accuracy: 0.8094 - val_loss: 0.4278 - val_accuracy: 0.7960
# Epoch 193/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4179 - accuracy: 0.8092 - val_loss: 0.4774 - val_accuracy: 0.7725
# Epoch 194/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4191 - accuracy: 0.8040 - val_loss: 0.4513 - val_accuracy: 0.7838
# Epoch 195/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4096 - accuracy: 0.8124 - val_loss: 0.4363 - val_accuracy: 0.8004
# Epoch 196/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4151 - accuracy: 0.8099 - val_loss: 0.4402 - val_accuracy: 0.7875
# Epoch 197/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4150 - accuracy: 0.8116 - val_loss: 0.4574 - val_accuracy: 0.7810
# Epoch 198/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4170 - accuracy: 0.8060 - val_loss: 0.4490 - val_accuracy: 0.7822
# Epoch 199/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4143 - accuracy: 0.8076 - val_loss: 0.4463 - val_accuracy: 0.7846
# Epoch 200/200
# 110/110 [==============================] - 0s 4ms/step - loss: 0.4116 - accuracy: 0.8141 - val_loss: 0.4757 - val_accuracy: 0.7721
# 78/78 [==============================] - 0s 2ms/step - loss: 0.4757 - accuracy: 0.7721
# Test Accuracy: 0.77

# %%
import matplotlib.pyplot as plt

def plot_learning_curve(history, epochs_to_skip=5):
    plt.figure(figsize=(12, 5))

    # Slice history to skip the first 'epochs_to_skip' epochs
    history_epochs = range(epochs_to_skip, len(history.history['accuracy']))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history_epochs, history.history['accuracy'][epochs_to_skip:], label='Train Accuracy')
    plt.plot(history_epochs, history.history['val_accuracy'][epochs_to_skip:], label='Validation Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history_epochs, history.history['loss'][epochs_to_skip:], label='Train Loss')
    plt.plot(history_epochs, history.history['val_loss'][epochs_to_skip:], label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_learning_curve(history)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Generate predictions on the test data
y_pred = best_model.predict(X_test)
y_pred_class = np.argmax(y_pred, axis=1)  # Convert to class labels (0 or 1)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_class)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
# Out:
# 78/78 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import classification_report

# Print precision, recall, and F1-score
report = classification_report(y_test, y_pred_class, target_names=label_encoder.classes_)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#                         precision    recall  f1-score   support
#
#     Engaged in fishing       0.63      0.94      0.75       913
# Under way using engine       0.95      0.67      0.79      1562
#
#               accuracy                           0.77      2475
#              macro avg       0.79      0.81      0.77      2475
#           weighted avg       0.83      0.77      0.78      2475

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve and AUC for each class
fpr, tpr, thresholds = roc_curve(y_test, y_pred[:, 1])  # Using class 1 for positive class
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal (random classifier)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
