# %% [markdown]
# 1. Filtering Files by Area and Copying Them
#
# We will create a method to filter files based on a specified geographical area and ensure vessels have at least 10 consecutive entries in the area.

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrow
import os
import pandas as pd
import numpy as np

def filter_files_by_area(input_folder, output_folder, area_bounds):
    """
    Filters vessel files to include only those with at least 10 consecutive entries in a specified area.
    Copies these files to the output folder and removes rows outside the area.
    """
    os.makedirs(output_folder, exist_ok=True)
    min_lat, max_lat, min_lon, max_lon = area_bounds

    files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]
    total_files = len(files)
    print(f"Processing {total_files} files from folder: {input_folder}")

    for idx, file in enumerate(files):
        print(f"({idx + 1}/{total_files}) Processing file: {file}")
        file_path = os.path.join(input_folder, file)
        
        try:
            # Read the file with specified dtypes
            df = pd.read_csv(
                file_path,
                dtype={
                    'Timestamp': str,
                    'Type of mobile': str,
                    'MMSI': str,
                    'Latitude': float,
                    'Longitude': float,
                    'Navigational status': str,
                    'ROT': float,
                    'SOG': float,
                    'COG': float,
                    'Heading': float,
                    'IMO': str,
                    'Callsign': str,
                    'Name': str,
                    'Ship type': str,
                    'Cargo type': str,
                    'Width': float,
                    'Length': float,
                    'Type of position fixing device': str,
                    'Draught': float,
                    'Destination': str,
                    'ETA': str,
                    'Data source type': str,
                    'A': str,
                    'B': str,
                    'C': str,
                    'D': str,
                },
                low_memory=False
            )
            print(f"Loaded file: {file}, Rows: {len(df)}")
            
            # Print the exact raw column names to check for issues
            print(f"Raw column names: {list(df.columns)}")  # Debug: raw column names

            # Strip leading "#" characters and any extra whitespace
            df.columns = df.columns.str.lstrip('#').str.strip()
            print(f"Cleaned column names: {list(df.columns)}")  # Debug: cleaned column names
            
            # Filter rows within the specified area
            df['Latitude'] = pd.to_numeric(df['Latitude'], errors='coerce')
            df['Longitude'] = pd.to_numeric(df['Longitude'], errors='coerce')

            in_area = (
                (df['Latitude'] >= min_lat) & 
                (df['Latitude'] <= max_lat) & 
                (df['Longitude'] >= min_lon) & 
                (df['Longitude'] <= max_lon)
            )
            print(f"Rows matching area condition: {in_area.sum()}")  # Debug: print number of rows matching area
            df_area = df[in_area].copy()  # Make a copy to avoid SettingWithCopyWarning
            print(f"Rows in area for {file}: {len(df_area)}")

            # Check for at least 10 consecutive entries in the area
            if not df_area.empty:
                # Sort by Timestamp (assuming consecutive entries are based on this field)
                df_area = df_area.sort_values(by='Timestamp').reset_index(drop=True)

                # Print a few sample Timestamps to check if they are consistent
                print(f"Sample Timestamps from {file}:")
                print(df_area['Timestamp'].head())  # Debug: print first few Timestamps
                
                # Convert Timestamp to datetime with the correct format
                try:
                    df_area['Timestamp'] = pd.to_datetime(df_area['Timestamp'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
                except Exception as e:
                    print(f"Error converting Timestamp in {file}: {e}")
                    continue

                # Check for any invalid Timestamps
                if df_area['Timestamp'].isna().any():
                    print(f"Error: Some Timestamps could not be parsed in {file}")
                    print("Invalid Timestamps:", df_area[df_area['Timestamp'].isna()])  # Debug: show rows with invalid Timestamps
                    continue  # Skip this file if conversion fails
                
                # Calculate the difference between consecutive timestamps
                df_area['time_diff'] = df_area['Timestamp'].diff().fillna(pd.Timedelta(seconds=0))

                # Define what you consider "consecutive" (e.g., within 1 minute)
                consecutive_threshold = pd.Timedelta(minutes=1)  # Adjust based on your criteria
                df_area['consecutive'] = (df_area['time_diff'] <= consecutive_threshold).cumsum()

                # Find the maximum number of consecutive entries
                max_consecutive_count = df_area['consecutive'].value_counts().max()
                print(f"Max consecutive entries for {file}: {max_consecutive_count}")

                # If there are at least 10 consecutive entries, save the file
                if max_consecutive_count >= 10:
                    output_path = os.path.join(output_folder, file)
                    df_area.drop(columns=['time_diff', 'consecutive'], inplace=True)  # Clean up temporary columns
                    df_area.to_csv(output_path, index=False)
                    print(f"File saved: {output_path}")
                else:
                    print(f"Skipped {file}: Insufficient consecutive entries in area.")
            else:
                print(f"Skipped {file}: No rows in specified area.")

        except Exception as e:
            print(f"Error processing {file}: {e}")

# %% [markdown]
# 2. Visualizing Data for a Specified Timeslot
#
# We will generate 10 map snippets, each showing positions and vector arrows for one vessel during the specified timeslot.

# %%
def visualize_timeslot(folder, timeslot, output_folder="map_snippets"):
    """
    Visualizes vessel positions and vectors for a specified timeslot.
    
    :param folder: Folder containing filtered vessel files
    :param timeslot: Tuple specifying start and end times (e.g., "10:30", "11:00")
    :param output_folder: Folder to save the map snippets
    """
    os.makedirs(output_folder, exist_ok=True)
    start_time, end_time = timeslot

    files = [f for f in os.listdir(folder) if f.endswith('.csv')][:10]  # Take up to 10 files
    for i, file in enumerate(files):
        file_path = os.path.join(folder, file)
        df = pd.read_csv(file_path)
        
        # Filter rows by timeslot
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])
        df_timeslot = df[(df['Timestamp'].dt.time >= pd.to_datetime(start_time).time()) &
                         (df['Timestamp'].dt.time <= pd.to_datetime(end_time).time())]

        if df_timeslot.shape[0] > 10:
            # Take 10 evenly spread rows
            df_timeslot = df_timeslot.iloc[::len(df_timeslot) // 10][:10]

        # Create map snippet
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_title(f"Vessel: {file} | Timeslot: {start_time}-{end_time}")

        for _, row in df_timeslot.iterrows():
            # Plot position
            ax.plot(row['Longitude'], row['Latitude'], 'bo')  # Blue point for position
            ax.text(row['Longitude'], row['Latitude'], row['Timestamp'].strftime('%H:%M'), fontsize=8)

            # Add vectors for COG/SOG
            cog_x = row['Longitude'] + 0.01 * row['SOG'] * np.cos(np.radians(row['COG']))
            cog_y = row['Latitude'] + 0.01 * row['SOG'] * np.sin(np.radians(row['COG']))
            ax.add_patch(FancyArrow(row['Longitude'], row['Latitude'], 
                                    cog_x - row['Longitude'], cog_y - row['Latitude'], 
                                    width=0.0002, color='red', label='COG/SOG'))

            # Add vectors for Heading
            heading_x = row['Longitude'] + 0.01 * np.cos(np.radians(row['Heading']))
            heading_y = row['Latitude'] + 0.01 * np.sin(np.radians(row['Heading']))
            ax.add_patch(FancyArrow(row['Longitude'], row['Latitude'], 
                                    heading_x - row['Longitude'], heading_y - row['Latitude'], 
                                    width=0.0002, color='green', label='Heading'))

        ax.set_xlabel("Longitude")
        ax.set_ylabel("Latitude")
        ax.legend(["Position", "COG/SOG", "Heading"], loc='upper left')

        # Save the map snippet
        snippet_path = os.path.join(output_folder, f"snippet_{i+1}.png")
        plt.savefig(snippet_path)
        plt.close(fig)
        print(f"Map snippet saved: {snippet_path}")

# %%
# Example usage:

# 1. Filter files by area
area_bounds = (53.0, 57.0, 7.0, 12.0)  # Define area (min_lat, max_lat, min_lon, max_lon)
input_folder = "grouped_files"
output_folder = "area_vessels"
filter_files_by_area(input_folder, output_folder, area_bounds)

# 2. Visualize timeslot
timeslot = ("10:30", "11:00")  # Define timeslot
visualize_timeslot(output_folder, timeslot)
# Out:
# Processing 1880 files from folder: grouped_files
# (1/1880) Processing file: mmsi_219012563.csv
# Loaded file: mmsi_219012563.csv, Rows: 216
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219012563.csv: 0
# Skipped mmsi_219012563.csv: No rows in specified area.
# (2/1880) Processing file: mmsi_219263000.csv
# Loaded file: mmsi_219263000.csv, Rows: 1318
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219263000.csv: 0
# Skipped mmsi_219263000.csv: No rows in specified area.
# (3/1880) Processing file: mmsi_219385000.csv
# Loaded file: mmsi_219385000.csv, Rows: 9160
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219385000.csv: 0
# Skipped mmsi_219385000.csv: No rows in specified area.
# (4/1880) Processing file: mmsi_374689000.csv
# Loaded file: mmsi_374689000.csv, Rows: 889
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 889
# Rows in area for mmsi_374689000.csv: 889
# Sample Timestamps from mmsi_374689000.csv:
# 0    26/11/2024 00:05:44
# 1    26/11/2024 00:05:44
# 2    26/11/2024 00:08:44
# 3    26/11/2024 00:08:44
# 4    26/11/2024 00:09:25
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_374689000.csv: 10
# File saved: area_vessels/mmsi_374689000.csv
# (5/1880) Processing file: mmsi_219001125.csv
# Loaded file: mmsi_219001125.csv, Rows: 2852
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219001125.csv: 0
# Skipped mmsi_219001125.csv: No rows in specified area.
# (6/1880) Processing file: mmsi_245901000.csv
# Loaded file: mmsi_245901000.csv, Rows: 7303
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_245901000.csv: 0
# Skipped mmsi_245901000.csv: No rows in specified area.
# (7/1880) Processing file: mmsi_636020853.csv
# Loaded file: mmsi_636020853.csv, Rows: 5181
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 5181
# Rows in area for mmsi_636020853.csv: 5181
# Sample Timestamps from mmsi_636020853.csv:
# 0    26/11/2024 00:00:38
# 1    26/11/2024 00:00:38
# 2    26/11/2024 00:00:38
# 3    26/11/2024 00:02:38
# 4    26/11/2024 00:02:38
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_636020853.csv: 4
# Skipped mmsi_636020853.csv: Insufficient consecutive entries in area.
# (8/1880) Processing file: mmsi_352002473.csv
# Loaded file: mmsi_352002473.csv, Rows: 16109
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 9516
# Rows in area for mmsi_352002473.csv: 9516
# Sample Timestamps from mmsi_352002473.csv:
# 0    26/11/2024 00:00:09
# 1    26/11/2024 00:00:09
# 2    26/11/2024 00:00:09
# 3    26/11/2024 00:00:18
# 4    26/11/2024 00:00:18
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_352002473.csv: 1
# Skipped mmsi_352002473.csv: Insufficient consecutive entries in area.
# (9/1880) Processing file: mmsi_205689000.csv
# Loaded file: mmsi_205689000.csv, Rows: 9017
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 9014
# Rows in area for mmsi_205689000.csv: 9014
# Sample Timestamps from mmsi_205689000.csv:
# 0    26/11/2024 00:02:37
# 1    26/11/2024 00:05:38
# 2    26/11/2024 00:07:17
# 3    26/11/2024 00:08:38
# 4    26/11/2024 00:11:38
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_205689000.csv: 30
# File saved: area_vessels/mmsi_205689000.csv
# (10/1880) Processing file: mmsi_244234000.csv
# Loaded file: mmsi_244234000.csv, Rows: 3402
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 2816
# Rows in area for mmsi_244234000.csv: 2816
# Sample Timestamps from mmsi_244234000.csv:
# 0    26/11/2024 09:20:35
# 1    26/11/2024 09:21:15
# 2    26/11/2024 09:58:55
# 3    26/11/2024 09:59:55
# 4    26/11/2024 10:00:05
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_244234000.csv: 8
# Skipped mmsi_244234000.csv: Insufficient consecutive entries in area.
# (11/1880) Processing file: mmsi_219033037.csv
# Loaded file: mmsi_219033037.csv, Rows: 865
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 865
# Rows in area for mmsi_219033037.csv: 865
# Sample Timestamps from mmsi_219033037.csv:
# 0    26/11/2024 00:02:45
# 1    26/11/2024 00:05:52
# 2    26/11/2024 00:06:31
# 3    26/11/2024 00:07:17
# 4    26/11/2024 00:07:19
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_219033037.csv: 82
# File saved: area_vessels/mmsi_219033037.csv
# (12/1880) Processing file: mmsi_246607000.csv
# Loaded file: mmsi_246607000.csv, Rows: 21726
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 21726
# Rows in area for mmsi_246607000.csv: 21726
# Sample Timestamps from mmsi_246607000.csv:
# 0    26/11/2024 00:00:06
# 1    26/11/2024 00:00:06
# 2    26/11/2024 00:00:17
# 3    26/11/2024 00:00:17
# 4    26/11/2024 00:00:27
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_246607000.csv: 1
# Skipped mmsi_246607000.csv: Insufficient consecutive entries in area.
# (13/1880) Processing file: mmsi_211921000.csv
# Loaded file: mmsi_211921000.csv, Rows: 5333
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_211921000.csv: 0
# Skipped mmsi_211921000.csv: No rows in specified area.
# (14/1880) Processing file: mmsi_246396000.csv
# Loaded file: mmsi_246396000.csv, Rows: 147
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 147
# Rows in area for mmsi_246396000.csv: 147
# Sample Timestamps from mmsi_246396000.csv:
# 0    26/11/2024 19:10:38
# 1    26/11/2024 19:12:15
# 2    26/11/2024 19:12:38
# 3    26/11/2024 19:13:39
# 4    26/11/2024 19:13:52
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_246396000.csv: 10
# File saved: area_vessels/mmsi_246396000.csv
# (15/1880) Processing file: mmsi_219005887.csv
# Loaded file: mmsi_219005887.csv, Rows: 9614
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 9614
# Rows in area for mmsi_219005887.csv: 9614
# Sample Timestamps from mmsi_219005887.csv:
# 0    26/11/2024 00:00:00
# 1    26/11/2024 00:00:10
# 2    26/11/2024 00:00:21
# 3    26/11/2024 00:00:30
# 4    26/11/2024 00:00:41
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_219005887.csv: 1
# Skipped mmsi_219005887.csv: Insufficient consecutive entries in area.
# (16/1880) Processing file: mmsi_209864000.csv
# Loaded file: mmsi_209864000.csv, Rows: 4731
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_209864000.csv: 0
# Skipped mmsi_209864000.csv: No rows in specified area.
# (17/1880) Processing file: mmsi_636019030.csv
# Loaded file: mmsi_636019030.csv, Rows: 611
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_636019030.csv: 0
# Skipped mmsi_636019030.csv: No rows in specified area.
# (18/1880) Processing file: mmsi_266460000.csv
# Loaded file: mmsi_266460000.csv, Rows: 570
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_266460000.csv: 0
# Skipped mmsi_266460000.csv: No rows in specified area.
# (19/1880) Processing file: mmsi_220205000.csv
# Loaded file: mmsi_220205000.csv, Rows: 7728
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 7728
# Rows in area for mmsi_220205000.csv: 7728
# Sample Timestamps from mmsi_220205000.csv:
# 0    26/11/2024 00:00:03
# 1    26/11/2024 00:00:12
# 2    26/11/2024 00:00:24
# 3    26/11/2024 00:00:32
# 4    26/11/2024 00:00:44
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_220205000.csv: 1
# Skipped mmsi_220205000.csv: Insufficient consecutive entries in area.
# (20/1880) Processing file: mmsi_250370000.csv
# Loaded file: mmsi_250370000.csv, Rows: 3085
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 175
# Rows in area for mmsi_250370000.csv: 175
# Sample Timestamps from mmsi_250370000.csv:
# 0    26/11/2024 14:45:38
# 1    26/11/2024 14:45:46
# 2    26/11/2024 14:46:16
# 3    26/11/2024 14:46:28
# 4    26/11/2024 19:05:55
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_250370000.csv: 2
# Skipped mmsi_250370000.csv: Insufficient consecutive entries in area.
# (21/1880) Processing file: mmsi_354340000.csv
# Loaded file: mmsi_354340000.csv, Rows: 301
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 301
# Rows in area for mmsi_354340000.csv: 301
# Sample Timestamps from mmsi_354340000.csv:
# 0    26/11/2024 11:42:06
# 1    26/11/2024 11:42:07
# 2    26/11/2024 11:42:08
# 3    26/11/2024 11:42:55
# 4    26/11/2024 11:43:34
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_354340000.csv: 6
# Skipped mmsi_354340000.csv: Insufficient consecutive entries in area.
# (22/1880) Processing file: mmsi_636018508.csv
# Loaded file: mmsi_636018508.csv, Rows: 2926
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 2461
# Rows in area for mmsi_636018508.csv: 2461
# Sample Timestamps from mmsi_636018508.csv:
# 0    26/11/2024 19:28:40
# 1    26/11/2024 19:28:59
# 2    26/11/2024 19:29:19
# 3    26/11/2024 19:29:30
# 4    26/11/2024 19:29:40
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_636018508.csv: 1
# Skipped mmsi_636018508.csv: Insufficient consecutive entries in area.
# (23/1880) Processing file: mmsi_219001275.csv
# Loaded file: mmsi_219001275.csv, Rows: 13736
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 13736
# Rows in area for mmsi_219001275.csv: 13736
# Sample Timestamps from mmsi_219001275.csv:
# 0    26/11/2024 00:00:01
# 1    26/11/2024 00:00:01
# 2    26/11/2024 00:00:10
# 3    26/11/2024 00:00:10
# 4    26/11/2024 00:00:20
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_219001275.csv: 2
# Skipped mmsi_219001275.csv: Insufficient consecutive entries in area.
# (24/1880) Processing file: mmsi_211445200.csv
# Loaded file: mmsi_211445200.csv, Rows: 1
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 1
# Rows in area for mmsi_211445200.csv: 1
# Sample Timestamps from mmsi_211445200.csv:
# 0    26/11/2024 21:43:24
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_211445200.csv: 1
# Skipped mmsi_211445200.csv: Insufficient consecutive entries in area.
# (25/1880) Processing file: mmsi_219019010.csv
# Loaded file: mmsi_219019010.csv, Rows: 16327
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219019010.csv: 0
# Skipped mmsi_219019010.csv: No rows in specified area.
# (26/1880) Processing file: mmsi_374309000.csv
# Loaded file: mmsi_374309000.csv, Rows: 1420
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_374309000.csv: 0
# Skipped mmsi_374309000.csv: No rows in specified area.
# (27/1880) Processing file: mmsi_211405010.csv
# Loaded file: mmsi_211405010.csv, Rows: 337
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 337
# Rows in area for mmsi_211405010.csv: 337
# Sample Timestamps from mmsi_211405010.csv:
# 0    26/11/2024 00:00:45
# 1    26/11/2024 00:05:38
# 2    26/11/2024 00:06:45
# 3    26/11/2024 00:09:45
# 4    26/11/2024 00:12:48
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_211405010.csv: 222
# File saved: area_vessels/mmsi_211405010.csv
# (28/1880) Processing file: mmsi_219032932.csv
# Loaded file: mmsi_219032932.csv, Rows: 7264
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219032932.csv: 0
# Skipped mmsi_219032932.csv: No rows in specified area.
# (29/1880) Processing file: mmsi_268246900.csv
# Loaded file: mmsi_268246900.csv, Rows: 4985
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_268246900.csv: 0
# Skipped mmsi_268246900.csv: No rows in specified area.
# (30/1880) Processing file: mmsi_219029785.csv
# Loaded file: mmsi_219029785.csv, Rows: 1031
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 1031
# Rows in area for mmsi_219029785.csv: 1031
# Sample Timestamps from mmsi_219029785.csv:
# 0    26/11/2024 00:02:38
# 1    26/11/2024 00:02:38
# 2    26/11/2024 00:05:38
# 3    26/11/2024 00:05:38
# 4    26/11/2024 00:06:03
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_219029785.csv: 6
# Skipped mmsi_219029785.csv: Insufficient consecutive entries in area.
# (31/1880) Processing file: mmsi_218098000.csv
# Loaded file: mmsi_218098000.csv, Rows: 1574
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_218098000.csv: 0
# Skipped mmsi_218098000.csv: No rows in specified area.
# (32/1880) Processing file: mmsi_257819000.csv
# Loaded file: mmsi_257819000.csv, Rows: 1866
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_257819000.csv: 0
# Skipped mmsi_257819000.csv: No rows in specified area.
# (33/1880) Processing file: mmsi_244482000.csv
# Loaded file: mmsi_244482000.csv, Rows: 7058
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 7058
# Rows in area for mmsi_244482000.csv: 7058
# Sample Timestamps from mmsi_244482000.csv:
# 0    26/11/2024 00:00:08
# 1    26/11/2024 00:00:08
# 2    26/11/2024 00:00:16
# 3    26/11/2024 00:00:16
# 4    26/11/2024 00:00:19
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_244482000.csv: 6
# Skipped mmsi_244482000.csv: Insufficient consecutive entries in area.
# (34/1880) Processing file: mmsi_636022218.csv
# Loaded file: mmsi_636022218.csv, Rows: 4643
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_636022218.csv: 0
# Skipped mmsi_636022218.csv: No rows in specified area.
# (35/1880) Processing file: mmsi_219309000.csv
# Loaded file: mmsi_219309000.csv, Rows: 1298
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219309000.csv: 0
# Skipped mmsi_219309000.csv: No rows in specified area.
# (36/1880) Processing file: mmsi_246777000.csv
# Loaded file: mmsi_246777000.csv, Rows: 1307
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 1307
# Rows in area for mmsi_246777000.csv: 1307
# Sample Timestamps from mmsi_246777000.csv:
# 0    26/11/2024 00:01:31
# 1    26/11/2024 00:01:31
# 2    26/11/2024 00:04:31
# 3    26/11/2024 00:04:31
# 4    26/11/2024 00:04:44
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_246777000.csv: 3
# Skipped mmsi_246777000.csv: Insufficient consecutive entries in area.
# (37/1880) Processing file: mmsi_563223700.csv
# Loaded file: mmsi_563223700.csv, Rows: 10955
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 10955
# Rows in area for mmsi_563223700.csv: 10955
# Sample Timestamps from mmsi_563223700.csv:
# 0    26/11/2024 00:01:58
# 1    26/11/2024 00:04:49
# 2    26/11/2024 00:04:51
# 3    26/11/2024 00:07:58
# 4    26/11/2024 00:10:49
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_563223700.csv: 17
# File saved: area_vessels/mmsi_563223700.csv
# (38/1880) Processing file: mmsi_244475000.csv
# Loaded file: mmsi_244475000.csv, Rows: 23001
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 23001
# Rows in area for mmsi_244475000.csv: 23001
# Sample Timestamps from mmsi_244475000.csv:
# 0    26/11/2024 00:00:08
# 1    26/11/2024 00:00:08
# 2    26/11/2024 00:00:16
# 3    26/11/2024 00:00:27
# 4    26/11/2024 00:00:38
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_244475000.csv: 1
# Skipped mmsi_244475000.csv: Insufficient consecutive entries in area.
# (39/1880) Processing file: mmsi_219007314.csv
# Loaded file: mmsi_219007314.csv, Rows: 673
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219007314.csv: 0
# Skipped mmsi_219007314.csv: No rows in specified area.
# (40/1880) Processing file: mmsi_220256000.csv
# Loaded file: mmsi_220256000.csv, Rows: 7634
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_220256000.csv: 0
# Skipped mmsi_220256000.csv: No rows in specified area.
# (41/1880) Processing file: mmsi_212900000.csv
# Loaded file: mmsi_212900000.csv, Rows: 8515
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 8515
# Rows in area for mmsi_212900000.csv: 8515
# Sample Timestamps from mmsi_212900000.csv:
# 0    26/11/2024 09:03:28
# 1    26/11/2024 09:04:09
# 2    26/11/2024 09:04:49
# 3    26/11/2024 09:05:09
# 4    26/11/2024 09:05:28
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_212900000.csv: 5
# Skipped mmsi_212900000.csv: Insufficient consecutive entries in area.
# (42/1880) Processing file: mmsi_209114000.csv
# Loaded file: mmsi_209114000.csv, Rows: 2473
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_209114000.csv: 0
# Skipped mmsi_209114000.csv: No rows in specified area.
# (43/1880) Processing file: mmsi_220088000.csv
# Loaded file: mmsi_220088000.csv, Rows: 14500
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_220088000.csv: 0
# Skipped mmsi_220088000.csv: No rows in specified area.
# (44/1880) Processing file: mmsi_211727510.csv
# Loaded file: mmsi_211727510.csv, Rows: 12432
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 7881
# Rows in area for mmsi_211727510.csv: 7881
# Sample Timestamps from mmsi_211727510.csv:
# 0    26/11/2024 05:58:14
# 1    26/11/2024 05:58:14
# 2    26/11/2024 05:58:19
# 3    26/11/2024 05:58:25
# 4    26/11/2024 05:58:25
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_211727510.csv: 2
# Skipped mmsi_211727510.csv: Insufficient consecutive entries in area.
# (45/1880) Processing file: mmsi_219001039.csv
# Loaded file: mmsi_219001039.csv, Rows: 8149
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 8149
# Rows in area for mmsi_219001039.csv: 8149
# Sample Timestamps from mmsi_219001039.csv:
# 0    26/11/2024 00:00:01
# 1    26/11/2024 00:00:12
# 2    26/11/2024 00:00:21
# 3    26/11/2024 00:00:31
# 4    26/11/2024 00:00:52
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_219001039.csv: 1
# Skipped mmsi_219001039.csv: Insufficient consecutive entries in area.
# (46/1880) Processing file: mmsi_219000217.csv
# Loaded file: mmsi_219000217.csv, Rows: 1095
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219000217.csv: 0
# Skipped mmsi_219000217.csv: No rows in specified area.
# (47/1880) Processing file: mmsi_265866000.csv
# Loaded file: mmsi_265866000.csv, Rows: 9126
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_265866000.csv: 0
# Skipped mmsi_265866000.csv: No rows in specified area.
# (48/1880) Processing file: mmsi_636018261.csv
# Loaded file: mmsi_636018261.csv, Rows: 3200
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 2430
# Rows in area for mmsi_636018261.csv: 2430
# Sample Timestamps from mmsi_636018261.csv:
# 0    26/11/2024 00:00:07
# 1    26/11/2024 00:00:07
# 2    26/11/2024 00:00:07
# 3    26/11/2024 00:00:18
# 4    26/11/2024 00:00:18
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_636018261.csv: 1
# Skipped mmsi_636018261.csv: Insufficient consecutive entries in area.
# (49/1880) Processing file: mmsi_219012076.csv
# Loaded file: mmsi_219012076.csv, Rows: 778
# ...
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 12611
# Rows in area for mmsi_244054000.csv: 12611
# Sample Timestamps from mmsi_244054000.csv:
# 0    26/11/2024 00:02:48
# 1    26/11/2024 00:02:48
# 2    26/11/2024 00:02:48
# 3    26/11/2024 00:05:41
# 4    26/11/2024 00:05:41
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_244054000.csv: 3
# Skipped mmsi_244054000.csv: Insufficient consecutive entries in area.
# (1867/1880) Processing file: mmsi_255802950.csv
# Loaded file: mmsi_255802950.csv, Rows: 1629
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 1629
# Rows in area for mmsi_255802950.csv: 1629
# Sample Timestamps from mmsi_255802950.csv:
# 0    26/11/2024 00:00:59
# 1    26/11/2024 00:00:59
# 2    26/11/2024 00:01:05
# 3    26/11/2024 00:01:05
# 4    26/11/2024 00:03:59
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_255802950.csv: 10
# File saved: area_vessels/mmsi_255802950.csv
# (1868/1880) Processing file: mmsi_211302890.csv
# Loaded file: mmsi_211302890.csv, Rows: 1340
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 1340
# Rows in area for mmsi_211302890.csv: 1340
# Sample Timestamps from mmsi_211302890.csv:
# 0    26/11/2024 00:00:11
# 1    26/11/2024 00:00:11
# 2    26/11/2024 00:02:09
# 3    26/11/2024 00:02:09
# 4    26/11/2024 00:05:27
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_211302890.csv: 5
# Skipped mmsi_211302890.csv: Insufficient consecutive entries in area.
# (1869/1880) Processing file: mmsi_261003012.csv
# Loaded file: mmsi_261003012.csv, Rows: 639
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 493
# Rows in area for mmsi_261003012.csv: 493
# Sample Timestamps from mmsi_261003012.csv:
# 0    26/11/2024 00:15:22
# 1    26/11/2024 00:17:03
# 2    26/11/2024 00:19:08
# 3    26/11/2024 00:21:02
# 4    26/11/2024 00:22:22
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_261003012.csv: 9
# Skipped mmsi_261003012.csv: Insufficient consecutive entries in area.
# (1870/1880) Processing file: mmsi_219024597.csv
# Loaded file: mmsi_219024597.csv, Rows: 6226
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 6226
# Rows in area for mmsi_219024597.csv: 6226
# Sample Timestamps from mmsi_219024597.csv:
# 0    26/11/2024 00:01:56
# 1    26/11/2024 00:01:56
# 2    26/11/2024 00:04:47
# 3    26/11/2024 00:04:47
# 4    26/11/2024 00:07:28
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_219024597.csv: 5
# Skipped mmsi_219024597.csv: Insufficient consecutive entries in area.
# (1871/1880) Processing file: mmsi_477624400.csv
# Loaded file: mmsi_477624400.csv, Rows: 10722
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 4604
# Rows in area for mmsi_477624400.csv: 4604
# Sample Timestamps from mmsi_477624400.csv:
# 0    26/11/2024 00:00:04
# 1    26/11/2024 00:00:04
# 2    26/11/2024 00:00:04
# 3    26/11/2024 00:00:13
# 4    26/11/2024 00:00:13
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_477624400.csv: 1
# Skipped mmsi_477624400.csv: Insufficient consecutive entries in area.
# (1872/1880) Processing file: mmsi_219012639.csv
# Loaded file: mmsi_219012639.csv, Rows: 9171
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 9171
# Rows in area for mmsi_219012639.csv: 9171
# Sample Timestamps from mmsi_219012639.csv:
# 0    26/11/2024 00:00:06
# 1    26/11/2024 00:00:17
# 2    26/11/2024 00:00:26
# 3    26/11/2024 00:00:37
# 4    26/11/2024 00:00:45
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_219012639.csv: 1
# Skipped mmsi_219012639.csv: Insufficient consecutive entries in area.
# (1873/1880) Processing file: mmsi_255806525.csv
# Loaded file: mmsi_255806525.csv, Rows: 12540
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 4385
# Rows in area for mmsi_255806525.csv: 4385
# Sample Timestamps from mmsi_255806525.csv:
# 0    26/11/2024 19:20:42
# 1    26/11/2024 19:20:52
# 2    26/11/2024 19:20:52
# 3    26/11/2024 19:21:02
# 4    26/11/2024 19:21:12
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_255806525.csv: 1
# Skipped mmsi_255806525.csv: Insufficient consecutive entries in area.
# (1874/1880) Processing file: mmsi_255806328.csv
# Loaded file: mmsi_255806328.csv, Rows: 4629
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_255806328.csv: 0
# Skipped mmsi_255806328.csv: No rows in specified area.
# (1875/1880) Processing file: mmsi_211833390.csv
# Loaded file: mmsi_211833390.csv, Rows: 8159
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 920
# Rows in area for mmsi_211833390.csv: 920
# Sample Timestamps from mmsi_211833390.csv:
# 0    26/11/2024 00:00:09
# 1    26/11/2024 00:00:19
# 2    26/11/2024 00:00:29
# 3    26/11/2024 00:00:29
# 4    26/11/2024 00:00:39
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_211833390.csv: 4
# Skipped mmsi_211833390.csv: Insufficient consecutive entries in area.
# (1876/1880) Processing file: mmsi_219018684.csv
# Loaded file: mmsi_219018684.csv, Rows: 1217
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219018684.csv: 0
# Skipped mmsi_219018684.csv: No rows in specified area.
# (1877/1880) Processing file: mmsi_352001928.csv
# Loaded file: mmsi_352001928.csv, Rows: 564
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 564
# Rows in area for mmsi_352001928.csv: 564
# Sample Timestamps from mmsi_352001928.csv:
# 0    26/11/2024 00:04:09
# 1    26/11/2024 00:07:10
# 2    26/11/2024 00:07:10
# 3    26/11/2024 00:08:00
# 4    26/11/2024 00:10:11
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_352001928.csv: 25
# File saved: area_vessels/mmsi_352001928.csv
# (1878/1880) Processing file: mmsi_219021176.csv
# Loaded file: mmsi_219021176.csv, Rows: 21149
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_219021176.csv: 0
# Skipped mmsi_219021176.csv: No rows in specified area.
# (1879/1880) Processing file: mmsi_245875000.csv
# Loaded file: mmsi_245875000.csv, Rows: 1218
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 1218
# Rows in area for mmsi_245875000.csv: 1218
# Sample Timestamps from mmsi_245875000.csv:
# 0    26/11/2024 00:00:27
# 1    26/11/2024 00:00:27
# 2    26/11/2024 00:03:20
# 3    26/11/2024 00:03:20
# 4    26/11/2024 00:03:29
# Name: Timestamp, dtype: object
# Max consecutive entries for mmsi_245875000.csv: 5
# Skipped mmsi_245875000.csv: Insufficient consecutive entries in area.
# (1880/1880) Processing file: mmsi_257312000.csv
# Loaded file: mmsi_257312000.csv, Rows: 152
# Raw column names: ['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Cleaned column names: ['Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude', 'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO', 'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length', 'Type of position fixing device', 'Draught', 'Destination', 'ETA', 'Data source type', 'A', 'B', 'C', 'D']
# Rows matching area condition: 0
# Rows in area for mmsi_257312000.csv: 0
# Skipped mmsi_257312000.csv: No rows in specified area.
# Map snippet saved: map_snippets/snippet_1.png
# Map snippet saved: map_snippets/snippet_2.png
# Map snippet saved: map_snippets/snippet_3.png
# Map snippet saved: map_snippets/snippet_4.png
# Map snippet saved: map_snippets/snippet_5.png
# Map snippet saved: map_snippets/snippet_6.png
# Map snippet saved: map_snippets/snippet_7.png
# Map snippet saved: map_snippets/snippet_8.png
# Map snippet saved: map_snippets/snippet_9.png
# Map snippet saved: map_snippets/snippet_10.png
