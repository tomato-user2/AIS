# %% [markdown]
# 1. Filtering Files by Area and Copying Them
#
# We will create a method to filter files based on a specified geographical area and ensure vessels have at least 10 consecutive entries in the area.

# %%
def filter_files_by_area(input_folder, output_folder, area_bounds):
    """
    Filters vessel files to include only those with at least 10 consecutive entries in a specified area.
    Copies these files to the output folder and removes rows outside the area.

    :param input_folder: Folder containing input files (vessel data)
    :param output_folder: Folder to save filtered files
    :param area_bounds: Tuple with bounds (min_lat, max_lat, min_lon, max_lon)
    """
    os.makedirs(output_folder, exist_ok=True)
    min_lat, max_lat, min_lon, max_lon = area_bounds

    files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]
    total_files = len(files)
    print(f"Processing {total_files} files from folder: {input_folder}")

    for idx, file in enumerate(files):
        print(f"({idx + 1}/{total_files}) Processing file: {file}")
        file_path = os.path.join(input_folder, file)
        
        try:
            # Read the file with specified dtypes
            df = pd.read_csv(
                file_path,
                dtype={
                    'Timestamp': str,
                    'Type of mobile': str,
                    'MMSI': str,
                    'Latitude': float,
                    'Longitude': float,
                    'Navigational status': str,
                    'ROT': float,
                    'SOG': float,
                    'COG': float,
                    'Heading': float,
                    'IMO': str,
                    'Callsign': str,
                    'Name': str,
                    'Ship type': str,
                    'Cargo type': str,
                    'Width': float,
                    'Length': float,
                    'Type of position fixing device': str,
                    'Draught': float,
                    'Destination': str,
                    'ETA': str,
                    'Data source type': str,
                    'A': str,
                    'B': str,
                    'C': str,
                    'D': str,
                },
                low_memory=False
            )
            print(f"Loaded file: {file}, Rows: {len(df)}")
            
            # Filter rows within the specified area
            in_area = (
                (df['Latitude'] >= min_lat) & 
                (df['Latitude'] <= max_lat) & 
                (df['Longitude'] >= min_lon) & 
                (df['Longitude'] <= max_lon)
            )
            df_area = df[in_area].copy()  # Make a copy to avoid SettingWithCopyWarning
            print(f"Rows in area for {file}: {len(df_area)}")

            # Check for at least 10 consecutive entries in the area
            if not df_area.empty:
                df_area['consecutive'] = (df_area.index.to_series().diff() == 1).cumsum()
                max_consecutive_count = df_area['consecutive'].value_counts().max()
                print(f"Max consecutive entries for {file}: {max_consecutive_count}")

                if max_consecutive_count >= 10:
                    # Save filtered data to the output folder
                    output_path = os.path.join(output_folder, file)
                    df_area.drop(columns=['consecutive'], inplace=True)  # Remove temporary column
                    df_area.to_csv(output_path, index=False)
                    print(f"File saved: {output_path}")
                else:
                    print(f"Skipped {file}: Insufficient consecutive entries in area.")
            else:
                print(f"Skipped {file}: No rows in specified area.")

        except Exception as e:
            print(f"Error processing {file}: {e}")

# %% [markdown]
# 2. Visualizing Data for a Specified Timeslot
#
# We will generate 10 map snippets, each showing positions and vector arrows for one vessel during the specified timeslot.

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrow

def visualize_timeslot(folder, timeslot, output_folder="map_snippets"):
    """
    Visualizes vessel positions and vectors for a specified timeslot.
    
    :param folder: Folder containing filtered vessel files
    :param timeslot: Tuple specifying start and end times (e.g., "10:30", "11:00")
    :param output_folder: Folder to save the map snippets
    """
    os.makedirs(output_folder, exist_ok=True)
    start_time, end_time = timeslot

    files = [f for f in os.listdir(folder) if f.endswith('.csv')][:10]  # Take up to 10 files
    for i, file in enumerate(files):
        file_path = os.path.join(folder, file)
        df = pd.read_csv(file_path)
        
        # Filter rows by timeslot
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])
        df_timeslot = df[(df['Timestamp'].dt.time >= pd.to_datetime(start_time).time()) &
                         (df['Timestamp'].dt.time <= pd.to_datetime(end_time).time())]

        if df_timeslot.shape[0] > 10:
            # Take 10 evenly spread rows
            df_timeslot = df_timeslot.iloc[::len(df_timeslot) // 10][:10]

        # Create map snippet
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_title(f"Vessel: {file} | Timeslot: {start_time}-{end_time}")

        for _, row in df_timeslot.iterrows():
            # Plot position
            ax.plot(row['Longitude'], row['Latitude'], 'bo')  # Blue point for position
            ax.text(row['Longitude'], row['Latitude'], row['Timestamp'].strftime('%H:%M'), fontsize=8)

            # Add vectors for COG/SOG
            cog_x = row['Longitude'] + 0.01 * row['SOG'] * np.cos(np.radians(row['COG']))
            cog_y = row['Latitude'] + 0.01 * row['SOG'] * np.sin(np.radians(row['COG']))
            ax.add_patch(FancyArrow(row['Longitude'], row['Latitude'], 
                                    cog_x - row['Longitude'], cog_y - row['Latitude'], 
                                    width=0.0002, color='red', label='COG/SOG'))

            # Add vectors for Heading
            heading_x = row['Longitude'] + 0.01 * np.cos(np.radians(row['Heading']))
            heading_y = row['Latitude'] + 0.01 * np.sin(np.radians(row['Heading']))
            ax.add_patch(FancyArrow(row['Longitude'], row['Latitude'], 
                                    heading_x - row['Longitude'], heading_y - row['Latitude'], 
                                    width=0.0002, color='green', label='Heading'))

        ax.set_xlabel("Longitude")
        ax.set_ylabel("Latitude")
        ax.legend(["Position", "COG/SOG", "Heading"], loc='upper left')

        # Save the map snippet
        snippet_path = os.path.join(output_folder, f"snippet_{i+1}.png")
        plt.savefig(snippet_path)
        plt.close(fig)
        print(f"Map snippet saved: {snippet_path}")

# %%
# Example usage:

# 1. Filter files by area
area_bounds = (53.0, 57.0, 7.0, 12.0)  # Define area (min_lat, max_lat, min_lon, max_lon)
input_folder = "grouped_files"
output_folder = "area_vessels"
filter_files_by_area(input_folder, output_folder, area_bounds)

# 2. Visualize timeslot
timeslot = ("10:30", "11:00")  # Define timeslot
visualize_timeslot(output_folder, timeslot)
# Out:
# Processing 1880 files from folder: grouped_files
# (1/1880) Processing file: mmsi_219012563.csv
# Loaded file: mmsi_219012563.csv, Rows: 216
# Rows in area for mmsi_219012563.csv: 0
# Skipped mmsi_219012563.csv: No rows in specified area.
# (2/1880) Processing file: mmsi_219263000.csv
# Loaded file: mmsi_219263000.csv, Rows: 1318
# Rows in area for mmsi_219263000.csv: 0
# Skipped mmsi_219263000.csv: No rows in specified area.
# (3/1880) Processing file: mmsi_219385000.csv
# Loaded file: mmsi_219385000.csv, Rows: 9160
# Rows in area for mmsi_219385000.csv: 0
# Skipped mmsi_219385000.csv: No rows in specified area.
# (4/1880) Processing file: mmsi_374689000.csv
# Loaded file: mmsi_374689000.csv, Rows: 889
# Rows in area for mmsi_374689000.csv: 889
# Max consecutive entries for mmsi_374689000.csv: 1
# Skipped mmsi_374689000.csv: Insufficient consecutive entries in area.
# (5/1880) Processing file: mmsi_219001125.csv
# Loaded file: mmsi_219001125.csv, Rows: 2852
# Rows in area for mmsi_219001125.csv: 0
# Skipped mmsi_219001125.csv: No rows in specified area.
# (6/1880) Processing file: mmsi_245901000.csv
# Loaded file: mmsi_245901000.csv, Rows: 7303
# Rows in area for mmsi_245901000.csv: 0
# Skipped mmsi_245901000.csv: No rows in specified area.
# (7/1880) Processing file: mmsi_636020853.csv
# Loaded file: mmsi_636020853.csv, Rows: 5181
# Rows in area for mmsi_636020853.csv: 5181
# Max consecutive entries for mmsi_636020853.csv: 1
# Skipped mmsi_636020853.csv: Insufficient consecutive entries in area.
# (8/1880) Processing file: mmsi_352002473.csv
# Loaded file: mmsi_352002473.csv, Rows: 16109
# Rows in area for mmsi_352002473.csv: 9516
# Max consecutive entries for mmsi_352002473.csv: 1
# Skipped mmsi_352002473.csv: Insufficient consecutive entries in area.
# (9/1880) Processing file: mmsi_205689000.csv
# Loaded file: mmsi_205689000.csv, Rows: 9017
# Rows in area for mmsi_205689000.csv: 9014
# Max consecutive entries for mmsi_205689000.csv: 2
# Skipped mmsi_205689000.csv: Insufficient consecutive entries in area.
# (10/1880) Processing file: mmsi_244234000.csv
# Loaded file: mmsi_244234000.csv, Rows: 3402
# Rows in area for mmsi_244234000.csv: 2816
# Max consecutive entries for mmsi_244234000.csv: 1
# Skipped mmsi_244234000.csv: Insufficient consecutive entries in area.
# (11/1880) Processing file: mmsi_219033037.csv
# Loaded file: mmsi_219033037.csv, Rows: 865
# Rows in area for mmsi_219033037.csv: 865
# Max consecutive entries for mmsi_219033037.csv: 1
# Skipped mmsi_219033037.csv: Insufficient consecutive entries in area.
# (12/1880) Processing file: mmsi_246607000.csv
# Loaded file: mmsi_246607000.csv, Rows: 21726
# Rows in area for mmsi_246607000.csv: 21726
# Max consecutive entries for mmsi_246607000.csv: 1
# Skipped mmsi_246607000.csv: Insufficient consecutive entries in area.
# (13/1880) Processing file: mmsi_211921000.csv
# Loaded file: mmsi_211921000.csv, Rows: 5333
# Rows in area for mmsi_211921000.csv: 0
# Skipped mmsi_211921000.csv: No rows in specified area.
# (14/1880) Processing file: mmsi_246396000.csv
# Loaded file: mmsi_246396000.csv, Rows: 147
# Rows in area for mmsi_246396000.csv: 147
# Max consecutive entries for mmsi_246396000.csv: 1
# Skipped mmsi_246396000.csv: Insufficient consecutive entries in area.
# (15/1880) Processing file: mmsi_219005887.csv
# Loaded file: mmsi_219005887.csv, Rows: 9614
# Rows in area for mmsi_219005887.csv: 9614
# Max consecutive entries for mmsi_219005887.csv: 1
# Skipped mmsi_219005887.csv: Insufficient consecutive entries in area.
# (16/1880) Processing file: mmsi_209864000.csv
# Loaded file: mmsi_209864000.csv, Rows: 4731
# Rows in area for mmsi_209864000.csv: 0
# Skipped mmsi_209864000.csv: No rows in specified area.
# (17/1880) Processing file: mmsi_636019030.csv
# Loaded file: mmsi_636019030.csv, Rows: 611
# Rows in area for mmsi_636019030.csv: 0
# Skipped mmsi_636019030.csv: No rows in specified area.
# (18/1880) Processing file: mmsi_266460000.csv
# Loaded file: mmsi_266460000.csv, Rows: 570
# Rows in area for mmsi_266460000.csv: 0
# Skipped mmsi_266460000.csv: No rows in specified area.
# (19/1880) Processing file: mmsi_220205000.csv
# Loaded file: mmsi_220205000.csv, Rows: 7728
# Rows in area for mmsi_220205000.csv: 7728
# Max consecutive entries for mmsi_220205000.csv: 1
# Skipped mmsi_220205000.csv: Insufficient consecutive entries in area.
# (20/1880) Processing file: mmsi_250370000.csv
# Loaded file: mmsi_250370000.csv, Rows: 3085
# Rows in area for mmsi_250370000.csv: 175
# Max consecutive entries for mmsi_250370000.csv: 2
# Skipped mmsi_250370000.csv: Insufficient consecutive entries in area.
# (21/1880) Processing file: mmsi_354340000.csv
# Loaded file: mmsi_354340000.csv, Rows: 301
# Rows in area for mmsi_354340000.csv: 301
# Max consecutive entries for mmsi_354340000.csv: 1
# Skipped mmsi_354340000.csv: Insufficient consecutive entries in area.
# (22/1880) Processing file: mmsi_636018508.csv
# Loaded file: mmsi_636018508.csv, Rows: 2926
# Rows in area for mmsi_636018508.csv: 2461
# Max consecutive entries for mmsi_636018508.csv: 1
# Skipped mmsi_636018508.csv: Insufficient consecutive entries in area.
# (23/1880) Processing file: mmsi_219001275.csv
# Loaded file: mmsi_219001275.csv, Rows: 13736
# Rows in area for mmsi_219001275.csv: 13736
# Max consecutive entries for mmsi_219001275.csv: 1
# Skipped mmsi_219001275.csv: Insufficient consecutive entries in area.
# (24/1880) Processing file: mmsi_211445200.csv
# Loaded file: mmsi_211445200.csv, Rows: 1
# Rows in area for mmsi_211445200.csv: 1
# Max consecutive entries for mmsi_211445200.csv: 1
# Skipped mmsi_211445200.csv: Insufficient consecutive entries in area.
# (25/1880) Processing file: mmsi_219019010.csv
# Loaded file: mmsi_219019010.csv, Rows: 16327
# Rows in area for mmsi_219019010.csv: 0
# Skipped mmsi_219019010.csv: No rows in specified area.
# (26/1880) Processing file: mmsi_374309000.csv
# Loaded file: mmsi_374309000.csv, Rows: 1420
# Rows in area for mmsi_374309000.csv: 0
# Skipped mmsi_374309000.csv: No rows in specified area.
# (27/1880) Processing file: mmsi_211405010.csv
# Loaded file: mmsi_211405010.csv, Rows: 337
# Rows in area for mmsi_211405010.csv: 337
# Max consecutive entries for mmsi_211405010.csv: 1
# Skipped mmsi_211405010.csv: Insufficient consecutive entries in area.
# (28/1880) Processing file: mmsi_219032932.csv
# Loaded file: mmsi_219032932.csv, Rows: 7264
# Rows in area for mmsi_219032932.csv: 0
# Skipped mmsi_219032932.csv: No rows in specified area.
# (29/1880) Processing file: mmsi_268246900.csv
# Loaded file: mmsi_268246900.csv, Rows: 4985
# Rows in area for mmsi_268246900.csv: 0
# Skipped mmsi_268246900.csv: No rows in specified area.
# (30/1880) Processing file: mmsi_219029785.csv
# Loaded file: mmsi_219029785.csv, Rows: 1031
# Rows in area for mmsi_219029785.csv: 1031
# Max consecutive entries for mmsi_219029785.csv: 1
# Skipped mmsi_219029785.csv: Insufficient consecutive entries in area.
# (31/1880) Processing file: mmsi_218098000.csv
# Loaded file: mmsi_218098000.csv, Rows: 1574
# Rows in area for mmsi_218098000.csv: 0
# Skipped mmsi_218098000.csv: No rows in specified area.
# (32/1880) Processing file: mmsi_257819000.csv
# Loaded file: mmsi_257819000.csv, Rows: 1866
# Rows in area for mmsi_257819000.csv: 0
# Skipped mmsi_257819000.csv: No rows in specified area.
# (33/1880) Processing file: mmsi_244482000.csv
# Loaded file: mmsi_244482000.csv, Rows: 7058
# Rows in area for mmsi_244482000.csv: 7058
# Max consecutive entries for mmsi_244482000.csv: 1
# Skipped mmsi_244482000.csv: Insufficient consecutive entries in area.
# (34/1880) Processing file: mmsi_636022218.csv
# Loaded file: mmsi_636022218.csv, Rows: 4643
# Rows in area for mmsi_636022218.csv: 0
# Skipped mmsi_636022218.csv: No rows in specified area.
# (35/1880) Processing file: mmsi_219309000.csv
# Loaded file: mmsi_219309000.csv, Rows: 1298
# Rows in area for mmsi_219309000.csv: 0
# Skipped mmsi_219309000.csv: No rows in specified area.
# (36/1880) Processing file: mmsi_246777000.csv
# Loaded file: mmsi_246777000.csv, Rows: 1307
# Rows in area for mmsi_246777000.csv: 1307
# Max consecutive entries for mmsi_246777000.csv: 1
# Skipped mmsi_246777000.csv: Insufficient consecutive entries in area.
# (37/1880) Processing file: mmsi_563223700.csv
# Loaded file: mmsi_563223700.csv, Rows: 10955
# Rows in area for mmsi_563223700.csv: 10955
# Max consecutive entries for mmsi_563223700.csv: 1
# Skipped mmsi_563223700.csv: Insufficient consecutive entries in area.
# (38/1880) Processing file: mmsi_244475000.csv
# Loaded file: mmsi_244475000.csv, Rows: 23001
# Rows in area for mmsi_244475000.csv: 23001
# Max consecutive entries for mmsi_244475000.csv: 1
# Skipped mmsi_244475000.csv: Insufficient consecutive entries in area.
# (39/1880) Processing file: mmsi_219007314.csv
# Loaded file: mmsi_219007314.csv, Rows: 673
# Rows in area for mmsi_219007314.csv: 0
# Skipped mmsi_219007314.csv: No rows in specified area.
# (40/1880) Processing file: mmsi_220256000.csv
# Loaded file: mmsi_220256000.csv, Rows: 7634
# Rows in area for mmsi_220256000.csv: 0
# Skipped mmsi_220256000.csv: No rows in specified area.
# (41/1880) Processing file: mmsi_212900000.csv
# Loaded file: mmsi_212900000.csv, Rows: 8515
# Rows in area for mmsi_212900000.csv: 8515
# Max consecutive entries for mmsi_212900000.csv: 1
# Skipped mmsi_212900000.csv: Insufficient consecutive entries in area.
# (42/1880) Processing file: mmsi_209114000.csv
# Loaded file: mmsi_209114000.csv, Rows: 2473
# Rows in area for mmsi_209114000.csv: 0
# Skipped mmsi_209114000.csv: No rows in specified area.
# (43/1880) Processing file: mmsi_220088000.csv
# Loaded file: mmsi_220088000.csv, Rows: 14500
# Rows in area for mmsi_220088000.csv: 0
# Skipped mmsi_220088000.csv: No rows in specified area.
# (44/1880) Processing file: mmsi_211727510.csv
# Loaded file: mmsi_211727510.csv, Rows: 12432
# Rows in area for mmsi_211727510.csv: 7881
# Max consecutive entries for mmsi_211727510.csv: 2
# Skipped mmsi_211727510.csv: Insufficient consecutive entries in area.
# (45/1880) Processing file: mmsi_219001039.csv
# Loaded file: mmsi_219001039.csv, Rows: 8149
# Rows in area for mmsi_219001039.csv: 8149
# Max consecutive entries for mmsi_219001039.csv: 1
# Skipped mmsi_219001039.csv: Insufficient consecutive entries in area.
# (46/1880) Processing file: mmsi_219000217.csv
# Loaded file: mmsi_219000217.csv, Rows: 1095
# Rows in area for mmsi_219000217.csv: 0
# Skipped mmsi_219000217.csv: No rows in specified area.
# (47/1880) Processing file: mmsi_265866000.csv
# Loaded file: mmsi_265866000.csv, Rows: 9126
# Rows in area for mmsi_265866000.csv: 0
# Skipped mmsi_265866000.csv: No rows in specified area.
# (48/1880) Processing file: mmsi_636018261.csv
# Loaded file: mmsi_636018261.csv, Rows: 3200
# Rows in area for mmsi_636018261.csv: 2430
# Max consecutive entries for mmsi_636018261.csv: 1
# Skipped mmsi_636018261.csv: Insufficient consecutive entries in area.
# (49/1880) Processing file: mmsi_219012076.csv
# Loaded file: mmsi_219012076.csv, Rows: 778
# Rows in area for mmsi_219012076.csv: 778
# Max consecutive entries for mmsi_219012076.csv: 1
# Skipped mmsi_219012076.csv: Insufficient consecutive entries in area.
# (50/1880) Processing file: mmsi_258879000.csv
# Loaded file: mmsi_258879000.csv, Rows: 24
# Rows in area for mmsi_258879000.csv: 0
# Skipped mmsi_258879000.csv: No rows in specified area.
# (51/1880) Processing file: mmsi_219002349.csv
# Loaded file: mmsi_219002349.csv, Rows: 671
# Rows in area for mmsi_219002349.csv: 671
# Max consecutive entries for mmsi_219002349.csv: 1
# Skipped mmsi_219002349.csv: Insufficient consecutive entries in area.
# (52/1880) Processing file: mmsi_219023834.csv
# Loaded file: mmsi_219023834.csv, Rows: 32583
# Rows in area for mmsi_219023834.csv: 32583
# Max consecutive entries for mmsi_219023834.csv: 1
# Skipped mmsi_219023834.csv: Insufficient consecutive entries in area.
# (53/1880) Processing file: mmsi_314415000.csv
# Loaded file: mmsi_314415000.csv, Rows: 12
# Rows in area for mmsi_314415000.csv: 0
# Skipped mmsi_314415000.csv: No rows in specified area.
# (54/1880) Processing file: mmsi_261061000.csv
# Loaded file: mmsi_261061000.csv, Rows: 1627
# Rows in area for mmsi_261061000.csv: 0
# Skipped mmsi_261061000.csv: No rows in specified area.
# (55/1880) Processing file: mmsi_219002602.csv
# Loaded file: mmsi_219002602.csv, Rows: 9807
# Rows in area for mmsi_219002602.csv: 9807
# Max consecutive entries for mmsi_219002602.csv: 1
# Skipped mmsi_219002602.csv: Insufficient consecutive entries in area.
# (56/1880) Processing file: mmsi_265563720.csv
# Loaded file: mmsi_265563720.csv, Rows: 1166
# Rows in area for mmsi_265563720.csv: 0
# Skipped mmsi_265563720.csv: No rows in specified area.
# (57/1880) Processing file: mmsi_219004203.csv
# Loaded file: mmsi_219004203.csv, Rows: 9637
# Rows in area for mmsi_219004203.csv: 0
# Skipped mmsi_219004203.csv: No rows in specified area.
# (58/1880) Processing file: mmsi_219005886.csv
# Loaded file: mmsi_219005886.csv, Rows: 8643
# Rows in area for mmsi_219005886.csv: 8643
# Max consecutive entries for mmsi_219005886.csv: 1
# Skipped mmsi_219005886.csv: Insufficient consecutive entries in area.
# (59/1880) Processing file: mmsi_266147000.csv
# Loaded file: mmsi_266147000.csv, Rows: 7015
# Rows in area for mmsi_266147000.csv: 0
# Skipped mmsi_266147000.csv: No rows in specified area.
# (60/1880) Processing file: mmsi_211783270.csv
# Loaded file: mmsi_211783270.csv, Rows: 1906
# Rows in area for mmsi_211783270.csv: 1906
# Max consecutive entries for mmsi_211783270.csv: 1
# Skipped mmsi_211783270.csv: Insufficient consecutive entries in area.
# (61/1880) Processing file: mmsi_219461000.csv
# Loaded file: mmsi_219461000.csv, Rows: 10006
# Rows in area for mmsi_219461000.csv: 0
# Skipped mmsi_219461000.csv: No rows in specified area.
# (62/1880) Processing file: mmsi_211410690.csv
# Loaded file: mmsi_211410690.csv, Rows: 13385
# Rows in area for mmsi_211410690.csv: 0
# Skipped mmsi_211410690.csv: No rows in specified area.
# (63/1880) Processing file: mmsi_219018172.csv
# Loaded file: mmsi_219018172.csv, Rows: 32683
# Rows in area for mmsi_219018172.csv: 32683
# Max consecutive entries for mmsi_219018172.csv: 1
# Skipped mmsi_219018172.csv: Insufficient consecutive entries in area.
# (64/1880) Processing file: mmsi_261036120.csv
# Loaded file: mmsi_261036120.csv, Rows: 1599
# Rows in area for mmsi_261036120.csv: 0
# Skipped mmsi_261036120.csv: No rows in specified area.
# (65/1880) Processing file: mmsi_636022504.csv
# Loaded file: mmsi_636022504.csv, Rows: 3749
# Rows in area for mmsi_636022504.csv: 0
# Skipped mmsi_636022504.csv: No rows in specified area.
# (66/1880) Processing file: mmsi_352003804.csv
# Loaded file: mmsi_352003804.csv, Rows: 13276
# Rows in area for mmsi_352003804.csv: 1247
# Max consecutive entries for mmsi_352003804.csv: 1
# Skipped mmsi_352003804.csv: Insufficient consecutive entries in area.
# (67/1880) Processing file: mmsi_305211000.csv
# Loaded file: mmsi_305211000.csv, Rows: 5833
# Rows in area for mmsi_305211000.csv: 4497
# Max consecutive entries for mmsi_305211000.csv: 1
# Skipped mmsi_305211000.csv: Insufficient consecutive entries in area.
# (68/1880) Processing file: mmsi_257357000.csv
# Loaded file: mmsi_257357000.csv, Rows: 6163
# Rows in area for mmsi_257357000.csv: 0
# Skipped mmsi_257357000.csv: No rows in specified area.
# (69/1880) Processing file: mmsi_211787120.csv
# Loaded file: mmsi_211787120.csv, Rows: 8426
# Rows in area for mmsi_211787120.csv: 0
# Skipped mmsi_211787120.csv: No rows in specified area.
# (70/1880) Processing file: mmsi_219002838.csv
# Loaded file: mmsi_219002838.csv, Rows: 7050
# Rows in area for mmsi_219002838.csv: 7050
# Max consecutive entries for mmsi_219002838.csv: 1
# Skipped mmsi_219002838.csv: Insufficient consecutive entries in area.
# (71/1880) Processing file: mmsi_219000469.csv
# Loaded file: mmsi_219000469.csv, Rows: 531
# Rows in area for mmsi_219000469.csv: 0
# Skipped mmsi_219000469.csv: No rows in specified area.
# (72/1880) Processing file: mmsi_265610940.csv
# Loaded file: mmsi_265610940.csv, Rows: 4782
# Rows in area for mmsi_265610940.csv: 0
# Skipped mmsi_265610940.csv: No rows in specified area.
# (73/1880) Processing file: mmsi_220464000.csv
# Loaded file: mmsi_220464000.csv, Rows: 8314
# Rows in area for mmsi_220464000.csv: 3273
# Max consecutive entries for mmsi_220464000.csv: 1
# Skipped mmsi_220464000.csv: Insufficient consecutive entries in area.
# (74/1880) Processing file: mmsi_219026081.csv
# Loaded file: mmsi_219026081.csv, Rows: 13721
# Rows in area for mmsi_219026081.csv: 0
# Skipped mmsi_219026081.csv: No rows in specified area.
# (75/1880) Processing file: mmsi_220024000.csv
# Loaded file: mmsi_220024000.csv, Rows: 6549
# Rows in area for mmsi_220024000.csv: 0
# Skipped mmsi_220024000.csv: No rows in specified area.
# (76/1880) Processing file: mmsi_265621060.csv
# Loaded file: mmsi_265621060.csv, Rows: 7848
# Rows in area for mmsi_265621060.csv: 0
# Skipped mmsi_265621060.csv: No rows in specified area.
# (77/1880) Processing file: mmsi_235090733.csv
# Loaded file: mmsi_235090733.csv, Rows: 5268
# Rows in area for mmsi_235090733.csv: 5268
# Max consecutive entries for mmsi_235090733.csv: 1
# Skipped mmsi_235090733.csv: Insufficient consecutive entries in area.
# (78/1880) Processing file: mmsi_265724260.csv
# Loaded file: mmsi_265724260.csv, Rows: 9078
# Rows in area for mmsi_265724260.csv: 0
# Skipped mmsi_265724260.csv: No rows in specified area.
# (79/1880) Processing file: mmsi_311001445.csv
# Loaded file: mmsi_311001445.csv, Rows: 2473
# Rows in area for mmsi_311001445.csv: 0
# Skipped mmsi_311001445.csv: No rows in specified area.
# (80/1880) Processing file: mmsi_219358000.csv
# Loaded file: mmsi_219358000.csv, Rows: 13690
# Rows in area for mmsi_219358000.csv: 0
# Skipped mmsi_219358000.csv: No rows in specified area.
# (81/1880) Processing file: mmsi_266199000.csv
# Loaded file: mmsi_266199000.csv, Rows: 4221
# Rows in area for mmsi_266199000.csv: 0
# Skipped mmsi_266199000.csv: No rows in specified area.
# (82/1880) Processing file: mmsi_209992000.csv
# Loaded file: mmsi_209992000.csv, Rows: 856
# Rows in area for mmsi_209992000.csv: 0
# Skipped mmsi_209992000.csv: No rows in specified area.
# (83/1880) Processing file: mmsi_231074000.csv
# Loaded file: mmsi_231074000.csv, Rows: 1047
# Rows in area for mmsi_231074000.csv: 0
# Skipped mmsi_231074000.csv: No rows in specified area.
# (84/1880) Processing file: mmsi_219016938.csv
# Loaded file: mmsi_219016938.csv, Rows: 25145
# Rows in area for mmsi_219016938.csv: 25145
# Max consecutive entries for mmsi_219016938.csv: 1
# Skipped mmsi_219016938.csv: Insufficient consecutive entries in area.
# (85/1880) Processing file: mmsi_219024411.csv
# Loaded file: mmsi_219024411.csv, Rows: 8785
# Rows in area for mmsi_219024411.csv: 0
# Skipped mmsi_219024411.csv: No rows in specified area.
# (86/1880) Processing file: mmsi_211321160.csv
# Loaded file: mmsi_211321160.csv, Rows: 1
# Rows in area for mmsi_211321160.csv: 1
# Max consecutive entries for mmsi_211321160.csv: 1
# Skipped mmsi_211321160.csv: Insufficient consecutive entries in area.
# (87/1880) Processing file: mmsi_219007456.csv
# Loaded file: mmsi_219007456.csv, Rows: 7552
# Rows in area for mmsi_219007456.csv: 7552
# Max consecutive entries for mmsi_219007456.csv: 1
# Skipped mmsi_219007456.csv: Insufficient consecutive entries in area.
# (88/1880) Processing file: mmsi_219016759.csv
# Loaded file: mmsi_219016759.csv, Rows: 8672
# Rows in area for mmsi_219016759.csv: 8581
# Max consecutive entries for mmsi_219016759.csv: 1
# Skipped mmsi_219016759.csv: Insufficient consecutive entries in area.
# (89/1880) Processing file: mmsi_231876000.csv
# Loaded file: mmsi_231876000.csv, Rows: 1324
# Rows in area for mmsi_231876000.csv: 1324
# Max consecutive entries for mmsi_231876000.csv: 1
# Skipped mmsi_231876000.csv: Insufficient consecutive entries in area.
# (90/1880) Processing file: mmsi_219011867.csv
# Loaded file: mmsi_219011867.csv, Rows: 9954
# Rows in area for mmsi_219011867.csv: 9954
# Max consecutive entries for mmsi_219011867.csv: 1
# Skipped mmsi_219011867.csv: Insufficient consecutive entries in area.
# (91/1880) Processing file: mmsi_211614010.csv
# Loaded file: mmsi_211614010.csv, Rows: 787
# Rows in area for mmsi_211614010.csv: 787
# Max consecutive entries for mmsi_211614010.csv: 1
# Skipped mmsi_211614010.csv: Insufficient consecutive entries in area.
# (92/1880) Processing file: mmsi_220272000.csv
# Loaded file: mmsi_220272000.csv, Rows: 4820
# Rows in area for mmsi_220272000.csv: 4820
# Max consecutive entries for mmsi_220272000.csv: 1
# Skipped mmsi_220272000.csv: Insufficient consecutive entries in area.
# (93/1880) Processing file: mmsi_255803870.csv
# Loaded file: mmsi_255803870.csv, Rows: 3
# Rows in area for mmsi_255803870.csv: 0
# Skipped mmsi_255803870.csv: No rows in specified area.
# (94/1880) Processing file: mmsi_477157800.csv
# Loaded file: mmsi_477157800.csv, Rows: 173
# Rows in area for mmsi_477157800.csv: 173
# Max consecutive entries for mmsi_477157800.csv: 1
# Skipped mmsi_477157800.csv: Insufficient consecutive entries in area.
# (95/1880) Processing file: mmsi_245256000.csv
# Loaded file: mmsi_245256000.csv, Rows: 12075
# Rows in area for mmsi_245256000.csv: 8201
# Max consecutive entries for mmsi_245256000.csv: 1
# Skipped mmsi_245256000.csv: Insufficient consecutive entries in area.
# (96/1880) Processing file: mmsi_246843000.csv
# Loaded file: mmsi_246843000.csv, Rows: 2024
# Rows in area for mmsi_246843000.csv: 0
# Skipped mmsi_246843000.csv: No rows in specified area.
# (97/1880) Processing file: mmsi_219025739.csv
# Loaded file: mmsi_219025739.csv, Rows: 8174
# Rows in area for mmsi_219025739.csv: 8174
# Max consecutive entries for mmsi_219025739.csv: 1
# Skipped mmsi_219025739.csv: Insufficient consecutive entries in area.
# (98/1880) Processing file: mmsi_304030000.csv
# Loaded file: mmsi_304030000.csv, Rows: 28422
# Rows in area for mmsi_304030000.csv: 8028
# Max consecutive entries for mmsi_304030000.csv: 1
# Skipped mmsi_304030000.csv: Insufficient consecutive entries in area.
# (99/1880) Processing file: mmsi_219000643.csv
# Loaded file: mmsi_219000643.csv, Rows: 22404
# Rows in area for mmsi_219000643.csv: 22404
# Max consecutive entries for mmsi_219000643.csv: 1
# Skipped mmsi_219000643.csv: Insufficient consecutive entries in area.
# (100/1880) Processing file: mmsi_255806465.csv
# Loaded file: mmsi_255806465.csv, Rows: 14044
# Rows in area for mmsi_255806465.csv: 13817
# Max consecutive entries for mmsi_255806465.csv: 1
# Skipped mmsi_255806465.csv: Insufficient consecutive entries in area.
# (101/1880) Processing file: mmsi_477913400.csv
# Loaded file: mmsi_477913400.csv, Rows: 28626
# Rows in area for mmsi_477913400.csv: 22750
# Max consecutive entries for mmsi_477913400.csv: 1
# Skipped mmsi_477913400.csv: Insufficient consecutive entries in area.
# (102/1880) Processing file: mmsi_219022165.csv
# Loaded file: mmsi_219022165.csv, Rows: 9490
# Rows in area for mmsi_219022165.csv: 0
# Skipped mmsi_219022165.csv: No rows in specified area.
# (103/1880) Processing file: mmsi_413491830.csv
# Loaded file: mmsi_413491830.csv, Rows: 24197
# Rows in area for mmsi_413491830.csv: 18456
# Max consecutive entries for mmsi_413491830.csv: 1
# Skipped mmsi_413491830.csv: Insufficient consecutive entries in area.
# (104/1880) Processing file: mmsi_219028352.csv
# Loaded file: mmsi_219028352.csv, Rows: 820
# Rows in area for mmsi_219028352.csv: 820
# Max consecutive entries for mmsi_219028352.csv: 1
# Skipped mmsi_219028352.csv: Insufficient consecutive entries in area.
# (105/1880) Processing file: mmsi_220434000.csv
# Loaded file: mmsi_220434000.csv, Rows: 6458
# Rows in area for mmsi_220434000.csv: 0
# Skipped mmsi_220434000.csv: No rows in specified area.
# (106/1880) Processing file: mmsi_265054000.csv
# Loaded file: mmsi_265054000.csv, Rows: 1601
# Rows in area for mmsi_265054000.csv: 0
# Skipped mmsi_265054000.csv: No rows in specified area.
# (107/1880) Processing file: mmsi_220043000.csv
# Loaded file: mmsi_220043000.csv, Rows: 22912
# Rows in area for mmsi_220043000.csv: 0
# Skipped mmsi_220043000.csv: No rows in specified area.
# (108/1880) Processing file: mmsi_258763000.csv
# Loaded file: mmsi_258763000.csv, Rows: 12842
# Rows in area for mmsi_258763000.csv: 12842
# Max consecutive entries for mmsi_258763000.csv: 1
# Skipped mmsi_258763000.csv: Insufficient consecutive entries in area.
# (109/1880) Processing file: mmsi_219612000.csv
# Loaded file: mmsi_219612000.csv, Rows: 23202
# Rows in area for mmsi_219612000.csv: 20834
# Max consecutive entries for mmsi_219612000.csv: 1
# Skipped mmsi_219612000.csv: Insufficient consecutive entries in area.
# (110/1880) Processing file: mmsi_210056000.csv
# Loaded file: mmsi_210056000.csv, Rows: 1938
# Rows in area for mmsi_210056000.csv: 0
# Skipped mmsi_210056000.csv: No rows in specified area.
# (111/1880) Processing file: mmsi_219009907.csv
# Loaded file: mmsi_219009907.csv, Rows: 1234
# Rows in area for mmsi_219009907.csv: 0
# Skipped mmsi_219009907.csv: No rows in specified area.
# (112/1880) Processing file: mmsi_304159000.csv
# Loaded file: mmsi_304159000.csv, Rows: 803
# Rows in area for mmsi_304159000.csv: 0
# Skipped mmsi_304159000.csv: No rows in specified area.
# (113/1880) Processing file: mmsi_311668000.csv
# Loaded file: mmsi_311668000.csv, Rows: 412
# Rows in area for mmsi_311668000.csv: 412
# Max consecutive entries for mmsi_311668000.csv: 1
# Skipped mmsi_311668000.csv: Insufficient consecutive entries in area.
# (114/1880) Processing file: mmsi_219018486.csv
# Loaded file: mmsi_219018486.csv, Rows: 8792
# Rows in area for mmsi_219018486.csv: 0
# Skipped mmsi_219018486.csv: No rows in specified area.
# (115/1880) Processing file: mmsi_246818000.csv
# Loaded file: mmsi_246818000.csv, Rows: 14884
# Rows in area for mmsi_246818000.csv: 14884
# Max consecutive entries for mmsi_246818000.csv: 1
# Skipped mmsi_246818000.csv: Insufficient consecutive entries in area.
# (116/1880) Processing file: mmsi_538007185.csv
# Loaded file: mmsi_538007185.csv, Rows: 3
# Rows in area for mmsi_538007185.csv: 3
# Max consecutive entries for mmsi_538007185.csv: 1
# Skipped mmsi_538007185.csv: Insufficient consecutive entries in area.
# (117/1880) Processing file: mmsi_211317720.csv
# Loaded file: mmsi_211317720.csv, Rows: 12260
# Rows in area for mmsi_211317720.csv: 0
# Skipped mmsi_211317720.csv: No rows in specified area.
# (118/1880) Processing file: mmsi_311000634.csv
# Loaded file: mmsi_311000634.csv, Rows: 1950
# Rows in area for mmsi_311000634.csv: 0
# Skipped mmsi_311000634.csv: No rows in specified area.
# (119/1880) Processing file: mmsi_255806196.csv
# Loaded file: mmsi_255806196.csv, Rows: 118
# Rows in area for mmsi_255806196.csv: 0
# Skipped mmsi_255806196.csv: No rows in specified area.
# (120/1880) Processing file: mmsi_259110000.csv
# Loaded file: mmsi_259110000.csv, Rows: 8642
# Rows in area for mmsi_259110000.csv: 7240
# Max consecutive entries for mmsi_259110000.csv: 1
# Skipped mmsi_259110000.csv: Insufficient consecutive entries in area.
# (121/1880) Processing file: mmsi_255805906.csv
# Loaded file: mmsi_255805906.csv, Rows: 21
# Rows in area for mmsi_255805906.csv: 0
# Skipped mmsi_255805906.csv: No rows in specified area.
# (122/1880) Processing file: mmsi_245693000.csv
# Loaded file: mmsi_245693000.csv, Rows: 11971
# Rows in area for mmsi_245693000.csv: 11971
# Max consecutive entries for mmsi_245693000.csv: 1
# Skipped mmsi_245693000.csv: Insufficient consecutive entries in area.
# (123/1880) Processing file: mmsi_219026000.csv
# Loaded file: mmsi_219026000.csv, Rows: 17411
# Rows in area for mmsi_219026000.csv: 0
# Skipped mmsi_219026000.csv: No rows in specified area.
# (124/1880) Processing file: mmsi_259140000.csv
# Loaded file: mmsi_259140000.csv, Rows: 9015
# Rows in area for mmsi_259140000.csv: 0
# Skipped mmsi_259140000.csv: No rows in specified area.
# (125/1880) Processing file: mmsi_228421600.csv
# Loaded file: mmsi_228421600.csv, Rows: 33809
# Rows in area for mmsi_228421600.csv: 26683
# Max consecutive entries for mmsi_228421600.csv: 1
# Skipped mmsi_228421600.csv: Insufficient consecutive entries in area.
# (126/1880) Processing file: mmsi_219027026.csv
# Loaded file: mmsi_219027026.csv, Rows: 16191
# Rows in area for mmsi_219027026.csv: 0
# Skipped mmsi_219027026.csv: No rows in specified area.
# (127/1880) Processing file: mmsi_265511440.csv
# Loaded file: mmsi_265511440.csv, Rows: 1
# Rows in area for mmsi_265511440.csv: 0
# Skipped mmsi_265511440.csv: No rows in specified area.
# (128/1880) Processing file: mmsi_219001771.csv
# Loaded file: mmsi_219001771.csv, Rows: 699
# Rows in area for mmsi_219001771.csv: 699
# Max consecutive entries for mmsi_219001771.csv: 1
# Skipped mmsi_219001771.csv: Insufficient consecutive entries in area.
# (129/1880) Processing file: mmsi_249128000.csv
# Loaded file: mmsi_249128000.csv, Rows: 359
# Rows in area for mmsi_249128000.csv: 0
# Skipped mmsi_249128000.csv: No rows in specified area.
# (130/1880) Processing file: mmsi_219000158.csv
# Loaded file: mmsi_219000158.csv, Rows: 1655
# Rows in area for mmsi_219000158.csv: 1655
# Max consecutive entries for mmsi_219000158.csv: 1
# Skipped mmsi_219000158.csv: Insufficient consecutive entries in area.
# (131/1880) Processing file: mmsi_219015153.csv
# Loaded file: mmsi_219015153.csv, Rows: 137
# Rows in area for mmsi_219015153.csv: 0
# Skipped mmsi_219015153.csv: No rows in specified area.
# (132/1880) Processing file: mmsi_210552000.csv
# Loaded file: mmsi_210552000.csv, Rows: 16109
# Rows in area for mmsi_210552000.csv: 15715
# Max consecutive entries for mmsi_210552000.csv: 1
# Skipped mmsi_210552000.csv: Insufficient consecutive entries in area.
# (133/1880) Processing file: mmsi_266220000.csv
# Loaded file: mmsi_266220000.csv, Rows: 13365
# Rows in area for mmsi_266220000.csv: 0
# Skipped mmsi_266220000.csv: No rows in specified area.
# (134/1880) Processing file: mmsi_219018526.csv
# Loaded file: mmsi_219018526.csv, Rows: 718
# Rows in area for mmsi_219018526.csv: 718
# Max consecutive entries for mmsi_219018526.csv: 1
# Skipped mmsi_219018526.csv: Insufficient consecutive entries in area.
# (135/1880) Processing file: mmsi_220225000.csv
# Loaded file: mmsi_220225000.csv, Rows: 8754
# Rows in area for mmsi_220225000.csv: 0
# Skipped mmsi_220225000.csv: No rows in specified area.
# (136/1880) Processing file: mmsi_265859000.csv
# Loaded file: mmsi_265859000.csv, Rows: 45243
# Rows in area for mmsi_265859000.csv: 29311
# Max consecutive entries for mmsi_265859000.csv: 2
# Skipped mmsi_265859000.csv: Insufficient consecutive entries in area.
# (137/1880) Processing file: mmsi_219000417.csv
# Loaded file: mmsi_219000417.csv, Rows: 2163
# Rows in area for mmsi_219000417.csv: 2163
# Max consecutive entries for mmsi_219000417.csv: 1
# Skipped mmsi_219000417.csv: Insufficient consecutive entries in area.
# (138/1880) Processing file: mmsi_219002177.csv
# Loaded file: mmsi_219002177.csv, Rows: 21999
# Rows in area for mmsi_219002177.csv: 21999
# Max consecutive entries for mmsi_219002177.csv: 1
# Skipped mmsi_219002177.csv: Insufficient consecutive entries in area.
# (139/1880) Processing file: mmsi_246836000.csv
# Loaded file: mmsi_246836000.csv, Rows: 1396
# Rows in area for mmsi_246836000.csv: 1396
# Max consecutive entries for mmsi_246836000.csv: 1
# Skipped mmsi_246836000.csv: Insufficient consecutive entries in area.
# (140/1880) Processing file: mmsi_257327000.csv
# Loaded file: mmsi_257327000.csv, Rows: 15208
# Rows in area for mmsi_257327000.csv: 0
# Skipped mmsi_257327000.csv: No rows in specified area.
# (141/1880) Processing file: mmsi_311019800.csv
# Loaded file: mmsi_311019800.csv, Rows: 663
# Rows in area for mmsi_311019800.csv: 0
# Skipped mmsi_311019800.csv: No rows in specified area.
# (142/1880) Processing file: mmsi_244880000.csv
# Loaded file: mmsi_244880000.csv, Rows: 8998
# Rows in area for mmsi_244880000.csv: 0
# Skipped mmsi_244880000.csv: No rows in specified area.
# (143/1880) Processing file: mmsi_232008874.csv
# Loaded file: mmsi_232008874.csv, Rows: 1582
# Rows in area for mmsi_232008874.csv: 1582
# Max consecutive entries for mmsi_232008874.csv: 1
# Skipped mmsi_232008874.csv: Insufficient consecutive entries in area.
# (144/1880) Processing file: mmsi_205196000.csv
# Loaded file: mmsi_205196000.csv, Rows: 1881
# Rows in area for mmsi_205196000.csv: 1881
# Max consecutive entries for mmsi_205196000.csv: 1
# Skipped mmsi_205196000.csv: Insufficient consecutive entries in area.
# (145/1880) Processing file: mmsi_219014000.csv
# Loaded file: mmsi_219014000.csv, Rows: 7062
# Rows in area for mmsi_219014000.csv: 0
# Skipped mmsi_219014000.csv: No rows in specified area.
# (146/1880) Processing file: mmsi_265810550.csv
# Loaded file: mmsi_265810550.csv, Rows: 6
# Rows in area for mmsi_265810550.csv: 0
# Skipped mmsi_265810550.csv: No rows in specified area.
# (147/1880) Processing file: mmsi_219186000.csv
# Loaded file: mmsi_219186000.csv, Rows: 19286
# Rows in area for mmsi_219186000.csv: 0
# Skipped mmsi_219186000.csv: No rows in specified area.
# (148/1880) Processing file: mmsi_205210000.csv
# Loaded file: mmsi_205210000.csv, Rows: 1730
# Rows in area for mmsi_205210000.csv: 1730
# Max consecutive entries for mmsi_205210000.csv: 1
# Skipped mmsi_205210000.csv: Insufficient consecutive entries in area.
# (149/1880) Processing file: mmsi_219825000.csv
# Loaded file: mmsi_219825000.csv, Rows: 1773
# Rows in area for mmsi_219825000.csv: 1773
# Max consecutive entries for mmsi_219825000.csv: 1
# Skipped mmsi_219825000.csv: Insufficient consecutive entries in area.
# (150/1880) Processing file: mmsi_211219990.csv
# Loaded file: mmsi_211219990.csv, Rows: 329
# Rows in area for mmsi_211219990.csv: 329
# Max consecutive entries for mmsi_211219990.csv: 1
# Skipped mmsi_211219990.csv: Insufficient consecutive entries in area.
# (151/1880) Processing file: mmsi_219330000.csv
# Loaded file: mmsi_219330000.csv, Rows: 16162
# Rows in area for mmsi_219330000.csv: 16162
# Max consecutive entries for mmsi_219330000.csv: 1
# Skipped mmsi_219330000.csv: Insufficient consecutive entries in area.
# (152/1880) Processing file: mmsi_255830000.csv
# Loaded file: mmsi_255830000.csv, Rows: 16207
# Rows in area for mmsi_255830000.csv: 0
# Skipped mmsi_255830000.csv: No rows in specified area.
# (153/1880) Processing file: mmsi_220343000.csv
# Loaded file: mmsi_220343000.csv, Rows: 8738
# Rows in area for mmsi_220343000.csv: 0
# Skipped mmsi_220343000.csv: No rows in specified area.
# (154/1880) Processing file: mmsi_266388000.csv
# Loaded file: mmsi_266388000.csv, Rows: 104
# Rows in area for mmsi_266388000.csv: 0
# Skipped mmsi_266388000.csv: No rows in specified area.
# (155/1880) Processing file: mmsi_229602000.csv
# Loaded file: mmsi_229602000.csv, Rows: 16275
# Rows in area for mmsi_229602000.csv: 2261
# Max consecutive entries for mmsi_229602000.csv: 1
# Skipped mmsi_229602000.csv: Insufficient consecutive entries in area.
# (156/1880) Processing file: mmsi_244675000.csv
# Loaded file: mmsi_244675000.csv, Rows: 5402
# Rows in area for mmsi_244675000.csv: 0
# Skipped mmsi_244675000.csv: No rows in specified area.
# (157/1880) Processing file: mmsi_265402000.csv
# Loaded file: mmsi_265402000.csv, Rows: 11159
# Rows in area for mmsi_265402000.csv: 0
# Skipped mmsi_265402000.csv: No rows in specified area.
# (158/1880) Processing file: mmsi_232009818.csv
# Loaded file: mmsi_232009818.csv, Rows: 17013
# Rows in area for mmsi_232009818.csv: 0
# Skipped mmsi_232009818.csv: No rows in specified area.
# (159/1880) Processing file: mmsi_314189000.csv
# Loaded file: mmsi_314189000.csv, Rows: 9197
# Rows in area for mmsi_314189000.csv: 9197
# Max consecutive entries for mmsi_314189000.csv: 1
# Skipped mmsi_314189000.csv: Insufficient consecutive entries in area.
# (160/1880) Processing file: mmsi_657246900.csv
# Loaded file: mmsi_657246900.csv, Rows: 10477
# Rows in area for mmsi_657246900.csv: 0
# Skipped mmsi_657246900.csv: No rows in specified area.
# (161/1880) Processing file: mmsi_211101000.csv
# Loaded file: mmsi_211101000.csv, Rows: 10710
# Rows in area for mmsi_211101000.csv: 10710
# Max consecutive entries for mmsi_211101000.csv: 1
# Skipped mmsi_211101000.csv: Insufficient consecutive entries in area.
# (162/1880) Processing file: mmsi_210071000.csv
# Loaded file: mmsi_210071000.csv, Rows: 18128
# Rows in area for mmsi_210071000.csv: 18128
# Max consecutive entries for mmsi_210071000.csv: 1
# Skipped mmsi_210071000.csv: Insufficient consecutive entries in area.
# (163/1880) Processing file: mmsi_255806016.csv
# Loaded file: mmsi_255806016.csv, Rows: 748
# Rows in area for mmsi_255806016.csv: 0
# Skipped mmsi_255806016.csv: No rows in specified area.
# (164/1880) Processing file: mmsi_230684000.csv
# Loaded file: mmsi_230684000.csv, Rows: 465
# Rows in area for mmsi_230684000.csv: 0
# Skipped mmsi_230684000.csv: No rows in specified area.
# (165/1880) Processing file: mmsi_219006789.csv
# Loaded file: mmsi_219006789.csv, Rows: 1534
# Rows in area for mmsi_219006789.csv: 1534
# Max consecutive entries for mmsi_219006789.csv: 1
# Skipped mmsi_219006789.csv: Insufficient consecutive entries in area.
# (166/1880) Processing file: mmsi_266254000.csv
# Loaded file: mmsi_266254000.csv, Rows: 6277
# Rows in area for mmsi_266254000.csv: 0
# Skipped mmsi_266254000.csv: No rows in specified area.
# (167/1880) Processing file: mmsi_277399000.csv
# Loaded file: mmsi_277399000.csv, Rows: 13909
# Rows in area for mmsi_277399000.csv: 13909
# Max consecutive entries for mmsi_277399000.csv: 1
# Skipped mmsi_277399000.csv: Insufficient consecutive entries in area.
# (168/1880) Processing file: mmsi_246668000.csv
# Loaded file: mmsi_246668000.csv, Rows: 207
# Rows in area for mmsi_246668000.csv: 0
# Skipped mmsi_246668000.csv: No rows in specified area.
# (169/1880) Processing file: mmsi_246544000.csv
# Loaded file: mmsi_246544000.csv, Rows: 253
# Rows in area for mmsi_246544000.csv: 253
# Max consecutive entries for mmsi_246544000.csv: 1
# Skipped mmsi_246544000.csv: Insufficient consecutive entries in area.
# (170/1880) Processing file: mmsi_246058000.csv
# Loaded file: mmsi_246058000.csv, Rows: 1912
# Rows in area for mmsi_246058000.csv: 1912
# Max consecutive entries for mmsi_246058000.csv: 1
# Skipped mmsi_246058000.csv: Insufficient consecutive entries in area.
# (171/1880) Processing file: mmsi_211497360.csv
# Loaded file: mmsi_211497360.csv, Rows: 4
# Rows in area for mmsi_211497360.csv: 0
# Skipped mmsi_211497360.csv: No rows in specified area.
# (172/1880) Processing file: mmsi_265049000.csv
# Loaded file: mmsi_265049000.csv, Rows: 16871
# Rows in area for mmsi_265049000.csv: 0
# Skipped mmsi_265049000.csv: No rows in specified area.
# (173/1880) Processing file: mmsi_266286000.csv
# Loaded file: mmsi_266286000.csv, Rows: 18291
# Rows in area for mmsi_266286000.csv: 0
# Skipped mmsi_266286000.csv: No rows in specified area.
# (174/1880) Processing file: mmsi_538011169.csv
# Loaded file: mmsi_538011169.csv, Rows: 16440
# Rows in area for mmsi_538011169.csv: 39
# Max consecutive entries for mmsi_538011169.csv: 1
# Skipped mmsi_538011169.csv: Insufficient consecutive entries in area.
# (175/1880) Processing file: mmsi_314603000.csv
# Loaded file: mmsi_314603000.csv, Rows: 22024
# Rows in area for mmsi_314603000.csv: 14628
# Max consecutive entries for mmsi_314603000.csv: 1
# Skipped mmsi_314603000.csv: Insufficient consecutive entries in area.
# (176/1880) Processing file: mmsi_255915617.csv
# Loaded file: mmsi_255915617.csv, Rows: 205
# Rows in area for mmsi_255915617.csv: 205
# Max consecutive entries for mmsi_255915617.csv: 1
# Skipped mmsi_255915617.csv: Insufficient consecutive entries in area.
# (177/1880) Processing file: mmsi_211283440.csv
# Loaded file: mmsi_211283440.csv, Rows: 97
# Rows in area for mmsi_211283440.csv: 97
# Max consecutive entries for mmsi_211283440.csv: 1
# Skipped mmsi_211283440.csv: Insufficient consecutive entries in area.
# (178/1880) Processing file: mmsi_211818270.csv
# Loaded file: mmsi_211818270.csv, Rows: 1
# Rows in area for mmsi_211818270.csv: 1
# Max consecutive entries for mmsi_211818270.csv: 1
# Skipped mmsi_211818270.csv: Insufficient consecutive entries in area.
# (179/1880) Processing file: mmsi_219007596.csv
# Loaded file: mmsi_219007596.csv, Rows: 22064
# Rows in area for mmsi_219007596.csv: 0
# Skipped mmsi_219007596.csv: No rows in specified area.
# (180/1880) Processing file: mmsi_219440000.csv
# Loaded file: mmsi_219440000.csv, Rows: 719
# Rows in area for mmsi_219440000.csv: 0
# Skipped mmsi_219440000.csv: No rows in specified area.
# (181/1880) Processing file: mmsi_219001266.csv
# Loaded file: mmsi_219001266.csv, Rows: 8967
# Rows in area for mmsi_219001266.csv: 8967
# Max consecutive entries for mmsi_219001266.csv: 1
# Skipped mmsi_219001266.csv: Insufficient consecutive entries in area.
# (182/1880) Processing file: mmsi_219031339.csv
# Loaded file: mmsi_219031339.csv, Rows: 20
# Rows in area for mmsi_219031339.csv: 0
# Skipped mmsi_219031339.csv: No rows in specified area.
# (183/1880) Processing file: mmsi_220000051.csv
# Loaded file: mmsi_220000051.csv, Rows: 14328
# Rows in area for mmsi_220000051.csv: 14328
# Max consecutive entries for mmsi_220000051.csv: 1
# Skipped mmsi_220000051.csv: Insufficient consecutive entries in area.
# (184/1880) Processing file: mmsi_211106380.csv
# Loaded file: mmsi_211106380.csv, Rows: 19
# Rows in area for mmsi_211106380.csv: 0
# Skipped mmsi_211106380.csv: No rows in specified area.
# (185/1880) Processing file: mmsi_219023531.csv
# Loaded file: mmsi_219023531.csv, Rows: 24244
# Rows in area for mmsi_219023531.csv: 24244
# Max consecutive entries for mmsi_219023531.csv: 1
# Skipped mmsi_219023531.csv: Insufficient consecutive entries in area.
# (186/1880) Processing file: mmsi_231048000.csv
# Loaded file: mmsi_231048000.csv, Rows: 18891
# Rows in area for mmsi_231048000.csv: 18891
# Max consecutive entries for mmsi_231048000.csv: 1
# Skipped mmsi_231048000.csv: Insufficient consecutive entries in area.
# (187/1880) Processing file: mmsi_219031896.csv
# Loaded file: mmsi_219031896.csv, Rows: 694
# Rows in area for mmsi_219031896.csv: 0
# Skipped mmsi_219031896.csv: No rows in specified area.
# (188/1880) Processing file: mmsi_219783000.csv
# Loaded file: mmsi_219783000.csv, Rows: 717
# Rows in area for mmsi_219783000.csv: 0
# Skipped mmsi_219783000.csv: No rows in specified area.
# (189/1880) Processing file: mmsi_219750000.csv
# Loaded file: mmsi_219750000.csv, Rows: 15771
# Rows in area for mmsi_219750000.csv: 13931
# Max consecutive entries for mmsi_219750000.csv: 1
# Skipped mmsi_219750000.csv: Insufficient consecutive entries in area.
# (190/1880) Processing file: mmsi_219022047.csv
# Loaded file: mmsi_219022047.csv, Rows: 14607
# Rows in area for mmsi_219022047.csv: 14607
# Max consecutive entries for mmsi_219022047.csv: 1
# Skipped mmsi_219022047.csv: Insufficient consecutive entries in area.
# (191/1880) Processing file: mmsi_265732860.csv
# Loaded file: mmsi_265732860.csv, Rows: 193
# Rows in area for mmsi_265732860.csv: 0
# Skipped mmsi_265732860.csv: No rows in specified area.
# (192/1880) Processing file: mmsi_311001593.csv
# Loaded file: mmsi_311001593.csv, Rows: 24274
# Rows in area for mmsi_311001593.csv: 14201
# Max consecutive entries for mmsi_311001593.csv: 1
# Skipped mmsi_311001593.csv: Insufficient consecutive entries in area.
# (193/1880) Processing file: mmsi_257035870.csv
# Loaded file: mmsi_257035870.csv, Rows: 2273
# Rows in area for mmsi_257035870.csv: 0
# Skipped mmsi_257035870.csv: No rows in specified area.
# (194/1880) Processing file: mmsi_265644320.csv
# Loaded file: mmsi_265644320.csv, Rows: 10
# Rows in area for mmsi_265644320.csv: 0
# Skipped mmsi_265644320.csv: No rows in specified area.
# (195/1880) Processing file: mmsi_241769000.csv
# Loaded file: mmsi_241769000.csv, Rows: 1281
# Rows in area for mmsi_241769000.csv: 1281
# Max consecutive entries for mmsi_241769000.csv: 1
# Skipped mmsi_241769000.csv: Insufficient consecutive entries in area.
# (196/1880) Processing file: mmsi_257286400.csv
# Loaded file: mmsi_257286400.csv, Rows: 3068
# Rows in area for mmsi_257286400.csv: 0
# Skipped mmsi_257286400.csv: No rows in specified area.
# (197/1880) Processing file: mmsi_211630850.csv
# Loaded file: mmsi_211630850.csv, Rows: 8
# Rows in area for mmsi_211630850.csv: 8
# Max consecutive entries for mmsi_211630850.csv: 1
# Skipped mmsi_211630850.csv: Insufficient consecutive entries in area.
# (198/1880) Processing file: mmsi_219000674.csv
# Loaded file: mmsi_219000674.csv, Rows: 13224
# Rows in area for mmsi_219000674.csv: 13224
# Max consecutive entries for mmsi_219000674.csv: 1
# Skipped mmsi_219000674.csv: Insufficient consecutive entries in area.
# (199/1880) Processing file: mmsi_219001239.csv
# Loaded file: mmsi_219001239.csv, Rows: 435
# Rows in area for mmsi_219001239.csv: 0
# Skipped mmsi_219001239.csv: No rows in specified area.
# (200/1880) Processing file: mmsi_265412000.csv
# Loaded file: mmsi_265412000.csv, Rows: 17757
# Rows in area for mmsi_265412000.csv: 0
# Skipped mmsi_265412000.csv: No rows in specified area.
# (201/1880) Processing file: mmsi_241348000.csv
# Loaded file: mmsi_241348000.csv, Rows: 3487
# Rows in area for mmsi_241348000.csv: 3487
# Max consecutive entries for mmsi_241348000.csv: 1
# Skipped mmsi_241348000.csv: Insufficient consecutive entries in area.
# (202/1880) Processing file: mmsi_219026257.csv
# Loaded file: mmsi_219026257.csv, Rows: 28286
# Rows in area for mmsi_219026257.csv: 28286
# Max consecutive entries for mmsi_219026257.csv: 1
# Skipped mmsi_219026257.csv: Insufficient consecutive entries in area.
# (203/1880) Processing file: mmsi_255803470.csv
# Loaded file: mmsi_255803470.csv, Rows: 7976
# Rows in area for mmsi_255803470.csv: 7976
# Max consecutive entries for mmsi_255803470.csv: 1
# Skipped mmsi_255803470.csv: Insufficient consecutive entries in area.
# (204/1880) Processing file: mmsi_219000407.csv
# Loaded file: mmsi_219000407.csv, Rows: 15345
# Rows in area for mmsi_219000407.csv: 0
# Skipped mmsi_219000407.csv: No rows in specified area.
# (205/1880) Processing file: mmsi_219028116.csv
# Loaded file: mmsi_219028116.csv, Rows: 16185
# Rows in area for mmsi_219028116.csv: 11095
# Max consecutive entries for mmsi_219028116.csv: 1
# Skipped mmsi_219028116.csv: Insufficient consecutive entries in area.
# (206/1880) Processing file: mmsi_219801000.csv
# Loaded file: mmsi_219801000.csv, Rows: 9582
# Rows in area for mmsi_219801000.csv: 0
# Skipped mmsi_219801000.csv: No rows in specified area.
# (207/1880) Processing file: mmsi_211551940.csv
# Loaded file: mmsi_211551940.csv, Rows: 661
# Rows in area for mmsi_211551940.csv: 661
# Max consecutive entries for mmsi_211551940.csv: 1
# Skipped mmsi_211551940.csv: Insufficient consecutive entries in area.
# (208/1880) Processing file: mmsi_244120000.csv
# Loaded file: mmsi_244120000.csv, Rows: 2521
# Rows in area for mmsi_244120000.csv: 2521
# Max consecutive entries for mmsi_244120000.csv: 1
# Skipped mmsi_244120000.csv: Insufficient consecutive entries in area.
# (209/1880) Processing file: mmsi_538006055.csv
# Loaded file: mmsi_538006055.csv, Rows: 24276
# Rows in area for mmsi_538006055.csv: 18835
# Max consecutive entries for mmsi_538006055.csv: 1
# Skipped mmsi_538006055.csv: Insufficient consecutive entries in area.
# (210/1880) Processing file: mmsi_219000897.csv
# Loaded file: mmsi_219000897.csv, Rows: 10043
# Rows in area for mmsi_219000897.csv: 0
# Skipped mmsi_219000897.csv: No rows in specified area.
# (211/1880) Processing file: mmsi_266444000.csv
# Loaded file: mmsi_266444000.csv, Rows: 15448
# Rows in area for mmsi_266444000.csv: 0
# Skipped mmsi_266444000.csv: No rows in specified area.
# (212/1880) Processing file: mmsi_220339000.csv
# Loaded file: mmsi_220339000.csv, Rows: 8710
# Rows in area for mmsi_220339000.csv: 0
# Skipped mmsi_220339000.csv: No rows in specified area.
# (213/1880) Processing file: mmsi_218197000.csv
# Loaded file: mmsi_218197000.csv, Rows: 1386
# Rows in area for mmsi_218197000.csv: 1386
# Max consecutive entries for mmsi_218197000.csv: 1
# Skipped mmsi_218197000.csv: Insufficient consecutive entries in area.
# (214/1880) Processing file: mmsi_258059000.csv
# Loaded file: mmsi_258059000.csv, Rows: 24973
# Rows in area for mmsi_258059000.csv: 0
# Skipped mmsi_258059000.csv: No rows in specified area.
# (215/1880) Processing file: mmsi_212423000.csv
# Loaded file: mmsi_212423000.csv, Rows: 758
# Rows in area for mmsi_212423000.csv: 0
# Skipped mmsi_212423000.csv: No rows in specified area.
# (216/1880) Processing file: mmsi_220259000.csv
# Loaded file: mmsi_220259000.csv, Rows: 1652
# Rows in area for mmsi_220259000.csv: 1652
# Max consecutive entries for mmsi_220259000.csv: 1
# Skipped mmsi_220259000.csv: Insufficient consecutive entries in area.
# (217/1880) Processing file: mmsi_219007414.csv
# Loaded file: mmsi_219007414.csv, Rows: 16129
# Rows in area for mmsi_219007414.csv: 16129
# Max consecutive entries for mmsi_219007414.csv: 1
# Skipped mmsi_219007414.csv: Insufficient consecutive entries in area.
# (218/1880) Processing file: mmsi_636020333.csv
# Loaded file: mmsi_636020333.csv, Rows: 27
# Rows in area for mmsi_636020333.csv: 27
# Max consecutive entries for mmsi_636020333.csv: 1
# Skipped mmsi_636020333.csv: Insufficient consecutive entries in area.
# (219/1880) Processing file: mmsi_255814000.csv
# Loaded file: mmsi_255814000.csv, Rows: 5988
# Rows in area for mmsi_255814000.csv: 0
# Skipped mmsi_255814000.csv: No rows in specified area.
# (220/1880) Processing file: mmsi_219006835.csv
# ...
# Max consecutive entries for mmsi_265874000.csv: 1
# Skipped mmsi_265874000.csv: Insufficient consecutive entries in area.
# (1810/1880) Processing file: mmsi_219023648.csv
# Loaded file: mmsi_219023648.csv, Rows: 43399
# Rows in area for mmsi_219023648.csv: 43399
# Max consecutive entries for mmsi_219023648.csv: 1
# Skipped mmsi_219023648.csv: Insufficient consecutive entries in area.
# (1811/1880) Processing file: mmsi_256562000.csv
# Loaded file: mmsi_256562000.csv, Rows: 7749
# Rows in area for mmsi_256562000.csv: 7749
# Max consecutive entries for mmsi_256562000.csv: 1
# Skipped mmsi_256562000.csv: Insufficient consecutive entries in area.
# (1812/1880) Processing file: mmsi_304108000.csv
# Loaded file: mmsi_304108000.csv, Rows: 15986
# Rows in area for mmsi_304108000.csv: 5508
# Max consecutive entries for mmsi_304108000.csv: 1
# Skipped mmsi_304108000.csv: Insufficient consecutive entries in area.
# (1813/1880) Processing file: mmsi_219000125.csv
# Loaded file: mmsi_219000125.csv, Rows: 1880
# Rows in area for mmsi_219000125.csv: 1880
# Max consecutive entries for mmsi_219000125.csv: 1
# Skipped mmsi_219000125.csv: Insufficient consecutive entries in area.
# (1814/1880) Processing file: mmsi_245662000.csv
# Loaded file: mmsi_245662000.csv, Rows: 1192
# Rows in area for mmsi_245662000.csv: 0
# Skipped mmsi_245662000.csv: No rows in specified area.
# (1815/1880) Processing file: mmsi_211806530.csv
# Loaded file: mmsi_211806530.csv, Rows: 1095
# Rows in area for mmsi_211806530.csv: 0
# Skipped mmsi_211806530.csv: No rows in specified area.
# (1816/1880) Processing file: mmsi_220622000.csv
# Loaded file: mmsi_220622000.csv, Rows: 7927
# Rows in area for mmsi_220622000.csv: 7927
# Max consecutive entries for mmsi_220622000.csv: 1
# Skipped mmsi_220622000.csv: Insufficient consecutive entries in area.
# (1817/1880) Processing file: mmsi_219921000.csv
# Loaded file: mmsi_219921000.csv, Rows: 6273
# Rows in area for mmsi_219921000.csv: 5786
# Max consecutive entries for mmsi_219921000.csv: 1
# Skipped mmsi_219921000.csv: Insufficient consecutive entries in area.
# (1818/1880) Processing file: mmsi_219173000.csv
# Loaded file: mmsi_219173000.csv, Rows: 11255
# Rows in area for mmsi_219173000.csv: 0
# Skipped mmsi_219173000.csv: No rows in specified area.
# (1819/1880) Processing file: mmsi_220181000.csv
# Loaded file: mmsi_220181000.csv, Rows: 8270
# Rows in area for mmsi_220181000.csv: 8270
# Max consecutive entries for mmsi_220181000.csv: 1
# Skipped mmsi_220181000.csv: Insufficient consecutive entries in area.
# (1820/1880) Processing file: mmsi_636015378.csv
# Loaded file: mmsi_636015378.csv, Rows: 719
# Rows in area for mmsi_636015378.csv: 0
# Skipped mmsi_636015378.csv: No rows in specified area.
# (1821/1880) Processing file: mmsi_210543000.csv
# Loaded file: mmsi_210543000.csv, Rows: 1615
# Rows in area for mmsi_210543000.csv: 1615
# Max consecutive entries for mmsi_210543000.csv: 1
# Skipped mmsi_210543000.csv: Insufficient consecutive entries in area.
# (1822/1880) Processing file: mmsi_219029707.csv
# Loaded file: mmsi_219029707.csv, Rows: 2302
# Rows in area for mmsi_219029707.csv: 0
# Skipped mmsi_219029707.csv: No rows in specified area.
# (1823/1880) Processing file: mmsi_261032010.csv
# Loaded file: mmsi_261032010.csv, Rows: 2
# Rows in area for mmsi_261032010.csv: 0
# Skipped mmsi_261032010.csv: No rows in specified area.
# (1824/1880) Processing file: mmsi_211888200.csv
# Loaded file: mmsi_211888200.csv, Rows: 2
# Rows in area for mmsi_211888200.csv: 2
# Max consecutive entries for mmsi_211888200.csv: 1
# Skipped mmsi_211888200.csv: Insufficient consecutive entries in area.
# (1825/1880) Processing file: mmsi_211757470.csv
# Loaded file: mmsi_211757470.csv, Rows: 7013
# Rows in area for mmsi_211757470.csv: 0
# Skipped mmsi_211757470.csv: No rows in specified area.
# (1826/1880) Processing file: mmsi_219005313.csv
# Loaded file: mmsi_219005313.csv, Rows: 6521
# Rows in area for mmsi_219005313.csv: 6521
# Max consecutive entries for mmsi_219005313.csv: 1
# Skipped mmsi_219005313.csv: Insufficient consecutive entries in area.
# (1827/1880) Processing file: mmsi_218039370.csv
# Loaded file: mmsi_218039370.csv, Rows: 8
# Rows in area for mmsi_218039370.csv: 8
# Max consecutive entries for mmsi_218039370.csv: 1
# Skipped mmsi_218039370.csv: Insufficient consecutive entries in area.
# (1828/1880) Processing file: mmsi_231809000.csv
# Loaded file: mmsi_231809000.csv, Rows: 190
# Rows in area for mmsi_231809000.csv: 0
# Skipped mmsi_231809000.csv: No rows in specified area.
# (1829/1880) Processing file: mmsi_219012788.csv
# Loaded file: mmsi_219012788.csv, Rows: 1006
# Rows in area for mmsi_219012788.csv: 1006
# Max consecutive entries for mmsi_219012788.csv: 1
# Skipped mmsi_219012788.csv: Insufficient consecutive entries in area.
# (1830/1880) Processing file: mmsi_219731000.csv
# Loaded file: mmsi_219731000.csv, Rows: 13658
# Rows in area for mmsi_219731000.csv: 0
# Skipped mmsi_219731000.csv: No rows in specified area.
# (1831/1880) Processing file: mmsi_210353000.csv
# Loaded file: mmsi_210353000.csv, Rows: 168
# Rows in area for mmsi_210353000.csv: 0
# Skipped mmsi_210353000.csv: No rows in specified area.
# (1832/1880) Processing file: mmsi_219018044.csv
# Loaded file: mmsi_219018044.csv, Rows: 707
# Rows in area for mmsi_219018044.csv: 707
# Max consecutive entries for mmsi_219018044.csv: 1
# Skipped mmsi_219018044.csv: Insufficient consecutive entries in area.
# (1833/1880) Processing file: mmsi_219024783.csv
# Loaded file: mmsi_219024783.csv, Rows: 13246
# Rows in area for mmsi_219024783.csv: 13246
# Max consecutive entries for mmsi_219024783.csv: 1
# Skipped mmsi_219024783.csv: Insufficient consecutive entries in area.
# (1834/1880) Processing file: mmsi_636021568.csv
# Loaded file: mmsi_636021568.csv, Rows: 4
# Rows in area for mmsi_636021568.csv: 0
# Skipped mmsi_636021568.csv: No rows in specified area.
# (1835/1880) Processing file: mmsi_305371000.csv
# Loaded file: mmsi_305371000.csv, Rows: 1539
# Rows in area for mmsi_305371000.csv: 0
# Skipped mmsi_305371000.csv: No rows in specified area.
# (1836/1880) Processing file: mmsi_257088050.csv
# Loaded file: mmsi_257088050.csv, Rows: 4518
# Rows in area for mmsi_257088050.csv: 0
# Skipped mmsi_257088050.csv: No rows in specified area.
# (1837/1880) Processing file: mmsi_219026706.csv
# Loaded file: mmsi_219026706.csv, Rows: 9900
# Rows in area for mmsi_219026706.csv: 0
# Skipped mmsi_219026706.csv: No rows in specified area.
# (1838/1880) Processing file: mmsi_265527470.csv
# Loaded file: mmsi_265527470.csv, Rows: 7763
# Rows in area for mmsi_265527470.csv: 0
# Skipped mmsi_265527470.csv: No rows in specified area.
# (1839/1880) Processing file: mmsi_215004000.csv
# Loaded file: mmsi_215004000.csv, Rows: 28411
# Rows in area for mmsi_215004000.csv: 13005
# Max consecutive entries for mmsi_215004000.csv: 1
# Skipped mmsi_215004000.csv: Insufficient consecutive entries in area.
# (1840/1880) Processing file: mmsi_220051000.csv
# Loaded file: mmsi_220051000.csv, Rows: 22008
# Rows in area for mmsi_220051000.csv: 0
# Skipped mmsi_220051000.csv: No rows in specified area.
# (1841/1880) Processing file: mmsi_219449000.csv
# Loaded file: mmsi_219449000.csv, Rows: 10162
# Rows in area for mmsi_219449000.csv: 0
# Skipped mmsi_219449000.csv: No rows in specified area.
# (1842/1880) Processing file: mmsi_219028965.csv
# Loaded file: mmsi_219028965.csv, Rows: 2020
# Rows in area for mmsi_219028965.csv: 2020
# Max consecutive entries for mmsi_219028965.csv: 1
# Skipped mmsi_219028965.csv: Insufficient consecutive entries in area.
# (1843/1880) Processing file: mmsi_256525000.csv
# Loaded file: mmsi_256525000.csv, Rows: 13067
# Rows in area for mmsi_256525000.csv: 9016
# Max consecutive entries for mmsi_256525000.csv: 1
# Skipped mmsi_256525000.csv: Insufficient consecutive entries in area.
# (1844/1880) Processing file: mmsi_636022672.csv
# Loaded file: mmsi_636022672.csv, Rows: 1870
# Rows in area for mmsi_636022672.csv: 0
# Skipped mmsi_636022672.csv: No rows in specified area.
# (1845/1880) Processing file: mmsi_209223000.csv
# Loaded file: mmsi_209223000.csv, Rows: 261
# Rows in area for mmsi_209223000.csv: 62
# Max consecutive entries for mmsi_209223000.csv: 1
# Skipped mmsi_209223000.csv: Insufficient consecutive entries in area.
# (1846/1880) Processing file: mmsi_219014435.csv
# Loaded file: mmsi_219014435.csv, Rows: 621
# Rows in area for mmsi_219014435.csv: 0
# Skipped mmsi_219014435.csv: No rows in specified area.
# (1847/1880) Processing file: mmsi_219015579.csv
# Loaded file: mmsi_219015579.csv, Rows: 4590
# Rows in area for mmsi_219015579.csv: 4590
# Max consecutive entries for mmsi_219015579.csv: 1
# Skipped mmsi_219015579.csv: Insufficient consecutive entries in area.
# (1848/1880) Processing file: mmsi_352003718.csv
# Loaded file: mmsi_352003718.csv, Rows: 7471
# Rows in area for mmsi_352003718.csv: 0
# Skipped mmsi_352003718.csv: No rows in specified area.
# (1849/1880) Processing file: mmsi_255724000.csv
# Loaded file: mmsi_255724000.csv, Rows: 2253
# Rows in area for mmsi_255724000.csv: 1950
# Max consecutive entries for mmsi_255724000.csv: 1
# Skipped mmsi_255724000.csv: Insufficient consecutive entries in area.
# (1850/1880) Processing file: mmsi_219997000.csv
# Loaded file: mmsi_219997000.csv, Rows: 11447
# Rows in area for mmsi_219997000.csv: 11447
# Max consecutive entries for mmsi_219997000.csv: 1
# Skipped mmsi_219997000.csv: Insufficient consecutive entries in area.
# (1851/1880) Processing file: mmsi_219005964.csv
# Loaded file: mmsi_219005964.csv, Rows: 7805
# Rows in area for mmsi_219005964.csv: 0
# Skipped mmsi_219005964.csv: No rows in specified area.
# (1852/1880) Processing file: mmsi_220368000.csv
# Loaded file: mmsi_220368000.csv, Rows: 3493
# Rows in area for mmsi_220368000.csv: 0
# Skipped mmsi_220368000.csv: No rows in specified area.
# (1853/1880) Processing file: mmsi_636015945.csv
# Loaded file: mmsi_636015945.csv, Rows: 6024
# Rows in area for mmsi_636015945.csv: 1430
# Max consecutive entries for mmsi_636015945.csv: 1
# Skipped mmsi_636015945.csv: Insufficient consecutive entries in area.
# (1854/1880) Processing file: mmsi_266461000.csv
# Loaded file: mmsi_266461000.csv, Rows: 3432
# Rows in area for mmsi_266461000.csv: 0
# Skipped mmsi_266461000.csv: No rows in specified area.
# (1855/1880) Processing file: mmsi_211316340.csv
# Loaded file: mmsi_211316340.csv, Rows: 2133
# Rows in area for mmsi_211316340.csv: 0
# Skipped mmsi_211316340.csv: No rows in specified area.
# (1856/1880) Processing file: mmsi_211287870.csv
# Loaded file: mmsi_211287870.csv, Rows: 3
# Rows in area for mmsi_211287870.csv: 3
# Max consecutive entries for mmsi_211287870.csv: 1
# Skipped mmsi_211287870.csv: Insufficient consecutive entries in area.
# (1857/1880) Processing file: mmsi_219024175.csv
# Loaded file: mmsi_219024175.csv, Rows: 19446
# Rows in area for mmsi_219024175.csv: 19446
# Max consecutive entries for mmsi_219024175.csv: 1
# Skipped mmsi_219024175.csv: Insufficient consecutive entries in area.
# (1858/1880) Processing file: mmsi_211217670.csv
# Loaded file: mmsi_211217670.csv, Rows: 14
# Rows in area for mmsi_211217670.csv: 0
# Skipped mmsi_211217670.csv: No rows in specified area.
# (1859/1880) Processing file: mmsi_209535000.csv
# Loaded file: mmsi_209535000.csv, Rows: 24340
# Rows in area for mmsi_209535000.csv: 9730
# Max consecutive entries for mmsi_209535000.csv: 1
# Skipped mmsi_209535000.csv: Insufficient consecutive entries in area.
# (1860/1880) Processing file: mmsi_219837000.csv
# Loaded file: mmsi_219837000.csv, Rows: 10302
# Rows in area for mmsi_219837000.csv: 0
# Skipped mmsi_219837000.csv: No rows in specified area.
# (1861/1880) Processing file: mmsi_566679000.csv
# Loaded file: mmsi_566679000.csv, Rows: 1066
# Rows in area for mmsi_566679000.csv: 0
# Skipped mmsi_566679000.csv: No rows in specified area.
# (1862/1880) Processing file: mmsi_219024886.csv
# Loaded file: mmsi_219024886.csv, Rows: 8410
# Rows in area for mmsi_219024886.csv: 8410
# Max consecutive entries for mmsi_219024886.csv: 1
# Skipped mmsi_219024886.csv: Insufficient consecutive entries in area.
# (1863/1880) Processing file: mmsi_219904000.csv
# Loaded file: mmsi_219904000.csv, Rows: 10253
# Rows in area for mmsi_219904000.csv: 10253
# Max consecutive entries for mmsi_219904000.csv: 1
# Skipped mmsi_219904000.csv: Insufficient consecutive entries in area.
# (1864/1880) Processing file: mmsi_538006145.csv
# Loaded file: mmsi_538006145.csv, Rows: 14769
# Rows in area for mmsi_538006145.csv: 6294
# Max consecutive entries for mmsi_538006145.csv: 1
# Skipped mmsi_538006145.csv: Insufficient consecutive entries in area.
# (1865/1880) Processing file: mmsi_538006085.csv
# Loaded file: mmsi_538006085.csv, Rows: 3105
# Rows in area for mmsi_538006085.csv: 0
# Skipped mmsi_538006085.csv: No rows in specified area.
# (1866/1880) Processing file: mmsi_244054000.csv
# Loaded file: mmsi_244054000.csv, Rows: 13576
# Rows in area for mmsi_244054000.csv: 12611
# Max consecutive entries for mmsi_244054000.csv: 2
# Skipped mmsi_244054000.csv: Insufficient consecutive entries in area.
# (1867/1880) Processing file: mmsi_255802950.csv
# Loaded file: mmsi_255802950.csv, Rows: 1629
# Rows in area for mmsi_255802950.csv: 1629
# Max consecutive entries for mmsi_255802950.csv: 1
# Skipped mmsi_255802950.csv: Insufficient consecutive entries in area.
# (1868/1880) Processing file: mmsi_211302890.csv
# Loaded file: mmsi_211302890.csv, Rows: 1340
# Rows in area for mmsi_211302890.csv: 1340
# Max consecutive entries for mmsi_211302890.csv: 1
# Skipped mmsi_211302890.csv: Insufficient consecutive entries in area.
# (1869/1880) Processing file: mmsi_261003012.csv
# Loaded file: mmsi_261003012.csv, Rows: 639
# Rows in area for mmsi_261003012.csv: 493
# Max consecutive entries for mmsi_261003012.csv: 2
# Skipped mmsi_261003012.csv: Insufficient consecutive entries in area.
# (1870/1880) Processing file: mmsi_219024597.csv
# Loaded file: mmsi_219024597.csv, Rows: 6226
# Rows in area for mmsi_219024597.csv: 6226
# Max consecutive entries for mmsi_219024597.csv: 1
# Skipped mmsi_219024597.csv: Insufficient consecutive entries in area.
# (1871/1880) Processing file: mmsi_477624400.csv
# Loaded file: mmsi_477624400.csv, Rows: 10722
# Rows in area for mmsi_477624400.csv: 4604
# Max consecutive entries for mmsi_477624400.csv: 1
# Skipped mmsi_477624400.csv: Insufficient consecutive entries in area.
# (1872/1880) Processing file: mmsi_219012639.csv
# Loaded file: mmsi_219012639.csv, Rows: 9171
# Rows in area for mmsi_219012639.csv: 9171
# Max consecutive entries for mmsi_219012639.csv: 1
# Skipped mmsi_219012639.csv: Insufficient consecutive entries in area.
# (1873/1880) Processing file: mmsi_255806525.csv
# Loaded file: mmsi_255806525.csv, Rows: 12540
# Rows in area for mmsi_255806525.csv: 4385
# Max consecutive entries for mmsi_255806525.csv: 1
# Skipped mmsi_255806525.csv: Insufficient consecutive entries in area.
# (1874/1880) Processing file: mmsi_255806328.csv
# Loaded file: mmsi_255806328.csv, Rows: 4629
# Rows in area for mmsi_255806328.csv: 0
# Skipped mmsi_255806328.csv: No rows in specified area.
# (1875/1880) Processing file: mmsi_211833390.csv
# Loaded file: mmsi_211833390.csv, Rows: 8159
# Rows in area for mmsi_211833390.csv: 920
# Max consecutive entries for mmsi_211833390.csv: 2
# Skipped mmsi_211833390.csv: Insufficient consecutive entries in area.
# (1876/1880) Processing file: mmsi_219018684.csv
# Loaded file: mmsi_219018684.csv, Rows: 1217
# Rows in area for mmsi_219018684.csv: 0
# Skipped mmsi_219018684.csv: No rows in specified area.
# (1877/1880) Processing file: mmsi_352001928.csv
# Loaded file: mmsi_352001928.csv, Rows: 564
# Rows in area for mmsi_352001928.csv: 564
# Max consecutive entries for mmsi_352001928.csv: 1
# Skipped mmsi_352001928.csv: Insufficient consecutive entries in area.
# (1878/1880) Processing file: mmsi_219021176.csv
# Loaded file: mmsi_219021176.csv, Rows: 21149
# Rows in area for mmsi_219021176.csv: 0
# Skipped mmsi_219021176.csv: No rows in specified area.
# (1879/1880) Processing file: mmsi_245875000.csv
# Loaded file: mmsi_245875000.csv, Rows: 1218
# Rows in area for mmsi_245875000.csv: 1218
# Max consecutive entries for mmsi_245875000.csv: 1
# Skipped mmsi_245875000.csv: Insufficient consecutive entries in area.
# (1880/1880) Processing file: mmsi_257312000.csv
# Loaded file: mmsi_257312000.csv, Rows: 152
# Rows in area for mmsi_257312000.csv: 0
# Skipped mmsi_257312000.csv: No rows in specified area.
